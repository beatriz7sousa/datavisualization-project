# %%
# !pip install cities_coordinates

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler

#https://github.com/sofzer/cities_coordinates
from cities_coordinates import CityCoordinator
c = CityCoordinator()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Data Visualization - ATP Stats
#
# </div>

# %% [markdown]
# - Ana Sofia Mendonça, number: 20220678
# - Beatriz Sousa, number: 20220674
# - Cláudia Rocha, number: r20191249
# - Susana Dias, number: 20220198

# %% [markdown]
# <a id = "toc"></a>
#
# 1. [Import the datasets](#import-datasets)
# 2. [Data understanding and preparation - Tournaments dataset](#understanding-preparation-tournaments)
# 3. [Data understanding and preparation - Match Scores dataset](#understanding-preparation-match-scores)
# 4. [Data understanding and preparation - Match Stats dataset](#understanding-preparation-match-stats)
# 5. [Merging the stats dataset with the score dataset](#merging-match-scores-stats)

# %% [markdown]
# <a id = "import-datasets"></a>
#
# ## 1. Import the datasets
#
# [Back to TOC](#toc)

# %%
# defining the path to get the datasets from github

path_datasets = 'https://raw.githubusercontent.com/serve-and-volley/atp-world-tour-tennis-data/master/csv/'
path_tournaments = '1_tournaments/'
path_match_scores = '2_match_scores/'
path_match_stats = '3_match_stats/'

# %%
# defining the name of the variables in the tournaments datasets, in order to define the header
tournaments_header = ['tourney_year_id', 'tourney_order', 'tourney_type', 'tourney_name', 'tourney_id', 'tourney_slug', 'tourney_location', 'tourney_date', 'year', 'tourney_month', 'tourney_day', 'tourney_singles_draw', 'tourney_doubles_draw', 'tourney_conditions', 'tourney_surface', 'tourney_fin_commit_raw', 'currency', 'tourney_fin_commit', 'tourney_url_suffix', 'singles_winner_name', 'singles_winner_url', 'singles_winner_player_slug', 'singles_winner_player_id', 'doubles_winner_1_name', 'doubles_winner_1_url', 'doubles_winner_1_player_slug', 'doubles_winner_1_player_id', 'doubles_winner_2_name', 'doubles_winner_2_url', 'doubles_winner_2_player_slug', 'doubles_winner_2_player_id']

# importing the datasets
tournaments = pd.read_csv(path_datasets + path_tournaments + 'tournaments_2010-2019.csv', names = tournaments_header)

# %%
# defining the name of the variables in the match scores datasets, in order to define the header
match_scores_header = ['tourney_year_id', 'tourney_order', 'tourney_name', 'tourney_slug', 'tourney_url_suffix', 'start_date', 'start_year', 'start_month', 'start_day', 'end_date', 'end_year', 'end_month', 'end_day', 'currency', 'prize_money', 'match_index', 'tourney_round_name', 'round_order', 'match_order', 'winner_name', 'winner_player_id', 'winner_slug', 'loser_name', 'loser_player_id', 'loser_slug', 'winner_seed', 'loser_seed', 'match_score_tiebreaks', 'winner_sets_won', 'loser_sets_won', 'winner_games_won', 'loser_games_won', 'winner_tiebreaks_won', 'loser_tiebreaks_won', 'match_id', 'match_stats_url_suffix']

# importing the datasets 
match_scores = pd.read_csv(path_datasets + path_match_scores + 'match_scores_2010-2019.csv', names = match_scores_header)

# %%
# defining the name of the variables in the match stats datasets, in order to define the header
match_stats_header = ['match_id', 'tourney_slug', 'match_stats_url_suffix', 'match_time', 'match_duration', 'winner_slug', 'winner_serve_rating', 'winner_aces', 'winner_double_faults', 'winner_first_serves_in', 'winner_first_serves_total', 'winner_first_serve_points_won', 'winner_first_serve_points_total', 'winner_second_serve_points_won', 'winner_second_serve_points_total', 'winner_break_points_saved', 'winner_break_points_serve_total', 'winner_service_games_played', 'winner_return_rating', 'winner_first_serve_return_won', 'winner_first_serve_return_total', 'winner_second_serve_return_won', 'winner_second_serve_return_total', 'winner_break_points_converted', 'winner_break_points_return_total', 'winner_return_games_played', 'winner_service_points_won', 'winner_service_points_total', 'winner_return_points_won', 'winner_return_points_total', 'winner_total_points_won', 'winner_total_points_total', 'loser_slug', 'loser_serve_rating', 'loser_aces', 'loser_double_faults', 'loser_first_serves_in', 'loser_first_serves_total', 'loser_first_serve_points_won', 'loser_first_serve_points_total', 'loser_second_serve_points_won', 'loser_second_serve_points_total', 'loser_break_points_saved', 'loser_break_points_serve_total', 'loser_service_games_played', 'loser_return_rating', 'loser_first_serve_return_won', 'loser_first_serve_return_total', 'loser_second_serve_return_won', 'loser_second_serve_return_total', 'loser_break_points_converted', 'loser_break_points_return_total', 'loser_return_games_played', 'loser_service_points_won', 'loser_service_points_total', 'loser_return_points_won', 'loser_return_points_total', 'loser_total_points_won', 'loser_total_points_total']

# importing the datasets 
match_stats_2010 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2010.csv', names = match_stats_header)
match_stats_2011 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2011.csv', names = match_stats_header)
match_stats_2012 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2012.csv', names = match_stats_header)
match_stats_2013 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2013.csv', names = match_stats_header)
match_stats_2014 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2014.csv', names = match_stats_header)
match_stats_2015 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2015.csv', names = match_stats_header)
match_stats_2016 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2016.csv', names = match_stats_header)
match_stats_2017 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2017.csv', names = match_stats_header)
match_stats_2018 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2018.csv', names = match_stats_header)
match_stats_2019 = pd.read_csv(path_datasets + path_match_stats + 'match_stats_2019.csv', names = match_stats_header)

# stack them into one dataset
match_stats = pd.concat([match_stats_2010, match_stats_2011, match_stats_2012, match_stats_2013, match_stats_2014, match_stats_2015, match_stats_2016, match_stats_2017, match_stats_2018, match_stats_2019], ignore_index = True)

# %% [markdown]
# <a id = "understanding-preparation-tournaments"></a>
#
# ## 2. Data understanding and preparation - Tournaments datasets
#
# [Back to TOC](#toc)

# %%
tournaments.T
# Out:
#                                                                        0    \
# tourney_year_id                                                   2010-339
# tourney_order                                                            1
# tourney_type                                                       ATP 250
# tourney_name                                                      Brisbane
# tourney_id                                                             339
# tourney_slug                                                      brisbane
# tourney_location                                                  Brisbane
# tourney_date                                                    2010.01.03
# year                                                                  2010
# tourney_month                                                            1
# tourney_day                                                              3
# tourney_singles_draw                                                    32
# tourney_doubles_draw                                                    16
# tourney_conditions                                                 Outdoor
# tourney_surface                                                       Hard
# tourney_fin_commit_raw                                            $424,250
# currency                                                               USD
# tourney_fin_commit                                                424250.0
# tourney_url_suffix            /en/scores/archive/brisbane/339/2010/results
# singles_winner_name                                           Andy Roddick
# singles_winner_url                  /en/players/andy-roddick/r485/overview
# singles_winner_player_slug                                    andy-roddick
# singles_winner_player_id                                              r485
# doubles_winner_1_name                                        Jeremy Chardy
# doubles_winner_1_url               /en/players/jeremy-chardy/ca12/overview
# doubles_winner_1_player_slug                                 jeremy-chardy
# doubles_winner_1_player_id                                            ca12
# doubles_winner_2_name                                         Marc Gicquel
# doubles_winner_2_url                /en/players/marc-gicquel/g436/overview
# doubles_winner_2_player_slug                                  marc-gicquel
# doubles_winner_2_player_id                                            g436
#
#                                                                            1    \
# tourney_year_id                                                       2010-451
# tourney_order                                                                2
# tourney_type                                                           ATP 250
# tourney_name                                                              Doha
# tourney_id                                                                 451
# tourney_slug                                                              doha
# tourney_location                                                          Doha
# tourney_date                                                        2010.01.04
# year                                                                      2010
# tourney_month                                                                1
# tourney_day                                                                  4
# tourney_singles_draw                                                        32
# tourney_doubles_draw                                                        16
# tourney_conditions                                                     Outdoor
# tourney_surface                                                           Hard
# tourney_fin_commit_raw                                              $1,110,250
# currency                                                                   USD
# tourney_fin_commit                                                   1110250.0
# tourney_url_suffix                    /en/scores/archive/doha/451/2010/results
# singles_winner_name                                          Nikolay Davydenko
# singles_winner_url                 /en/players/nikolay-davydenko/d402/overview
# singles_winner_player_slug                                   nikolay-davydenko
# singles_winner_player_id                                                  d402
# doubles_winner_1_name                                   Guillermo Garcia-Lopez
# doubles_winner_1_url          /en/players/guillermo-garcia-lopez/g476/overview
# doubles_winner_1_player_slug                            guillermo-garcia-lopez
# doubles_winner_1_player_id                                                g476
# doubles_winner_2_name                                          Albert Montanes
# doubles_winner_2_url                 /en/players/albert-montanes/m824/overview
# doubles_winner_2_player_slug                                   albert-montanes
# doubles_winner_2_player_id                                                m824
#
#                                                                       2    \
# tourney_year_id                                                  2010-891
# tourney_order                                                           3
# tourney_type                                                      ATP 250
# tourney_name                                                      Chennai
# tourney_id                                                            891
# tourney_slug                                                      chennai
# tourney_location                                                  Chennai
# tourney_date                                                   2010.01.04
# year                                                                 2010
# tourney_month                                                           1
# tourney_day                                                             4
# tourney_singles_draw                                                   32
# tourney_doubles_draw                                                   16
# tourney_conditions                                                Outdoor
# tourney_surface                                                      Hard
# tourney_fin_commit_raw                                           $450,000
# currency                                                              USD
# tourney_fin_commit                                               450000.0
# tourney_url_suffix            /en/scores/archive/chennai/891/2010/results
# singles_winner_name                                           Marin Cilic
# singles_winner_url                  /en/players/marin-cilic/c977/overview
# singles_winner_player_slug                                    marin-cilic
# singles_winner_player_id                                             c977
# doubles_winner_1_name                                   Marcel Granollers
# doubles_winner_1_url          /en/players/marcel-granollers/g710/overview
# doubles_winner_1_player_slug                            marcel-granollers
# doubles_winner_1_player_id                                           g710
# doubles_winner_2_name                                    Santiago Ventura
# doubles_winner_2_url           /en/players/santiago-ventura/v251/overview
# doubles_winner_2_player_slug                             santiago-ventura
# doubles_winner_2_player_id                                           v251
#
#                                                                      3    \
# tourney_year_id                                                 2010-338
# tourney_order                                                          4
# tourney_type                                                     ATP 250
# tourney_name                                                      Sydney
# tourney_id                                                           338
# tourney_slug                                                      sydney
# tourney_location                                                  Sydney
# tourney_date                                                  2010.01.11
# year                                                                2010
# tourney_month                                                          1
# tourney_day                                                           11
# tourney_singles_draw                                                  28
# tourney_doubles_draw                                                  16
# tourney_conditions                                               Outdoor
# tourney_surface                                                     Hard
# tourney_fin_commit_raw                                          $424,250
# currency                                                             USD
# tourney_fin_commit                                              424250.0
# tourney_url_suffix            /en/scores/archive/sydney/338/2010/results
# singles_winner_name                                     Marcos Baghdatis
# singles_winner_url            /en/players/marcos-baghdatis/b837/overview
# singles_winner_player_slug                              marcos-baghdatis
# singles_winner_player_id                                            b837
# doubles_winner_1_name                                      Daniel Nestor
# doubles_winner_1_url             /en/players/daniel-nestor/n210/overview
# doubles_winner_1_player_slug                               daniel-nestor
# doubles_winner_1_player_id                                          n210
# doubles_winner_2_name                                     Nenad Zimonjic
# doubles_winner_2_url            /en/players/nenad-zimonjic/z072/overview
# doubles_winner_2_player_slug                              nenad-zimonjic
# doubles_winner_2_player_id                                          z072
#
#                                                                        4    \
# tourney_year_id                                                   2010-301
# tourney_order                                                            5
# tourney_type                                                       ATP 250
# tourney_name                                                      Auckland
# tourney_id                                                             301
# tourney_slug                                                      auckland
# tourney_location                                                  Auckland
# tourney_date                                                    2010.01.11
# year                                                                  2010
# tourney_month                                                            1
# tourney_day                                                             11
# tourney_singles_draw                                                    28
# tourney_doubles_draw                                                    16
# tourney_conditions                                                 Outdoor
# tourney_surface                                                       Hard
# tourney_fin_commit_raw                                            $407,250
# currency                                                               USD
# tourney_fin_commit                                                407250.0
# tourney_url_suffix            /en/scores/archive/auckland/301/2010/results
# singles_winner_name                                             John Isner
# singles_winner_url                    /en/players/john-isner/i186/overview
# singles_winner_player_slug                                      john-isner
# singles_winner_player_id                                              i186
# doubles_winner_1_name                                       Marcus Daniell
# doubles_winner_1_url              /en/players/marcus-daniell/d763/overview
# doubles_winner_1_player_slug                                marcus-daniell
# doubles_winner_1_player_id                                            d763
# doubles_winner_2_name                                          Horia Tecau
# doubles_winner_2_url                 /en/players/horia-tecau/t749/overview
# doubles_winner_2_player_slug                                   horia-tecau
# doubles_winner_2_player_id                                            t749
#
#                                                                             5    \
# tourney_year_id                                                        2010-580
# tourney_order                                                                 6
# tourney_type                                                         Grand Slam
# tourney_name                                                    Australian Open
# tourney_id                                                                  580
# tourney_slug                                                    australian-open
# tourney_location                                                      Melbourne
# tourney_date                                                         2010.01.18
# year                                                                       2010
# tourney_month                                                                 1
# tourney_day                                                                  18
# tourney_singles_draw                                                        128
# tourney_doubles_draw                                                         64
# tourney_conditions                                                      Outdoor
# tourney_surface                                                            Hard
# tourney_fin_commit_raw                                             A$11,048,640
# currency                                                                    AUD
# tourney_fin_commit                                                   11048640.0
# tourney_url_suffix            /en/scores/archive/australian-open/580/2010/re...
# singles_winner_name                                               Roger Federer
# singles_winner_url                      /en/players/roger-federer/f324/overview
# singles_winner_player_slug                                        roger-federer
# singles_winner_player_id                                                   f324
# doubles_winner_1_name                                                 Bob Bryan
# doubles_winner_1_url                        /en/players/bob-bryan/b588/overview
# doubles_winner_1_player_slug                                          bob-bryan
# doubles_winner_1_player_id                                                 b588
# doubles_winner_2_name                                                Mike Bryan
# doubles_winner_2_url                       /en/players/mike-bryan/b589/overview
# doubles_winner_2_player_slug                                         mike-bryan
# doubles_winner_2_player_id                                                 b589
#
#                                                                             6    \
# tourney_year_id                                                       2010-5012
# tourney_order                                                                 7
# tourney_type                                                            ATP 250
# tourney_name                                                       Johannesburg
# tourney_id                                                                 5012
# tourney_slug                                                       johannesburg
# tourney_location                                                   Johannesburg
# tourney_date                                                         2010.02.01
# year                                                                       2010
# tourney_month                                                                 2
# tourney_day                                                                   1
# tourney_singles_draw                                                         32
# tourney_doubles_draw                                                         16
# tourney_conditions                                                      Outdoor
# tourney_surface                                                            Hard
# tourney_fin_commit_raw                                                 $500,000
# currency                                                                    USD
# tourney_fin_commit                                                     500000.0
# tourney_url_suffix            /en/scores/archive/johannesburg/5012/2010/results
# singles_winner_name                                             Feliciano Lopez
# singles_winner_url                    /en/players/feliciano-lopez/l397/overview
# singles_winner_player_slug                                      feliciano-lopez
# singles_winner_player_id                                                   l397
# doubles_winner_1_name                                             Rohan Bopanna
# doubles_winner_1_url                    /en/players/rohan-bopanna/b757/overview
# doubles_winner_1_player_slug                                      rohan-bopanna
# doubles_winner_1_player_id                                                 b757
# doubles_winner_2_name                                      Aisam-Ul-Haq Qureshi
# doubles_winner_2_url             /en/players/aisam-ul-haq-qureshi/q019/overview
# doubles_winner_2_player_slug                               aisam-ul-haq-qureshi
# doubles_winner_2_player_id                                                 q019
#
#                                                                        7    \
# tourney_year_id                                                   2010-505
# tourney_order                                                            8
# tourney_type                                                       ATP 250
# tourney_name                                                      Santiago
# tourney_id                                                             505
# tourney_slug                                                      santiago
# tourney_location                                                  Santiago
# tourney_date                                                    2010.02.01
# year                                                                  2010
# tourney_month                                                            2
# tourney_day                                                              1
# tourney_singles_draw                                                    32
# tourney_doubles_draw                                                    16
# tourney_conditions                                                 Outdoor
# tourney_surface                                                       Clay
# tourney_fin_commit_raw                                            $450,000
# currency                                                               USD
# tourney_fin_commit                                                450000.0
# tourney_url_suffix            /en/scores/archive/santiago/505/2010/results
# singles_winner_name                                        Thomaz Bellucci
# singles_winner_url               /en/players/thomaz-bellucci/bd20/overview
# singles_winner_player_slug                                 thomaz-bellucci
# singles_winner_player_id                                              bd20
# doubles_winner_1_name                                         Lukasz Kubot
# doubles_winner_1_url                /en/players/lukasz-kubot/k540/overview
# doubles_winner_1_player_slug                                  lukasz-kubot
# doubles_winner_1_player_id                                            k540
# doubles_winner_2_name                                        Oliver Marach
# doubles_winner_2_url               /en/players/oliver-marach/m760/overview
# doubles_winner_2_player_slug                                 oliver-marach
# doubles_winner_2_player_id                                            m760
#
#                                                                        8    \
# tourney_year_id                                                  2010-2276
# tourney_order                                                            9
# tourney_type                                                       ATP 250
# tourney_name                                                        Zagreb
# tourney_id                                                            2276
# tourney_slug                                                        zagreb
# tourney_location                                                    Zagreb
# tourney_date                                                    2010.02.01
# year                                                                  2010
# tourney_month                                                            2
# tourney_day                                                              1
# tourney_singles_draw                                                    32
# tourney_doubles_draw                                                    16
# tourney_conditions                                                  Indoor
# tourney_surface                                                       Hard
# tourney_fin_commit_raw                                            €450,000
# currency                                                               EUR
# tourney_fin_commit                                                450000.0
# tourney_url_suffix             /en/scores/archive/zagreb/2276/2010/results
# singles_winner_name                                            Marin Cilic
# singles_winner_url                   /en/players/marin-cilic/c977/overview
# singles_winner_player_slug                                     marin-cilic
# singles_winner_player_id                                              c977
# doubles_winner_1_name                                        Jurgen Melzer
# doubles_winner_1_url               /en/players/jurgen-melzer/m762/overview
# doubles_winner_1_player_slug                                 jurgen-melzer
# doubles_winner_1_player_id                                            m762
# doubles_winner_2_name                                   Philipp Petzschner
# doubles_winner_2_url          /en/players/philipp-petzschner/p624/overview
# doubles_winner_2_player_slug                            philipp-petzschner
# doubles_winner_2_player_id                                            p624
#
#                                                                         9    \
# tourney_year_id                                                    2010-407
# tourney_order                                                            10
# tourney_type                                                        ATP 500
# tourney_name                                                      Rotterdam
# tourney_id                                                              407
# tourney_slug                                                      rotterdam
# tourney_location                                                  Rotterdam
# tourney_date                                                     2010.02.08
# year                                                                   2010
# tourney_month                                                             2
# tourney_day                                                               8
# tourney_singles_draw                                                     32
# tourney_doubles_draw                                                     16
# tourney_conditions                                                   Indoor
# tourney_surface                                                        Hard
# tourney_fin_commit_raw                                           €1,445,000
# currency                                                                EUR
# tourney_fin_commit                                                1445000.0
# tourney_url_suffix            /en/scores/archive/rotterdam/407/2010/results
# singles_winner_name                                         Robin Soderling
# singles_winner_url                /en/players/robin-soderling/sa49/overview
# singles_winner_player_slug                                  robin-soderling
# singles_winner_player_id                                               sa49
# doubles_winner_1_name                                         Daniel Nestor
# doubles_winner_1_url                /en/players/daniel-nestor/n210/overview
# doubles_winner_1_player_slug                                  daniel-nestor
# doubles_winner_1_player_id                                             n210
# doubles_winner_2_name                                        Nenad Zimonjic
# doubles_winner_2_url               /en/players/nenad-zimonjic/z072/overview
# doubles_winner_2_player_slug                                 nenad-zimonjic
# doubles_winner_2_player_id                                             z072
#
#                               ...  \
# tourney_year_id               ...
# tourney_order                 ...
# tourney_type                  ...
# tourney_name                  ...
# tourney_id                    ...
# tourney_slug                  ...
# tourney_location              ...
# tourney_date                  ...
# year                          ...
# tourney_month                 ...
# tourney_day                   ...
# tourney_singles_draw          ...
# tourney_doubles_draw          ...
# tourney_conditions            ...
# tourney_surface               ...
# tourney_fin_commit_raw        ...
# currency                      ...
# tourney_fin_commit            ...
# tourney_url_suffix            ...
# singles_winner_name           ...
# singles_winner_url            ...
# singles_winner_player_slug    ...
# singles_winner_player_id      ...
# doubles_winner_1_name         ...
# doubles_winner_1_url          ...
# doubles_winner_1_player_slug  ...
# doubles_winner_1_player_id    ...
# doubles_winner_2_name         ...
# doubles_winner_2_url          ...
# doubles_winner_2_player_slug  ...
# doubles_winner_2_player_id    ...
#
#                                                                            658  \
# tourney_year_id                                                       2019-329
# tourney_order                                                               59
# tourney_type                                                           ATP 500
# tourney_name                                                             Tokyo
# tourney_id                                                                 329
# tourney_slug                                                             tokyo
# tourney_location                                                  Tokyo, Japan
# tourney_date                                                        2019.09.30
# year                                                                      2019
# tourney_month                                                                9
# tourney_day                                                                 30
# tourney_singles_draw                                                        32
# tourney_doubles_draw                                                        16
# tourney_conditions                                                     Outdoor
# tourney_surface                                                           Hard
# tourney_fin_commit_raw                                              $2,046,340
# currency                                                                   USD
# tourney_fin_commit                                                   2046340.0
# tourney_url_suffix                   /en/scores/archive/tokyo/329/2019/results
# singles_winner_name                                             Novak Djokovic
# singles_winner_url                    /en/players/novak-djokovic/d643/overview
# singles_winner_player_slug                                      novak-djokovic
# singles_winner_player_id                                                  d643
# doubles_winner_1_name                                            Nicolas Mahut
# doubles_winner_1_url                   /en/players/nicolas-mahut/m873/overview
# doubles_winner_1_player_slug                                     nicolas-mahut
# doubles_winner_1_player_id                                                m873
# doubles_winner_2_name                                   Edouard Roger-Vasselin
# doubles_winner_2_url          /en/players/edouard-roger-vasselin/r613/overview
# doubles_winner_2_player_slug                            edouard-roger-vasselin
# doubles_winner_2_player_id                                                r613
#
#                                                                         659  \
# tourney_year_id                                                   2019-5014
# tourney_order                                                            60
# tourney_type                                                   Masters 1000
# tourney_name                                      ATP Masters 1000 Shanghai
# tourney_id                                                             5014
# tourney_slug                                                       shanghai
# tourney_location                                            Shanghai, China
# tourney_date                                                     2019.10.06
# year                                                                   2019
# tourney_month                                                            10
# tourney_day                                                               6
# tourney_singles_draw                                                     56
# tourney_doubles_draw                                                     32
# tourney_conditions                                                  Outdoor
# tourney_surface                                                        Hard
# tourney_fin_commit_raw                                           $8,322,885
# currency                                                                USD
# tourney_fin_commit                                                8322885.0
# tourney_url_suffix            /en/scores/archive/shanghai/5014/2019/results
# singles_winner_name                                         Daniil Medvedev
# singles_winner_url                /en/players/daniil-medvedev/mm58/overview
# singles_winner_player_slug                                  daniil-medvedev
# singles_winner_player_id                                               mm58
# doubles_winner_1_name                                            Mate Pavic
# doubles_winner_1_url                   /en/players/mate-pavic/pf00/overview
# doubles_winner_1_player_slug                                     mate-pavic
# doubles_winner_1_player_id                                             pf00
# doubles_winner_2_name                                          Bruno Soares
# doubles_winner_2_url                 /en/players/bruno-soares/s938/overview
# doubles_winner_2_player_slug                                   bruno-soares
# doubles_winner_2_player_id                                             s938
#
#                                                                       660  \
# tourney_year_id                                                  2019-438
# tourney_order                                                          61
# tourney_type                                                      ATP 250
# tourney_name                                                       Moscow
# tourney_id                                                            438
# tourney_slug                                                       moscow
# tourney_location                                           Moscow, Russia
# tourney_date                                                   2019.10.14
# year                                                                 2019
# tourney_month                                                          10
# tourney_day                                                            14
# tourney_singles_draw                                                   28
# tourney_doubles_draw                                                   16
# tourney_conditions                                                 Indoor
# tourney_surface                                                      Hard
# tourney_fin_commit_raw                                           $922,520
# currency                                                              USD
# tourney_fin_commit                                               922520.0
# tourney_url_suffix             /en/scores/archive/moscow/438/2019/results
# singles_winner_name                                         Andrey Rublev
# singles_winner_url                /en/players/andrey-rublev/re44/overview
# singles_winner_player_slug                                  andrey-rublev
# singles_winner_player_id                                             re44
# doubles_winner_1_name                                   Marcelo Demoliner
# doubles_winner_1_url          /en/players/marcelo-demoliner/d833/overview
# doubles_winner_1_player_slug                            marcelo-demoliner
# doubles_winner_1_player_id                                           d833
# doubles_winner_2_name                                    Matwe Middelkoop
# doubles_winner_2_url           /en/players/matwe-middelkoop/mb88/overview
# doubles_winner_2_player_slug                             matwe-middelkoop
# doubles_winner_2_player_id                                           mb88
#
#                                                                        661  \
# tourney_year_id                                                  2019-7485
# tourney_order                                                           62
# tourney_type                                                       ATP 250
# tourney_name                                                       Antwerp
# tourney_id                                                            7485
# tourney_slug                                                       antwerp
# tourney_location                                          Antwerp, Belgium
# tourney_date                                                    2019.10.14
# year                                                                  2019
# tourney_month                                                           10
# tourney_day                                                             14
# tourney_singles_draw                                                    28
# tourney_doubles_draw                                                    16
# tourney_conditions                                                  Indoor
# tourney_surface                                                       Hard
# tourney_fin_commit_raw                                            €711,275
# currency                                                               EUR
# tourney_fin_commit                                                711275.0
# tourney_url_suffix            /en/scores/archive/antwerp/7485/2019/results
# singles_winner_name                                            Andy Murray
# singles_winner_url                   /en/players/andy-murray/mc10/overview
# singles_winner_player_slug                                     andy-murray
# singles_winner_player_id                                              mc10
# doubles_winner_1_name                                       Kevin Krawietz
# doubles_winner_1_url              /en/players/kevin-krawietz/kb92/overview
# doubles_winner_1_player_slug                                kevin-krawietz
# doubles_winner_1_player_id                                            kb92
# doubles_winner_2_name                                         Andreas Mies
# doubles_winner_2_url                /en/players/andreas-mies/mj40/overview
# doubles_winner_2_player_slug                                  andreas-mies
# doubles_winner_2_player_id                                            mj40
#
#                                                                            662  \
# tourney_year_id                                                       2019-429
# tourney_order                                                               63
# tourney_type                                                           ATP 250
# tourney_name                                                         Stockholm
# tourney_id                                                                 429
# tourney_slug                                                         stockholm
# tourney_location                                             Stockholm, Sweden
# tourney_date                                                        2019.10.14
# year                                                                      2019
# tourney_month                                                               10
# tourney_day                                                                 14
# tourney_singles_draw                                                        28
# tourney_doubles_draw                                                        16
# tourney_conditions                                                      Indoor
# tourney_surface                                                           Hard
# tourney_fin_commit_raw                                                €711,275
# currency                                                                   EUR
# tourney_fin_commit                                                    711275.0
# tourney_url_suffix               /en/scores/archive/stockholm/429/2019/results
# singles_winner_name                                           Denis Shapovalov
# singles_winner_url                  /en/players/denis-shapovalov/su55/overview
# singles_winner_player_slug                                    denis-shapovalov
# singles_winner_player_id                                                  su55
# doubles_winner_1_name                                           Henri Kontinen
# doubles_winner_1_url                  /en/players/henri-kontinen/ka80/overview
# doubles_winner_1_player_slug                                    henri-kontinen
# doubles_winner_1_player_id                                                ka80
# doubles_winner_2_name                                   Edouard Roger-Vasselin
# doubles_winner_2_url          /en/players/edouard-roger-vasselin/r613/overview
# doubles_winner_2_player_slug                            edouard-roger-vasselin
# doubles_winner_2_player_id                                                r613
#
#                                                                      663  \
# tourney_year_id                                                 2019-337
# tourney_order                                                         64
# tourney_type                                                     ATP 500
# tourney_name                                                      Vienna
# tourney_id                                                           337
# tourney_slug                                                      vienna
# tourney_location                                         Vienna, Austria
# tourney_date                                                  2019.10.21
# year                                                                2019
# tourney_month                                                         10
# tourney_day                                                           21
# tourney_singles_draw                                                  32
# tourney_doubles_draw                                                  16
# tourney_conditions                                                Indoor
# tourney_surface                                                     Hard
# tourney_fin_commit_raw                                        €2,433,810
# currency                                                             EUR
# tourney_fin_commit                                             2433810.0
# tourney_url_suffix            /en/scores/archive/vienna/337/2019/results
# singles_winner_name                                        Dominic Thiem
# singles_winner_url               /en/players/dominic-thiem/tb69/overview
# singles_winner_player_slug                                 dominic-thiem
# singles_winner_player_id                                            tb69
# doubles_winner_1_name                                         Rajeev Ram
# doubles_winner_1_url                /en/players/rajeev-ram/r548/overview
# doubles_winner_1_player_slug                                  rajeev-ram
# doubles_winner_1_player_id                                          r548
# doubles_winner_2_name                                      Joe Salisbury
# doubles_winner_2_url             /en/players/joe-salisbury/so70/overview
# doubles_winner_2_player_slug                               joe-salisbury
# doubles_winner_2_player_id                                          so70
#
#                                                                       664  \
# tourney_year_id                                                  2019-328
# tourney_order                                                          65
# tourney_type                                                      ATP 500
# tourney_name                                                        Basel
# tourney_id                                                            328
# tourney_slug                                                        basel
# tourney_location                                       Basel, Switzerland
# tourney_date                                                   2019.10.21
# year                                                                 2019
# tourney_month                                                          10
# tourney_day                                                            21
# tourney_singles_draw                                                   32
# tourney_doubles_draw                                                   16
# tourney_conditions                                                 Indoor
# tourney_surface                                                      Hard
# tourney_fin_commit_raw                                         €2,219,975
# currency                                                              EUR
# tourney_fin_commit                                              2219975.0
# tourney_url_suffix              /en/scores/archive/basel/328/2019/results
# singles_winner_name                                         Roger Federer
# singles_winner_url                /en/players/roger-federer/f324/overview
# singles_winner_player_slug                                  roger-federer
# singles_winner_player_id                                             f324
# doubles_winner_1_name                                   Jean-Julien Rojer
# doubles_winner_1_url          /en/players/jean-julien-rojer/r513/overview
# doubles_winner_1_player_slug                            jean-julien-rojer
# doubles_winner_1_player_id                                           r513
# doubles_winner_2_name                                         Horia Tecau
# doubles_winner_2_url                /en/players/horia-tecau/t749/overview
# doubles_winner_2_player_slug                                  horia-tecau
# doubles_winner_2_player_id                                           t749
#
#                                                                           665  \
# tourney_year_id                                                      2019-352
# tourney_order                                                              66
# tourney_type                                                     Masters 1000
# tourney_name                                           ATP Masters 1000 Paris
# tourney_id                                                                352
# tourney_slug                                                            paris
# tourney_location                                                Paris, France
# tourney_date                                                       2019.10.28
# year                                                                     2019
# tourney_month                                                              10
# tourney_day                                                                28
# tourney_singles_draw                                                       48
# tourney_doubles_draw                                                       32
# tourney_conditions                                                     Indoor
# tourney_surface                                                          Hard
# tourney_fin_commit_raw                                             €5,791,280
# currency                                                                  EUR
# tourney_fin_commit                                                  5791280.0
# tourney_url_suffix                  /en/scores/archive/paris/352/2019/results
# singles_winner_name                                            Novak Djokovic
# singles_winner_url                   /en/players/novak-djokovic/d643/overview
# singles_winner_player_slug                                     novak-djokovic
# singles_winner_player_id                                                 d643
# doubles_winner_1_name                                   Pierre-Hugues Herbert
# doubles_winner_1_url          /en/players/pierre-hugues-herbert/h996/overview
# doubles_winner_1_player_slug                            pierre-hugues-herbert
# doubles_winner_1_player_id                                               h996
# doubles_winner_2_name                                           Nicolas Mahut
# doubles_winner_2_url                  /en/players/nicolas-mahut/m873/overview
# doubles_winner_2_player_slug                                    nicolas-mahut
# doubles_winner_2_player_id                                               m873
#
#                                                                             666  \
# tourney_year_id                                                       2019-7696
# tourney_order                                                                67
# tourney_type                                                    Next Gen Finals
# tourney_name                                                Next Gen ATP Finals
# tourney_id                                                                 7696
# tourney_slug                                                next-gen-atp-finals
# tourney_location                                                   Milan, Italy
# tourney_date                                                         2019.11.05
# year                                                                       2019
# tourney_month                                                                11
# tourney_day                                                                   5
# tourney_singles_draw                                                          8
# tourney_doubles_draw                                                          0
# tourney_conditions                                                       Indoor
# tourney_surface                                                            Hard
# tourney_fin_commit_raw                                               $1,400,000
# currency                                                                    USD
# tourney_fin_commit                                                    1400000.0
# tourney_url_suffix            /en/scores/archive/next-gen-atp-finals/7696/20...
# singles_winner_name                                               Jannik Sinner
# singles_winner_url                      /en/players/jannik-sinner/s0ag/overview
# singles_winner_player_slug                                        jannik-sinner
# singles_winner_player_id                                                   s0ag
# doubles_winner_1_name                                                       NaN
# doubles_winner_1_url                                                        NaN
# doubles_winner_1_player_slug                                                NaN
# doubles_winner_1_player_id                                                  NaN
# doubles_winner_2_name                                                       NaN
# doubles_winner_2_url                                                        NaN
# doubles_winner_2_player_slug                                                NaN
# doubles_winner_2_player_id                                                  NaN
#
#                                                                             667
# tourney_year_id                                                        2019-605
# tourney_order                                                                68
# tourney_type                                                         ATP Finals
# tourney_name                                                   Nitto ATP Finals
# tourney_id                                                                  605
# tourney_slug                                                   nitto-atp-finals
# tourney_location                                          London, Great Britain
# tourney_date                                                         2019.11.10
# year                                                                       2019
# tourney_month                                                                11
# tourney_day                                                                  10
# tourney_singles_draw                                                          8
# tourney_doubles_draw                                                          8
# tourney_conditions                                                       Indoor
# tourney_surface                                                            Hard
# tourney_fin_commit_raw                                               $9,000,000
# currency                                                                    USD
# tourney_fin_commit                                                    9000000.0
# tourney_url_suffix            /en/scores/archive/nitto-atp-finals/605/2019/r...
# singles_winner_name                                          Stefanos Tsitsipas
# singles_winner_url                 /en/players/stefanos-tsitsipas/te51/overview
# singles_winner_player_slug                                   stefanos-tsitsipas
# singles_winner_player_id                                                   te51
# doubles_winner_1_name                                     Pierre-Hugues Herbert
# doubles_winner_1_url            /en/players/pierre-hugues-herbert/h996/overview
# doubles_winner_1_player_slug                              pierre-hugues-herbert
# doubles_winner_1_player_id                                                 h996
# doubles_winner_2_name                                             Nicolas Mahut
# doubles_winner_2_url                    /en/players/nicolas-mahut/m873/overview
# doubles_winner_2_player_slug                                      nicolas-mahut
# doubles_winner_2_player_id                                                 m873
#
# [31 rows x 668 columns]

# %% [markdown]
# #### Variables:
#
# - `tourney_year_id`
# - `tourney_order`: in terms of the calendar.
# - `tourney_type`: *Grand Slam Tournaments* (the matches are played as best-of-five sets and offer 2000 points), *ATP Finals* (the matches are played as best-of-three sets and offer 1500 points), *ATP Masters 1000* (the matches are played as best-of-three sets and offer 1000 points), *ATP 500 Tournaments* (the matches are played as best-of-three sets and offer 500 points), or *ATP 250 Tournaments* (the matches are played as best-of-three sets and offer 250 points).
# - `tourney_name`
# - `tourney_id`
# - `tourney_slug`
# - `tourney_location`
# - `tourney_date`
# - `year`
# - `tourney_month`
# - `tourney_day`
# - `tourney_singles_draw`: number of players who will compete in the tournament's main singles draw.
# - `tourney_doubles_draw`: number of teams who will compete in the tournament's main doubles draw.
# - `tourney_conditions`: whether it is an indoor tournament or outdoor tournament.
# - `tourney_surface`: refers to the type of playing surface that the tournament is played on. There are 4 main types of surfaces: *hard courts* (made of asphalt or concrete and coated with acrylic material, and provide a relatively fast and predictable bounce), *clay courts* (made of crushed brick, shale, or stone, and provide a slower and higher bounce than hard courts; players must slide into their shots on clay courts, and the surface is known for producing long and physically demanding matches), *grass courts* (are the fastest surface and provide a low and skidding bounce; they require players to have good footwork and quick reflexes, as the ball tends to stay low, making it difficult for players to hit powerful shots), and *carpet courts* (are an indoor surface, and provide a relatively fast and low bounce; not very used).
# - `tourney_fin_commit_raw`: total amount of prize money that the tournament organizers commit to paying out to the players, including the prize money for both the singles and doubles events, as well as any fees or bonuses that the players may receive for participating in the tournament.
# - `currency`
# - `tourney_fin_commit`: the same as `tourney_fin_commit_raw`, but stored as a number in the dataset.
# - `tourney_url_suffix`
# - `singles_winner_name`
# - `singles_winner_url`
# - `singles_winner_player_slug`
# - `singles_winner_player_id`
# - `doubles_winner_1_name`
# - `doubles_winner_1_url`
# - `doubles_winner_1_player_slug`
# - `doubles_winner_1_player_id`
# - `doubles_winner_2_name`
# - `doubles_winner_2_url`
# - `doubles_winner_2_player_slug`
# - `doubles_winner_2_player_id`

# %%
# checking the shape of the dataset

tournaments.shape
# Out:
# (668, 31)

# %% [markdown]
# #### Data types:

# %%
# checking the types of the variables, as well as the number of non-null observations in each variable

tournaments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tourney_year_id               668 non-null    object
#  1   tourney_order                 668 non-null    int64
#  2   tourney_type                  663 non-null    object
#  3   tourney_name                  668 non-null    object
#  4   tourney_id                    668 non-null    int64
#  5   tourney_slug                  668 non-null    object
#  6   tourney_location              667 non-null    object
#  7   tourney_date                  668 non-null    object
#  8   year                          668 non-null    int64
#  9   tourney_month                 668 non-null    int64
#  10  tourney_day                   668 non-null    int64
#  11  tourney_singles_draw          668 non-null    int64
#  12  tourney_doubles_draw          668 non-null    int64
#  13  tourney_conditions            668 non-null    object
#  14  tourney_surface               668 non-null    object
#  15  tourney_fin_commit_raw        663 non-null    object
#  16  currency                      663 non-null    object
#  17  tourney_fin_commit            663 non-null    float64
#  18  tourney_url_suffix            668 non-null    object
#  19  singles_winner_name           664 non-null    object
#  20  singles_winner_url            664 non-null    object
#  21  singles_winner_player_slug    664 non-null    object
#  22  singles_winner_player_id      664 non-null    object
#  23  doubles_winner_1_name         661 non-null    object
#  24  doubles_winner_1_url          661 non-null    object
#  25  doubles_winner_1_player_slug  661 non-null    object
#  26  doubles_winner_1_player_id    661 non-null    object
#  27  doubles_winner_2_name         661 non-null    object
#  28  doubles_winner_2_url          661 non-null    object
#  29  doubles_winner_2_player_slug  661 non-null    object
#  30  doubles_winner_2_player_id    661 non-null    object
# dtypes: float64(1), int64(7), object(23)
# memory usage: 161.9+ KB

# %% [markdown]
# Some tournaments have the `tourney_location` and `tourney_type` missing, and some have the data regarding the Total Financial Commitment missing. The winners are also missing for some tournaments, maybe because the time range of this dataset includes the tournaments that were not played due to the Covid-19 pandemic.
#
# Regarding `tourney_date`, it is stored as a string, and should be store as a date.

# %%
# storing correctly the variable regarding dates

tournaments['tourney_date'] = pd.to_datetime(tournaments['tourney_date'], format = '%Y.%m.%d')

# %% [markdown]
# #### Descriptive statistics:

# %%
tournaments.describe().T
# Out:
#                       count          mean           std       min       25%  \
# tourney_order         668.0  3.391467e+01  1.932132e+01       1.0      17.0
# tourney_id            668.0  1.524737e+03  2.351811e+03      96.0     375.0
# year                  668.0  2.014542e+03  2.883502e+00    2010.0    2012.0
# tourney_month         668.0  5.715569e+00  3.126508e+00       1.0       2.0
# tourney_day           668.0  1.606287e+01  8.515033e+00       1.0       9.0
# tourney_singles_draw  668.0  4.075449e+01  2.638805e+01       8.0      28.0
# tourney_doubles_draw  668.0  2.020958e+01  1.185537e+01       0.0      16.0
# tourney_fin_commit    663.0  2.458502e+06  4.001018e+06  407250.0  520177.5
#
#                            50%        75%         max
# tourney_order             34.0       51.0        69.0
# tourney_id               451.0      742.5      9210.0
# year                    2015.0     2017.0      2019.0
# tourney_month              6.0        8.0        12.0
# tourney_day               16.0       23.0        31.0
# tourney_singles_draw      32.0       48.0       128.0
# tourney_doubles_draw      16.0       16.0        64.0
# tourney_fin_commit    727685.0  2341990.0  29687000.0

# %%
tournaments.describe(include = ['O']).T
# Out:
#                              count unique  \
# tourney_year_id                668    668
# tourney_type                   663      7
# tourney_name                   668     96
# tourney_slug                   668     96
# tourney_location               667    126
# tourney_conditions             668      2
# tourney_surface                668      3
# tourney_fin_commit_raw         663    413
# currency                       663      4
# tourney_url_suffix             668    668
# singles_winner_name            664    126
# singles_winner_url             664    126
# singles_winner_player_slug     664    126
# singles_winner_player_id       664    126
# doubles_winner_1_name          661    153
# doubles_winner_1_url           661    153
# doubles_winner_1_player_slug   661    153
# doubles_winner_1_player_id     661    153
# doubles_winner_2_name          661    144
# doubles_winner_2_url           661    144
# doubles_winner_2_player_slug   661    144
# doubles_winner_2_player_id     661    144
#
#                                                                        top  \
# tourney_year_id                                                   2010-339
# tourney_type                                                       ATP 250
# tourney_name                                                      Brisbane
# tourney_slug                                                        london
# tourney_location                                     London, Great Britain
# tourney_conditions                                                 Outdoor
# tourney_surface                                                       Hard
# tourney_fin_commit_raw                                            €450,000
# currency                                                               USD
# tourney_url_suffix            /en/scores/archive/brisbane/339/2010/results
# singles_winner_name                                         Novak Djokovic
# singles_winner_url                /en/players/novak-djokovic/d643/overview
# singles_winner_player_slug                                  novak-djokovic
# singles_winner_player_id                                              d643
# doubles_winner_1_name                                            Bob Bryan
# doubles_winner_1_url                   /en/players/bob-bryan/b588/overview
# doubles_winner_1_player_slug                                     bob-bryan
# doubles_winner_1_player_id                                            b588
# doubles_winner_2_name                                           Mike Bryan
# doubles_winner_2_url                  /en/players/mike-bryan/b589/overview
# doubles_winner_2_player_slug                                    mike-bryan
# doubles_winner_2_player_id                                            b589
#
#                              freq
# tourney_year_id                 1
# tourney_type                  397
# tourney_name                   10
# tourney_slug                   11
# tourney_location               30
# tourney_conditions            502
# tourney_surface               378
# tourney_fin_commit_raw         32
# currency                      325
# tourney_url_suffix              1
# singles_winner_name            61
# singles_winner_url             61
# singles_winner_player_slug     61
# singles_winner_player_id       61
# doubles_winner_1_name          63
# doubles_winner_1_url           63
# doubles_winner_1_player_slug   63
# doubles_winner_1_player_id     63
# doubles_winner_2_name          63
# doubles_winner_2_url           63
# doubles_winner_2_player_slug   63
# doubles_winner_2_player_id     63

# %% [markdown]
# From this descriptive statistics, it can be seen that the mean of players in the singles tournaments is 40 for and the mean of teams in the doubles tournaments is 20. As for the Total Financial Commitment, it is, on average, 2 milion, however this must be standardized, since the values are represented in different currencies. The majority of the tournaments are in outdoor conditions, and played in hard courts. The most successful singles player in the male Tennis circuit is Novak Djokovic during this period of time.

# %% [markdown]
# #### Do not make sense for our analysis:

# %%
tournaments['tourney_type'].value_counts()
# Out:
# ATP 250            397
# ATP 500            120
# Masters 1000        90
# Grand Slam          40
# ATP Finals          10
# Laver Cup            3
# Next Gen Finals      3
# Name: tourney_type, dtype: int64

# %% [markdown]
# The Laver Cup is a competition that features a team format between Europe and the rest of the world. Since the Laver Cup is not a part of the ATP Tour, it does not award ranking points to players, therefore it will not be considered for this analysis.
#
# Also, the ATP Cup is a men's professional tennis tournament that features national teams from different countries competing against each other. It is a team competition, with players representing their countries, and altough it awards ranking points, also it will not be considered since it is a teams competition.

# %%
# dropping the tournaments that fall into the category found before

tournaments = tournaments[tournaments['tourney_type'] != 'Laver Cup']
tournaments = tournaments[tournaments['tourney_type'] != 'ATP Cup']

# %% [markdown]
# Also, we have some other variables that do not make a lot of sense to mantain, for example `tourney_fin_commit_raw`, since this is a variable that do not add new information (as we have the same information but properly encoded in `tourney_fin_commit` and `currency`). As for the websites provided in the dataset (in variables `tourney_url_suffix`, `singles_winner_url`, `doubles_winner_1_url`, `doubles_winner_2_url`), they are irrelevant for our analysis, therefore will be deleted.

# %%
# droping the variables as explained above

tournaments.drop(columns = ['tourney_fin_commit_raw', 'tourney_url_suffix', 'singles_winner_url', 'doubles_winner_1_url', 'doubles_winner_2_url'], inplace = True)

# %% [markdown]
# As we already have the dates stored of the tournaments stored in a variable (properly encoded), it does not make sense to have two additional variables with month, and day. Therefore, these variables (`tourney_month`, `tourney_day`) should be deleted.

# %%
# droping the variables as explained above

tournaments.drop(columns = ['tourney_month', 'tourney_day'], inplace = True)

# %% [markdown]
# #### Missing values:

# %%
# creating a copy to solve the problems with missing values

tournaments_missing = tournaments.copy()

# %%
# replacing other types of missing values not recognized by pandas with NaN and checking again the number of missing values

missing_values = ['n/a', 'na', '--', '', 'unknown', 'Unknown']

tournaments_missing.replace(missing_values, np.nan, inplace = True)
tournaments_missing.isna().sum()
# Out:
# tourney_year_id                 0
# tourney_order                   0
# tourney_type                    5
# tourney_name                    0
# tourney_id                      0
# tourney_slug                    0
# tourney_location                1
# tourney_date                    0
# year                            0
# tourney_singles_draw            0
# tourney_doubles_draw            0
# tourney_conditions              0
# tourney_surface                 0
# currency                        2
# tourney_fin_commit              2
# singles_winner_name             1
# singles_winner_player_slug      1
# singles_winner_player_id        1
# doubles_winner_1_name           4
# doubles_winner_1_player_slug    4
# doubles_winner_1_player_id      4
# doubles_winner_2_name           4
# doubles_winner_2_player_slug    4
# doubles_winner_2_player_id      4
# dtype: int64

# %%
# seeing rows with NaNs

tournaments_nans_index = tournaments_missing.isna().any(axis = 1)
tournaments_missing[tournaments_nans_index].T
# Out:
#                                                   29                   65   \
# tourney_year_id                              2010-615             2010-605
# tourney_order                                      30                   66
# tourney_type                                      NaN           ATP Finals
# tourney_name                  World Team Championship           ATP Finals
# tourney_id                                        615                  605
# tourney_slug                               dusseldorf           atp-finals
# tourney_location                           Dusseldorf                  NaN
# tourney_date                      2010-05-16 00:00:00  2010-11-21 00:00:00
# year                                             2010                 2010
# tourney_singles_draw                               32                    8
# tourney_doubles_draw                               16                    8
# tourney_conditions                            Outdoor               Indoor
# tourney_surface                                  Clay                 Hard
# currency                                          EUR                  USD
# tourney_fin_commit                          1350000.0            5070000.0
# singles_winner_name                       Juan Monaco        Roger Federer
# singles_winner_player_slug                juan-monaco        roger-federer
# singles_winner_player_id                         ma21                 f324
# doubles_winner_1_name                       Bob Bryan        Daniel Nestor
# doubles_winner_1_player_slug                bob-bryan        daniel-nestor
# doubles_winner_1_player_id                       b588                 n210
# doubles_winner_2_name                      Mike Bryan       Nenad Zimonjic
# doubles_winner_2_player_slug               mike-bryan       nenad-zimonjic
# doubles_winner_2_player_id                       b589                 z072
#
#                                                   95   \
# tourney_year_id                              2011-615
# tourney_order                                      30
# tourney_type                                      NaN
# tourney_name                  World Team Championship
# tourney_id                                        615
# tourney_slug                               dusseldorf
# tourney_location                  Dusseldorf, Germany
# tourney_date                      2011-05-15 00:00:00
# year                                             2011
# tourney_singles_draw                               32
# tourney_doubles_draw                               16
# tourney_conditions                            Outdoor
# tourney_surface                                  Clay
# currency                                          EUR
# tourney_fin_commit                          1100000.0
# singles_winner_name                Juan Ignacio Chela
# singles_winner_player_slug         juan-ignacio-chela
# singles_winner_player_id                         c514
# doubles_winner_1_name           Philipp Kohlschreiber
# doubles_winner_1_player_slug    philipp-kohlschreiber
# doubles_winner_1_player_id                       k435
# doubles_winner_2_name              Philipp Petzschner
# doubles_winner_2_player_slug       philipp-petzschner
# doubles_winner_2_player_id                       p624
#
#                                                   162                    179  \
# tourney_year_id                              2012-615                2012-96
# tourney_order                                      31                     48
# tourney_type                                      NaN                    NaN
# tourney_name                  World Team Championship        London Olympics
# tourney_id                                        615                     96
# tourney_slug                               dusseldorf                 london
# tourney_location                  Dusseldorf, Germany  London, Great Britain
# tourney_date                      2012-05-20 00:00:00    2012-07-25 00:00:00
# year                                             2012                   2012
# tourney_singles_draw                               32                     64
# tourney_doubles_draw                               16                     32
# tourney_conditions                            Outdoor                Outdoor
# tourney_surface                                  Clay                  Grass
# currency                                          EUR                    NaN
# tourney_fin_commit                          1300000.0                    NaN
# singles_winner_name                               NaN            Andy Murray
# singles_winner_player_slug                        NaN            andy-murray
# singles_winner_player_id                          NaN                   mc10
# doubles_winner_1_name                             NaN              Bob Bryan
# doubles_winner_1_player_slug                      NaN              bob-bryan
# doubles_winner_1_player_id                        NaN                   b588
# doubles_winner_2_name                             NaN             Mike Bryan
# doubles_winner_2_player_slug                      NaN             mike-bryan
# doubles_winner_2_player_id                        NaN                   b589
#
#                                                        443  \
# tourney_year_id                                    2016-96
# tourney_order                                           49
# tourney_type                                           NaN
# tourney_name                  Rio de Janeiro Olympic Games
# tourney_id                                              96
# tourney_slug                                rio-de-janeiro
# tourney_location                    Rio de Janeiro, Brazil
# tourney_date                           2016-08-04 00:00:00
# year                                                  2016
# tourney_singles_draw                                    64
# tourney_doubles_draw                                    32
# tourney_conditions                                 Outdoor
# tourney_surface                                       Hard
# currency                                               NaN
# tourney_fin_commit                                     NaN
# singles_winner_name                            Andy Murray
# singles_winner_player_slug                     andy-murray
# singles_winner_player_id                              mc10
# doubles_winner_1_name                           Marc Lopez
# doubles_winner_1_player_slug                    marc-lopez
# doubles_winner_1_player_id                            l480
# doubles_winner_2_name                         Rafael Nadal
# doubles_winner_2_player_slug                  rafael-nadal
# doubles_winner_2_player_id                            n409
#
#                                               529                  598  \
# tourney_year_id                         2017-7696            2018-7696
# tourney_order                                  68                   68
# tourney_type                      Next Gen Finals      Next Gen Finals
# tourney_name                  Next Gen ATP Finals  Next Gen ATP Finals
# tourney_id                                   7696                 7696
# tourney_slug                  next-gen-atp-finals  next-gen-atp-finals
# tourney_location                     Milan, Italy         Milan, Italy
# tourney_date                  2017-11-07 00:00:00  2018-11-06 00:00:00
# year                                         2017                 2018
# tourney_singles_draw                            8                    8
# tourney_doubles_draw                            0                    0
# tourney_conditions                         Indoor               Indoor
# tourney_surface                              Hard                 Hard
# currency                                      USD                  USD
# tourney_fin_commit                      1275000.0            1335000.0
# singles_winner_name                   Hyeon Chung   Stefanos Tsitsipas
# singles_winner_player_slug            hyeon-chung   stefanos-tsitsipas
# singles_winner_player_id                     ch27                 te51
# doubles_winner_1_name                         NaN                  NaN
# doubles_winner_1_player_slug                  NaN                  NaN
# doubles_winner_1_player_id                    NaN                  NaN
# doubles_winner_2_name                         NaN                  NaN
# doubles_winner_2_player_slug                  NaN                  NaN
# doubles_winner_2_player_id                    NaN                  NaN
#
#                                               666
# tourney_year_id                         2019-7696
# tourney_order                                  67
# tourney_type                      Next Gen Finals
# tourney_name                  Next Gen ATP Finals
# tourney_id                                   7696
# tourney_slug                  next-gen-atp-finals
# tourney_location                     Milan, Italy
# tourney_date                  2019-11-05 00:00:00
# year                                         2019
# tourney_singles_draw                            8
# tourney_doubles_draw                            0
# tourney_conditions                         Indoor
# tourney_surface                              Hard
# currency                                      USD
# tourney_fin_commit                      1400000.0
# singles_winner_name                 Jannik Sinner
# singles_winner_player_slug          jannik-sinner
# singles_winner_player_id                     s0ag
# doubles_winner_1_name                         NaN
# doubles_winner_1_player_slug                  NaN
# doubles_winner_1_player_id                    NaN
# doubles_winner_2_name                         NaN
# doubles_winner_2_player_slug                  NaN
# doubles_winner_2_player_id                    NaN

# %%
# seeing missing values in the type variable

tournaments_missing[tournaments_missing['tourney_type'].isna()]
# Out:
#     tourney_year_id  tourney_order tourney_type                  tourney_name  \
# 29         2010-615             30          NaN       World Team Championship
# 95         2011-615             30          NaN       World Team Championship
# 162        2012-615             31          NaN       World Team Championship
# 179         2012-96             48          NaN               London Olympics
# 443         2016-96             49          NaN  Rio de Janeiro Olympic Games
#
#      tourney_id    tourney_slug        tourney_location tourney_date  year  \
# 29          615      dusseldorf              Dusseldorf   2010-05-16  2010
# 95          615      dusseldorf     Dusseldorf, Germany   2011-05-15  2011
# 162         615      dusseldorf     Dusseldorf, Germany   2012-05-20  2012
# 179          96          london   London, Great Britain   2012-07-25  2012
# 443          96  rio-de-janeiro  Rio de Janeiro, Brazil   2016-08-04  2016
#
#      tourney_singles_draw  ...  tourney_fin_commit singles_winner_name  \
# 29                     32  ...           1350000.0         Juan Monaco
# 95                     32  ...           1100000.0  Juan Ignacio Chela
# 162                    32  ...           1300000.0                 NaN
# 179                    64  ...                 NaN         Andy Murray
# 443                    64  ...                 NaN         Andy Murray
#
#     singles_winner_player_slug singles_winner_player_id  \
# 29                 juan-monaco                     ma21
# 95          juan-ignacio-chela                     c514
# 162                        NaN                      NaN
# 179                andy-murray                     mc10
# 443                andy-murray                     mc10
#
#      doubles_winner_1_name doubles_winner_1_player_slug  \
# 29               Bob Bryan                    bob-bryan
# 95   Philipp Kohlschreiber        philipp-kohlschreiber
# 162                    NaN                          NaN
# 179              Bob Bryan                    bob-bryan
# 443             Marc Lopez                   marc-lopez
#
#     doubles_winner_1_player_id doubles_winner_2_name  \
# 29                        b588            Mike Bryan
# 95                        k435    Philipp Petzschner
# 162                        NaN                   NaN
# 179                       b588            Mike Bryan
# 443                       l480          Rafael Nadal
#
#     doubles_winner_2_player_slug doubles_winner_2_player_id
# 29                    mike-bryan                       b589
# 95            philipp-petzschner                       p624
# 162                          NaN                        NaN
# 179                   mike-bryan                       b589
# 443                 rafael-nadal                       n409
#
# [5 rows x 24 columns]

# %% [markdown]
# Since we are not considering for the analysis the competitions that do not award points or are teams competitions, we will delete the Olympics and the World Team Championship.

# %%
# deleting the observations as explained before

tournaments_missing.dropna(subset = ['tourney_type'], inplace = True)

# %%
# seeing missing values in the location variable

tournaments_missing[tournaments_missing['tourney_location'].isna()]
# Out:
#    tourney_year_id  tourney_order tourney_type tourney_name  tourney_id  \
# 65        2010-605             66   ATP Finals   ATP Finals         605
#
#    tourney_slug tourney_location tourney_date  year  tourney_singles_draw  \
# 65   atp-finals              NaN   2010-11-21  2010                     8
#
#     ...  tourney_fin_commit singles_winner_name singles_winner_player_slug  \
# 65  ...           5070000.0       Roger Federer              roger-federer
#
#    singles_winner_player_id  doubles_winner_1_name  \
# 65                     f324          Daniel Nestor
#
#    doubles_winner_1_player_slug doubles_winner_1_player_id  \
# 65                daniel-nestor                       n210
#
#    doubles_winner_2_name doubles_winner_2_player_slug  \
# 65        Nenad Zimonjic               nenad-zimonjic
#
#    doubles_winner_2_player_id
# 65                       z072
#
# [1 rows x 24 columns]

# %% [markdown]
# As it can be seen, the tournament that misses the location is "2010 ATP World Tour Finals". So, after a quick search (https://www.bbc.co.uk/programmes/b00wkcqm) we found that they were hosted in London, Great Britain.

# %%
# inputting the missing value

tournaments_missing.loc[65, 'tourney_location'] = 'London, Great Britain'

# %%
# seeing missing values in the doubles winner variable

tournaments_missing[tournaments_missing['doubles_winner_1_name'].isna()]
# Out:
#     tourney_year_id  tourney_order     tourney_type         tourney_name  \
# 529       2017-7696             68  Next Gen Finals  Next Gen ATP Finals
# 598       2018-7696             68  Next Gen Finals  Next Gen ATP Finals
# 666       2019-7696             67  Next Gen Finals  Next Gen ATP Finals
#
#      tourney_id         tourney_slug tourney_location tourney_date  year  \
# 529        7696  next-gen-atp-finals     Milan, Italy   2017-11-07  2017
# 598        7696  next-gen-atp-finals     Milan, Italy   2018-11-06  2018
# 666        7696  next-gen-atp-finals     Milan, Italy   2019-11-05  2019
#
#      tourney_singles_draw  ...  tourney_fin_commit singles_winner_name  \
# 529                     8  ...           1275000.0         Hyeon Chung
# 598                     8  ...           1335000.0  Stefanos Tsitsipas
# 666                     8  ...           1400000.0       Jannik Sinner
#
#     singles_winner_player_slug singles_winner_player_id  \
# 529                hyeon-chung                     ch27
# 598         stefanos-tsitsipas                     te51
# 666              jannik-sinner                     s0ag
#
#      doubles_winner_1_name doubles_winner_1_player_slug  \
# 529                    NaN                          NaN
# 598                    NaN                          NaN
# 666                    NaN                          NaN
#
#     doubles_winner_1_player_id doubles_winner_2_name  \
# 529                        NaN                   NaN
# 598                        NaN                   NaN
# 666                        NaN                   NaN
#
#     doubles_winner_2_player_slug doubles_winner_2_player_id
# 529                          NaN                        NaN
# 598                          NaN                        NaN
# 666                          NaN                        NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# The Next Gen ATP Finals is a men's professional tennis tournament that features only a singles competition. The tournament is specifically designed to showcase the top young male players aged 21 and under, based on their ATP rankings. The format of the tournament is also unique, with shorter sets, no lets, no advantage scoring, and a shot clock to speed up the pace of play. So, these missing values are not an error, so, we can inpute them.

# %%
# inputting the missing values

tournaments_missing.loc[tournaments_missing['doubles_winner_1_name'].isna(), ['doubles_winner_1_name', 'doubles_winner_1_player_slug', 'doubles_winner_1_player_id', 'doubles_winner_2_name', 'doubles_winner_2_player_slug', 'doubles_winner_2_player_id']] = 'There is no doubles competition'

# %%
# checking that there are no more missing values

tournaments_missing.isna().sum()
# Out:
# tourney_year_id                 0
# tourney_order                   0
# tourney_type                    0
# tourney_name                    0
# tourney_id                      0
# tourney_slug                    0
# tourney_location                0
# tourney_date                    0
# year                            0
# tourney_singles_draw            0
# tourney_doubles_draw            0
# tourney_conditions              0
# tourney_surface                 0
# currency                        0
# tourney_fin_commit              0
# singles_winner_name             0
# singles_winner_player_slug      0
# singles_winner_player_id        0
# doubles_winner_1_name           0
# doubles_winner_1_player_slug    0
# doubles_winner_1_player_id      0
# doubles_winner_2_name           0
# doubles_winner_2_player_slug    0
# doubles_winner_2_player_id      0
# dtype: int64

# %%
# keeping the dataframe without missing values

tournaments = tournaments_missing.copy()

# %% [markdown]
# #### Solving the currency problem:

# %%
# checking the different currencies present in the dataset

tournaments['currency'].value_counts()
# Out:
# USD    325
# EUR    315
# AUD     10
# GBP     10
# Name: currency, dtype: int64

# %%
# defining a dataframe with the exchange rate for US Dollars at 12/03/2023, 09:52 UTC
# https://www.google.com/finance/quote/AUD-USD
# https://www.google.com/finance/quote/EUR-USD
# https://www.google.com/finance/quote/GBP-USD
# all prizes will be converted to USD
exchange_rate = pd.DataFrame(data = {'exchange_rate': [1, 1.0646, 0.6583, 1.2034], 'currency': ['USD', 'EUR', 'AUD', 'GBP']})

# merging the tournaments dataframe with the exchange rate dataframe
merged_tournaments = tournaments.merge(exchange_rate, on = 'currency')

# creating a new column in the merged dataframe with the TFC in US dollars, by multiplying the value with the exchange rate
merged_tournaments['tourney_fin_commit_USD'] = merged_tournaments['tourney_fin_commit'] * merged_tournaments['exchange_rate']

# drop the currency and exchange rate columns, as they are no longer needed
merged_tournaments.drop(['currency', 'exchange_rate', 'tourney_fin_commit'], axis = 1, inplace = True)

# sorting by ascending order regarding variable date
merged_tournaments.sort_index(inplace = True)

# %%
# keeping the changes for the currencies in the original dataset

tournaments = merged_tournaments.copy()

# %% [markdown]
# Also, since we will be working with the geographic location of the tournaments, it is also interesting to know to which geographical region each tournament belongs. Therefore, we will add a column to the dataset with the Region (either, Oceanina, Asia, Europe, North America, south america, or Africa).

# %%
regions_code = {
    'Brisbane': 'oceania',
    'Doha': 'asia',
    'Chennai': 'asia',
    'Sydney': 'oceania',
    'Auckland': 'oceania',
    'Johannesburg': 'africa',
    'Santiago': 'south america',
    'San Jose': 'north america',
    'Costa do Sauipe': 'south america',
    'Memphis': 'north america',
    'Buenos Aires': 'south america',
    'Dubai, United Arab Emirates': 'asia',
    'Acapulco, Mexico': 'north america',
    'Delray Beach': 'north america',
    'Indian Wells': 'north america',
    'Miami': 'north america',
    'Houston, United States': 'north america',
    'Newport, United States': 'north america',
    'Atlanta, United States': 'north america',
    'Los Angeles, United States': 'north america',
    'Washington, United States': 'north america',
    'Toronto, Canada': 'north america',
    'Cincinnati, United States': 'north america',
    'New Haven': 'north america',
    'New York': 'north america',
    'Kuala Lumpur': 'asia',
    'Bangkok': 'asia',
    'Beijing, China': 'asia',
    'Tokyo': 'asia',
    'Shanghai, China': 'asia',
    'Moscow, Russia': 'europe',
    'St. Petersburg, Russia': 'europe',
    'London, Great Britain': 'europe',
    'Brisbane, Australia': 'oceania',
    'Doha, Qatar': 'asia',
    'Chennai, India': 'asia',
    'Sydney, Australia': 'oceania',
    'Auckland, New Zealand': 'oceania',
    'Johannesburg, South Africa': 'africa',
    'Santiago, Chile': 'south america',
    'San Jose, United States': 'north america',
    'Costa do Sauipe, Brazil': 'south america',
    'Memphis, United States': 'north america',
    'Buenos Aires, Argentina': 'south america',
    'Delray Beach, United States': 'north america',
    'Indian Wells, United States': 'north america',
    'Miami, United States': 'north america',
    'Montreal, Canada': 'north america',
    'Winston-Salem, United States': 'north america',
    'New York, United States': 'north america',
    'Kuala Lumpur, Malaysia': 'asia',
    'Bangkok, Thailand': 'asia',
    'Tokyo, Japan': 'asia',
    'Vina del Mar, Chile': 'south america',
    'Sao Paulo, Brazil': 'south america',
    'Bogota, Colombia': 'south america',
    'Rio de Janeiro, Brazil': 'south america',
    'New York City, United States': 'north america',
    'Shenzhen, China': 'asia',
    'Quito, Ecuador': 'south america',
    'Los Cabos, Mexico': 'north america',
    'Chengdu, China': 'asia',
    'Milan, Italy': 'europe',
    'Pune, India': 'asia',
    'Cordoba, Argentina': 'south america',
    'Zhuhai, China': 'asia',
    'Melbourne': 'oceania',
    'Melbourne, Australia': 'oceania',
    'Africagreb': 'europe',
    'Rotterdam': 'europe',
    'Marseille, France': 'europe',
    'Casablanca': 'africa',
    'Monte Carlo': 'Europa',
    'Barcelona': 'europe',
    'Rome': 'europe',
    'Munich': 'europe',
    'Estoril': 'europe',
    'Belgrade': 'europe',
    'Madrid': 'europe',
    'Nice': 'europe',
    'Paris': 'europe',
    'Halle': 'europe',
    'Eastbourne': 'europe',
    's-Hertogenbosch': 'europe',
    'Bastad': 'europe',
    'Stuttgart': 'europe',
    'Hamburg': 'europe',
    'Gstaad': 'europe',
    'Umag': 'europe',
    'Metz': 'europe',
    'Bucharest': 'europe',
    'Stockholm': 'europe',
    'Montpellier': 'europe',
    'Vienna': 'europe',
    'Valencia': 'europe',
    'Basel': 'europe',
    'Zagreb': 'europe',
    'Rotterdam': 'europe',
    'Casablanca': 'africa',
    'Monte Carlo': 'europe',
    'Barcelona': 'europe',
    'Estoril': 'europe',
    'Belgrade': 'europe',
    'Rome': 'europe',
    'Kitzbuhel': 'europe',
    'Metz': 'europe',
    'Bucharest': 'europe',
    'Stockholm': 'europe',
    'Valencia': 'europe',
    'Bastad': 'europe',
    'Kitzbuhel': 'europe',
    'Monte-Carlo': 'europe',
    'Oeiras': 'europe',
    'Dusseldorf': 'europe',
    'Istanbul': 'asia',
    'Geneva': 'europe',
    'Nottingham': 'europe',
    'Sofia': 'europe',
    'Marrakech': 'africa',
    'Antwerp': 'europe',
    'Budapest': 'europe',
    'Lyon': 'europe',
    'Antalya': 'asia',
    'Munich, Germany' : 'europe',
    'Madrid, Spain' : 'europe',
    'Nice, France' : 'europe',
    'Paris, France' : 'europe',
    'Halle, Germany' : 'europe',
    'Eastbourne, Great Britain' : 'europe',
    's-Hertogenbosch, Netherlands' : 'europe',
    'Bastad, Sweden' : 'europe',
    'Stuttgart, Germany' : 'europe',
    'Hamburg, Germany' : 'europe',
    'Gstaad, Switzerland' : 'europe',
    'Umag, Croatia' : 'europe',
    'Montpellier, France' : 'europe',
    'Vienna, Austria' : 'europe',
    'Valencia, Switzerland' : 'europe',
    'Basel, Switzerland' : 'europe',
    'Zagreb, Croatia' : 'europe',
    'Rotterdam, Netherlands' : 'europe',
    'Casablanca, Morocco' : 'africa',
    'Monte Carlo, Monaco' : 'europe',
    'Barcelona, Spain' : 'europe',
    'Estoril, Portugal' : 'europe',
    'Belgrade, Serbia' : 'europe',
    'Rome, Italy' : 'europe',
    'Kitzbhel, Austria' : 'europe',
    'Metz, France' : 'europe',
    'Bucharest, Romania' : 'europe',
    'Stockholm, Sweden' : 'europe',
    'Valencia, Spain' : 'europe',
    'B†stad, Sweden' : 'europe',
    'Kitzbuhel, Austria' : 'europe',
    'Monte-Carlo, Monaco' : 'europe',
    'Oeiras, Portugal' : 'europe',
    'Dusseldorf, Germany' : 'europe',
    'Istanbul, Turkey': 'europe',
    'Geneva, Switzerland': 'europe',
    'Nottingham, Great Britain': 'europe',
    'Sofia, Bulgaria': 'europe',
    'Marrakech, Morocco': 'africa',
    'Antwerp, Belgium': 'europe',
    'Budapest, Hungary': 'europe',
    'Lyon, France': 'europe',
    'Antalya, Turkey': 'europe'
}

# creating a new column called 'tourney_region'
tournaments['tourney_region'] = ''

# loop over the rows of the tournaments dataframe and map the country names to Continents
for i, row in tournaments.iterrows():
    region_name = row['tourney_location']
    if region_name in regions_code:
        continent_code = regions_code[region_name]
    else:
        continent_code = 'unknown'  # set the continent as 'unknown' if not found in the dictionary
    tournaments.loc[i, 'tourney_region'] = continent_code

# %% [markdown]
# The same happens for the country and city. From the `tourney_location` variable, the city of the tournament will be extracted, and also a column with the country code will be added, because it will be needed for the map visualizations in the dashboard.

# %%
# using split method to keep the city name (that is located before the comma) 

tournaments['tourney_city'] = tournaments['tourney_location'].str.split(',').str[0]

# %%
# creating a dictionary mapping city names to country codes
country_codes = {
    'Brisbane': 'AU',
    'Doha': 'QA',
    'Chennai': 'IN',
    'Sydney': 'AU',
    'Auckland': 'NZ',
    'Johannesburg': 'ZA',
    'Santiago': 'CL',
    'San Jose': 'CR',
    'Costa do Sauipe': 'BR',
    'Memphis': 'US',
    'Buenos Aires': 'AR',
    'Dubai, United Arab Emirates': 'AE',
    'Acapulco, Mexico': 'MX',
    'Delray Beach': 'US',
    'Indian Wells': 'US',
    'Miami': 'US',
    'Houston, United States': 'US',
    'Newport, United States': 'US',
    'Atlanta, United States': 'US',
    'Los Angeles, United States': 'US',
    'Washington, United States': 'US',
    'Toronto, Canada': 'CA',
    'Cincinnati, United States': 'US',
    'New Haven': 'US',
    'New York': 'US',
    'Kuala Lumpur': 'MY',
    'Bangkok': 'TH',
    'Beijing, China': 'CN',
    'Tokyo': 'JP',
    'Shanghai, China': 'CN',
    'Moscow, Russia': 'RU',
    'St. Petersburg, Russia': 'RU',
    'London, Great Britain': 'GB',
    'Brisbane, Australia': 'AU',
    'Doha, Qatar': 'QA',
    'Chennai, India': 'IN',
    'Sydney, Australia': 'AU',
    'Auckland, New Zealand': 'NZ',
    'Johannesburg, South Africa': 'ZA',
    'Santiago, Chile': 'CL',
    'San Jose, United States': 'CR',
    'Costa do Sauipe, Brazil': 'BR',
    'Memphis, United States': 'US',
    'Buenos Aires, Argentina': 'AR',
    'Delray Beach, United States': 'US',
    'Indian Wells, United States': 'US',
    'Miami, United States': 'US',
    'Montreal, Canada': 'CA',
    'Winston-Salem, United States': 'US',
    'New York, United States': 'US',
    'Kuala Lumpur, Malaysia': 'MY',
    'Bangkok, Thailand': 'TH',
    'Tokyo, Japan': 'JP',
    'Vina del Mar, Chile': 'CL',
    'Sao Paulo, Brazil': 'BR',
    'Bogota, Colombia': 'CO',
    'Rio de Janeiro, Brazil': 'BR',
    'New York City, United States': 'US',
    'Shenzhen, China': 'CN',
    'Quito, Ecuador': 'EC',
    'Los Cabos, Mexico': 'MX',
    'Chengdu, China': 'CN',
    'Milan, Italy': 'IT',
    'Pune, India': 'IN',
    'Cordoba, Argentina': 'AR',
    'Zhuhai, China': 'CN',
    'Melbourne': 'AU',
    'Melbourne, Australia': 'AU',
    'Zagreb': 'HR',
    'Rotterdam': 'NL',
    'Marseille, France': 'FR',
    'Casablanca': 'MA',
    'Monte Carlo': 'MC',
    'Barcelona': 'ES',
    'Rome': 'IT',
    'Munich': 'DE',
    'Estoril': 'PT',
    'Belgrade': 'RS',
    'Madrid': 'ES',
    'Nice': 'FR',
    'Paris': 'FR',
    'Halle': 'DE',
    'Eastbourne': 'GB',
    's-Hertogenbosch': 'NL',
    'Bastad': 'SE',
    'Stuttgart': 'DE',
    'Hamburg': 'DE',
    'Gstaad': 'CH',
    'Umag': 'HR',
    'Metz': 'FR',
    'Bucharest': 'RO',
    'Stockholm': 'SE',
    'Montpellier': 'FR',
    'Vienna': 'AT',
    'Valencia': 'ES',
    'Basel': 'CH',
    'Zagreb': 'HR',
    'Rotterdam': 'NL',
    'Casablanca': 'MA',
    'Monte Carlo': 'MC',
    'Barcelona': 'ES',
    'Estoril': 'PT',
    'Belgrade': 'RS',
    'Rome': 'IT',
    'Kitzbuhel': 'AT',
    'Metz': 'FR',
    'Bucharest': 'RO',
    'Stockholm': 'SE',
    'Valencia': 'ES',
    'Bastad': 'SE',
    'Kitzbuhel': 'AT',
    'Monte-Carlo': 'MC',
    'Oeiras': 'PT',
    'Dusseldorf': 'DE',
    'Istanbul': 'TR',
    'Geneva': 'CH',
    'Nottingham': 'GB',
    'Sofia': 'BG',
    'Marrakech': 'MA',
    'Antwerp': 'BE',
    'Budapest': 'HU',
    'Lyon': 'FR',
    'Antalya': 'TR',
    'Munich, Germany' : 'DE',
    'Madrid, Spain' : 'ES',
    'Nice, France' : 'FR',
    'Paris, France' : 'FR',
    'Halle, Germany' : 'DE',
    'Eastbourne, Great Britain' : 'GB',
    's-Hertogenbosch, Netherlands' : 'NL',
    'Bastad, Sweden' : 'SE',
    'Stuttgart, Germany' : 'DE',
    'Hamburg, Germany' : 'DE',
    'Gstaad, Switzerland' : 'CH',
    'Umag, Croatia' : 'HR',
    'Montpellier, France' : 'FR',
    'Vienna, Austria' : 'AT',
    'Valencia, Switzerland' : 'ES',
    'Basel, Switzerland' : 'CH',
    'Zagreb, Croatia' : 'HR',
    'Rotterdam, Netherlands' : 'NL',
    'Casablanca, Morocco' : 'MA',
    'Monte Carlo, Monaco' : 'MC',
    'Barcelona, Spain' : 'ES',
    'Estoril, Portugal' : 'PT',
    'Belgrade, Serbia' : 'RS',
    'Rome, Italy' : 'IT',
    'Kitzbhel, Austria' : 'AT',
    'Metz, France' : 'FR',
    'Bucharest, Romania' : 'RO',
    'Stockholm, Sweden' : 'SE',
    'Valencia, Spain' : 'ES',
    'B†stad, Sweden' : 'SE',
    'Kitzbuhel, Austria' : 'AT',
    'Monte-Carlo, Monaco' : 'MC',
    'Oeiras, Portugal' : 'PT',
    'Dusseldorf, Germany' : 'DE',
    'Istanbul, Turkey': 'TR',
    'Geneva, Switzerland': 'CH',
    'Nottingham, Great Britain': 'GB',
    'Sofia, Bulgaria': 'BG',
    'Marrakech, Morocco': 'MA',
    'Antwerp, Belgium': 'BE',
    'Budapest, Hungary': 'HU',
    'Lyon, France': 'FR',
    'Antalya, Turkey': 'TR'
}

# creating a new column called 'country_code
tournaments['country_code'] = ''

# loop over the rows of the data frame and map the country names to country codes
for i, row in tournaments.iterrows():
    country_name = row['tourney_location']
    if country_name in country_codes:
        country_code = country_codes[country_name]
    else:
        country_code = 'unknown'  # setting the country code as 'unknown' if not found in the dictionary
    tournaments.loc[i, 'country_code'] = country_code

# %% [markdown]
# Also, for the map, the coordinates of the cities will be needed. Therefore, new columns with the latitude and longitude will also be added.

# %%
# creating empty columns for latitude and longitude
tournaments['latitude'] = ""
tournaments['longitude'] = ""

# iterating through the rows of the dataframe
for i, row in tournaments.iterrows():
    # geting the city name from the 'city' column and convert to lowercase
    city = row['tourney_city']
    code = row['country_code']
    try:
        # using the CityCoordinator object to get the coordinates for the city
        result = c.get_city(city_name = city, country_code_iso = code)

        # extracting the latitude and longitude from the result and add to the dataframe
        tournaments.at[i, 'latitude'] = result['location']['lat']
        tournaments.at[i, 'longitude'] = result['location']['lon']
    except:
        # if the city name is not found, set the latitude and longitude to NaN
        tournaments.at[i, 'latitude'] = float('nan')
        tournaments.at[i, 'longitude'] = float('nan')

# %%
# there are some tournaments without the latitude and longitude because the cities' names are different in the dataset and in the CityCoordinator mapper

falta = tournaments[tournaments['latitude'].isna()]
falta.groupby('tourney_city')['tourney_region', 'country_code', 'latitude', 'longitude'].agg('first')
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_33528\917297412.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   falta.groupby('tourney_city')['tourney_region', 'country_code', 'latitude', 'longitude'].agg('first')
#                 tourney_region country_code latitude longitude
# tourney_city
# Acapulco         north america           MX     None      None
# Antwerp                 europe           BE     None      None
# Bastad                  europe           SE     None      None
# Bogota           south america           CO     None      None
# B†stad                  europe           SE     None      None
# Cordoba          south america           AR     None      None
# Costa do Sauipe  south america           BR     None      None
# Dusseldorf              europe           DE     None      None
# Geneva                  europe           CH     None      None
# Kitzbhel                europe           AT     None      None
# Kitzbuhel               europe           AT     None      None
# Los Cabos        north america           MX     None      None
# Marrakech               africa           MA     None      None
# Monte Carlo             europe           MC     None      None
# Montreal         north america           CA     None      None
# New York         north america           US     None      None
# San Jose         north america           CR     None      None
# Sao Paulo        south america           BR     None      None
# St. Petersburg          europe           RU     None      None
# Vina del Mar     south america           CL     None      None
# s-Hertogenbosch         europe           NL     None      None

# %%
# dictionary with the right cities' names
new_cities = {'Acapulco': 'Acapulco de Juárez',
              'Antwerp': 'Antwerpen',
              'Bastad': 'Båstad',
              'Bogota': 'Bogotá',
              'B†stad': 'Båstad',
              'Cordoba': 'Córdoba',
              'Costa do Sauipe': 'Mata de São João',
              'Dusseldorf': 'Düsseldorf',
              'Geneva': 'Genève',
              'Kitzbhel': 'Kitzbühel',
              'Kitzbuhel': 'Kitzbühel',
              'Los Cabos': 'Cabo San Lucas',
              'Marrakech': 'Marrakesh',
              'Monte Carlo': 'Monte-Carlo',
              'Montreal': 'Montréal',
              'New York': 'New York City',
              'San Jose': 'San José',
              'Sao Paulo': 'São Paulo',
              'St. Petersburg': 'Saint Petersburg',
              'Vina del Mar': 'Viña del Mar',
              's-Hertogenbosch': '\'s-Hertogenbosch'
              }

# replacing the cities' names
tournaments['tourney_city'] = tournaments['tourney_city'].replace(new_cities)

# assigning again the latitude and longitude
# iterating through the rows of the dataframe
for i, row in tournaments.iterrows():
    # geting the city name from the 'city' column and convert to lowercase
    city = row['tourney_city']
    code = row['country_code']
    try:
        # using the CityCoordinator object to get the coordinates for the city
        result = c.get_city(city_name = city, country_code_iso = code)

        # extracting the latitude and longitude from the result and add to the dataframe
        tournaments.at[i, 'latitude'] = result['location']['lat']
        tournaments.at[i, 'longitude'] = result['location']['lon']
    except:
        # if the city name is not found, set the latitude and longitude to NaN
        tournaments.at[i, 'latitude'] = float('nan')
        tournaments.at[i, 'longitude'] = float('nan')

# %%
tournaments.T
# Out:
#                                               0                       1    \
# tourney_year_id                          2010-339                2010-451
# tourney_order                                   1                       2
# tourney_type                              ATP 250                 ATP 250
# tourney_name                             Brisbane                    Doha
# tourney_id                                    339                     451
# tourney_slug                             brisbane                    doha
# tourney_location                         Brisbane                    Doha
# tourney_date                  2010-01-03 00:00:00     2010-01-04 00:00:00
# year                                         2010                    2010
# tourney_singles_draw                           32                      32
# tourney_doubles_draw                           16                      16
# tourney_conditions                        Outdoor                 Outdoor
# tourney_surface                              Hard                    Hard
# singles_winner_name                  Andy Roddick       Nikolay Davydenko
# singles_winner_player_slug           andy-roddick       nikolay-davydenko
# singles_winner_player_id                     r485                    d402
# doubles_winner_1_name               Jeremy Chardy  Guillermo Garcia-Lopez
# doubles_winner_1_player_slug        jeremy-chardy  guillermo-garcia-lopez
# doubles_winner_1_player_id                   ca12                    g476
# doubles_winner_2_name                Marc Gicquel         Albert Montanes
# doubles_winner_2_player_slug         marc-gicquel         albert-montanes
# doubles_winner_2_player_id                   g436                    m824
# tourney_fin_commit_USD                   424250.0               1110250.0
# tourney_region                            oceania                    asia
# tourney_city                             Brisbane                    Doha
# country_code                                   AU                      QA
# latitude                                -27.46794                25.28545
# longitude                               153.02809                51.53096
#
#                                               2                    3    \
# tourney_year_id                          2010-891             2010-338
# tourney_order                                   3                    4
# tourney_type                              ATP 250              ATP 250
# tourney_name                              Chennai               Sydney
# tourney_id                                    891                  338
# tourney_slug                              chennai               sydney
# tourney_location                          Chennai               Sydney
# tourney_date                  2010-01-04 00:00:00  2010-01-11 00:00:00
# year                                         2010                 2010
# tourney_singles_draw                           32                   28
# tourney_doubles_draw                           16                   16
# tourney_conditions                        Outdoor              Outdoor
# tourney_surface                              Hard                 Hard
# singles_winner_name                   Marin Cilic     Marcos Baghdatis
# singles_winner_player_slug            marin-cilic     marcos-baghdatis
# singles_winner_player_id                     c977                 b837
# doubles_winner_1_name           Marcel Granollers        Daniel Nestor
# doubles_winner_1_player_slug    marcel-granollers        daniel-nestor
# doubles_winner_1_player_id                   g710                 n210
# doubles_winner_2_name            Santiago Ventura       Nenad Zimonjic
# doubles_winner_2_player_slug     santiago-ventura       nenad-zimonjic
# doubles_winner_2_player_id                   v251                 z072
# tourney_fin_commit_USD                   450000.0             424250.0
# tourney_region                               asia              oceania
# tourney_city                              Chennai               Sydney
# country_code                                   IN                   AU
# latitude                                 13.08784            -33.86785
# longitude                                80.27847            151.20732
#
#                                               4                     5    \
# tourney_year_id                          2010-301             2010-5012
# tourney_order                                   5                     7
# tourney_type                              ATP 250               ATP 250
# tourney_name                             Auckland          Johannesburg
# tourney_id                                    301                  5012
# tourney_slug                             auckland          johannesburg
# tourney_location                         Auckland          Johannesburg
# tourney_date                  2010-01-11 00:00:00   2010-02-01 00:00:00
# year                                         2010                  2010
# tourney_singles_draw                           28                    32
# tourney_doubles_draw                           16                    16
# tourney_conditions                        Outdoor               Outdoor
# tourney_surface                              Hard                  Hard
# singles_winner_name                    John Isner       Feliciano Lopez
# singles_winner_player_slug             john-isner       feliciano-lopez
# singles_winner_player_id                     i186                  l397
# doubles_winner_1_name              Marcus Daniell         Rohan Bopanna
# doubles_winner_1_player_slug       marcus-daniell         rohan-bopanna
# doubles_winner_1_player_id                   d763                  b757
# doubles_winner_2_name                 Horia Tecau  Aisam-Ul-Haq Qureshi
# doubles_winner_2_player_slug          horia-tecau  aisam-ul-haq-qureshi
# doubles_winner_2_player_id                   t749                  q019
# tourney_fin_commit_USD                   407250.0              500000.0
# tourney_region                            oceania                africa
# tourney_city                             Auckland          Johannesburg
# country_code                                   NZ                    ZA
# latitude                                -36.84853             -26.20227
# longitude                               174.76349              28.04363
#
#                                               6                    7    \
# tourney_year_id                          2010-505             2010-424
# tourney_order                                   8                   11
# tourney_type                              ATP 250              ATP 250
# tourney_name                             Santiago             San Jose
# tourney_id                                    505                  424
# tourney_slug                             santiago             san-jose
# tourney_location                         Santiago             San Jose
# tourney_date                  2010-02-01 00:00:00  2010-02-08 00:00:00
# year                                         2010                 2010
# tourney_singles_draw                           32                   32
# tourney_doubles_draw                           16                   16
# tourney_conditions                        Outdoor               Indoor
# tourney_surface                              Clay                 Hard
# singles_winner_name               Thomaz Bellucci    Fernando Verdasco
# singles_winner_player_slug        thomaz-bellucci    fernando-verdasco
# singles_winner_player_id                     bd20                 v306
# doubles_winner_1_name                Lukasz Kubot           Mardy Fish
# doubles_winner_1_player_slug         lukasz-kubot           mardy-fish
# doubles_winner_1_player_id                   k540                 f339
# doubles_winner_2_name               Oliver Marach          Sam Querrey
# doubles_winner_2_player_slug        oliver-marach          sam-querrey
# doubles_winner_2_player_id                   m760                 q927
# tourney_fin_commit_USD                   450000.0             600000.0
# tourney_region                      south america        north america
# tourney_city                             Santiago             San José
# country_code                                   CL                   CR
# latitude                                -33.45694             10.95173
# longitude                               -70.64827             -85.1361
#
#                                               8                    9    ...  \
# tourney_year_id                          2010-533             2010-402  ...
# tourney_order                                  12                   13  ...
# tourney_type                              ATP 250              ATP 500  ...
# tourney_name                      Costa do Sauipe              Memphis  ...
# tourney_id                                    533                  402  ...
# tourney_slug                      costa-do-sauipe              memphis  ...
# tourney_location                  Costa do Sauipe              Memphis  ...
# tourney_date                  2010-02-08 00:00:00  2010-02-15 00:00:00  ...
# year                                         2010                 2010  ...
# tourney_singles_draw                           32                   32  ...
# tourney_doubles_draw                           16                   16  ...
# tourney_conditions                        Outdoor               Indoor  ...
# tourney_surface                              Clay                 Hard  ...
# singles_winner_name           Juan Carlos Ferrero          Sam Querrey  ...
# singles_winner_player_slug    juan-carlos-ferrero          sam-querrey  ...
# singles_winner_player_id                     f316                 q927  ...
# doubles_winner_1_name                Pablo Cuevas           John Isner  ...
# doubles_winner_1_player_slug         pablo-cuevas           john-isner  ...
# doubles_winner_1_player_id                   c882                 i186  ...
# doubles_winner_2_name           Marcel Granollers          Sam Querrey  ...
# doubles_winner_2_player_slug    marcel-granollers          sam-querrey  ...
# doubles_winner_2_player_id                   g710                 q927  ...
# tourney_fin_commit_USD                   500000.0            1226500.0  ...
# tourney_region                      south america        north america  ...
# tourney_city                     Mata de São João              Memphis  ...
# country_code                                   BR                   US  ...
# latitude                                -12.53028             27.53587  ...
# longitude                               -38.29917            -82.56121  ...
#
#                                                 650                    651  \
# tourney_year_id                            2010-540               2011-540
# tourney_order                                    37                     37
# tourney_type                             Grand Slam             Grand Slam
# tourney_name                              Wimbledon              Wimbledon
# tourney_id                                      540                    540
# tourney_slug                              wimbledon              wimbledon
# tourney_location              London, Great Britain  London, Great Britain
# tourney_date                    2010-06-21 00:00:00    2011-06-20 00:00:00
# year                                           2010                   2011
# tourney_singles_draw                            128                    128
# tourney_doubles_draw                             64                     64
# tourney_conditions                          Outdoor                Outdoor
# tourney_surface                               Grass                  Grass
# singles_winner_name                    Rafael Nadal         Novak Djokovic
# singles_winner_player_slug             rafael-nadal         novak-djokovic
# singles_winner_player_id                       n409                   d643
# doubles_winner_1_name                 Jurgen Melzer              Bob Bryan
# doubles_winner_1_player_slug          jurgen-melzer              bob-bryan
# doubles_winner_1_player_id                     m762                   b588
# doubles_winner_2_name            Philipp Petzschner             Mike Bryan
# doubles_winner_2_player_slug     philipp-petzschner             mike-bryan
# doubles_winner_2_player_id                     p624                   b589
# tourney_fin_commit_USD                    7456266.4              7979745.4
# tourney_region                               europe                 europe
# tourney_city                                 London                 London
# country_code                                     GB                     GB
# latitude                                   51.50853               51.50853
# longitude                                  -0.12574               -0.12574
#
#                                                 652                    653  \
# tourney_year_id                            2012-540               2013-540
# tourney_order                                    38                     37
# tourney_type                             Grand Slam             Grand Slam
# tourney_name                              Wimbledon              Wimbledon
# tourney_id                                      540                    540
# tourney_slug                              wimbledon              wimbledon
# tourney_location              London, Great Britain  London, Great Britain
# tourney_date                    2012-06-25 00:00:00    2013-06-24 00:00:00
# year                                           2012                   2013
# tourney_singles_draw                            128                    128
# tourney_doubles_draw                             64                     64
# tourney_conditions                          Outdoor                Outdoor
# tourney_surface                               Grass                  Grass
# singles_winner_name                   Roger Federer            Andy Murray
# singles_winner_player_slug            roger-federer            andy-murray
# singles_winner_player_id                       f324                   mc10
# doubles_winner_1_name               Jonathan Marray              Bob Bryan
# doubles_winner_1_player_slug        jonathan-marray              bob-bryan
# doubles_winner_1_player_id                     m983                   b588
# doubles_winner_2_name              Frederik Nielsen             Mike Bryan
# doubles_winner_2_player_slug       frederik-nielsen             mike-bryan
# doubles_winner_2_player_id                     n390                   b589
# tourney_fin_commit_USD                   8767009.68             12652547.6
# tourney_region                               europe                 europe
# tourney_city                                 London                 London
# country_code                                     GB                     GB
# latitude                                   51.50853               51.50853
# longitude                                  -0.12574               -0.12574
#
#                                                 654                    655  \
# tourney_year_id                            2014-540               2015-540
# tourney_order                                    38                     39
# tourney_type                             Grand Slam             Grand Slam
# tourney_name                              Wimbledon              Wimbledon
# tourney_id                                      540                    540
# tourney_slug                              wimbledon              wimbledon
# tourney_location              London, Great Britain  London, Great Britain
# tourney_date                    2014-06-23 00:00:00    2015-06-29 00:00:00
# year                                           2014                   2015
# tourney_singles_draw                            128                    128
# tourney_doubles_draw                             64                     64
# tourney_conditions                          Outdoor                Outdoor
# tourney_surface                               Grass                  Grass
# singles_winner_name                  Novak Djokovic         Novak Djokovic
# singles_winner_player_slug           novak-djokovic         novak-djokovic
# singles_winner_player_id                       d643                   d643
# doubles_winner_1_name                Vasek Pospisil      Jean-Julien Rojer
# doubles_winner_1_player_slug         vasek-pospisil      jean-julien-rojer
# doubles_winner_1_player_id                     pd07                   r513
# doubles_winner_2_name                     Jack Sock            Horia Tecau
# doubles_winner_2_player_slug              jack-sock            horia-tecau
# doubles_winner_2_player_id                     sm25                   t749
# tourney_fin_commit_USD                   14097831.0             15124331.2
# tourney_region                               europe                 europe
# tourney_city                                 London                 London
# country_code                                     GB                     GB
# latitude                                   51.50853               51.50853
# longitude                                  -0.12574               -0.12574
#
#                                                 656                    657  \
# tourney_year_id                            2016-540               2017-540
# tourney_order                                    39                     40
# tourney_type                             Grand Slam             Grand Slam
# tourney_name                              Wimbledon              Wimbledon
# tourney_id                                      540                    540
# tourney_slug                              wimbledon              wimbledon
# tourney_location              London, Great Britain  London, Great Britain
# tourney_date                    2016-06-27 00:00:00    2017-07-03 00:00:00
# year                                           2016                   2017
# tourney_singles_draw                            128                    128
# tourney_doubles_draw                             64                     64
# tourney_conditions                          Outdoor                Outdoor
# tourney_surface                               Grass                  Grass
# singles_winner_name                     Andy Murray          Roger Federer
# singles_winner_player_slug              andy-murray          roger-federer
# singles_winner_player_id                       mc10                   f324
# doubles_winner_1_name         Pierre-Hugues Herbert           Lukasz Kubot
# doubles_winner_1_player_slug  pierre-hugues-herbert           lukasz-kubot
# doubles_winner_1_player_id                     h996                   k540
# doubles_winner_2_name                 Nicolas Mahut           Marcelo Melo
# doubles_winner_2_player_slug          nicolas-mahut           marcelo-melo
# doubles_winner_2_player_id                     m873                   m919
# tourney_fin_commit_USD                   15840354.2             17858456.0
# tourney_region                               europe                 europe
# tourney_city                                 London                 London
# country_code                                     GB                     GB
# latitude                                   51.50853               51.50853
# longitude                                  -0.12574               -0.12574
#
#                                                 658                    659
# tourney_year_id                            2018-540               2019-540
# tourney_order                                    40                     39
# tourney_type                             Grand Slam             Grand Slam
# tourney_name                              Wimbledon              Wimbledon
# tourney_id                                      540                    540
# tourney_slug                              wimbledon              wimbledon
# tourney_location              London, Great Britain  London, Great Britain
# tourney_date                    2018-07-02 00:00:00    2019-07-01 00:00:00
# year                                           2018                   2019
# tourney_singles_draw                            128                    128
# tourney_doubles_draw                             64                     64
# tourney_conditions                          Outdoor                Outdoor
# tourney_surface                               Grass                  Grass
# singles_winner_name                  Novak Djokovic         Novak Djokovic
# singles_winner_player_slug           novak-djokovic         novak-djokovic
# singles_winner_player_id                       d643                   d643
# doubles_winner_1_name                    Mike Bryan   Juan Sebastian Cabal
# doubles_winner_1_player_slug             mike-bryan   juan-sebastian-cabal
# doubles_winner_1_player_id                     b589                   c834
# doubles_winner_2_name                     Jack Sock           Robert Farah
# doubles_winner_2_player_slug              jack-sock           robert-farah
# doubles_winner_2_player_id                     sm25                   f525
# tourney_fin_commit_USD                   19232738.8             21383214.6
# tourney_region                               europe                 europe
# tourney_city                                 London                 London
# country_code                                     GB                     GB
# latitude                                   51.50853               51.50853
# longitude                                  -0.12574               -0.12574
#
# [28 rows x 660 columns]

# %% [markdown]
# After starting constructing of the dashboard, we noticed that it was being too slow, maybe due to the high number of features and observations in the datasets. Therefore, we decided to drop the variables and observations that were not needed for the analysis.

# %%
tournaments.drop(columns = ['tourney_year_id', 'tourney_order', 'tourney_id', 'tourney_slug', 'tourney_date', 'tourney_singles_draw', 'tourney_doubles_draw', 'singles_winner_player_slug', 'singles_winner_player_id', 'doubles_winner_1_player_slug', 'doubles_winner_1_player_id', 'doubles_winner_2_player_slug', 'doubles_winner_2_player_id'], inplace = True)
tournaments.T
# Out:
#                                   0                       1    \
# tourney_type                  ATP 250                 ATP 250
# tourney_name                 Brisbane                    Doha
# tourney_location             Brisbane                    Doha
# year                             2010                    2010
# tourney_conditions            Outdoor                 Outdoor
# tourney_surface                  Hard                    Hard
# singles_winner_name      Andy Roddick       Nikolay Davydenko
# doubles_winner_1_name   Jeremy Chardy  Guillermo Garcia-Lopez
# doubles_winner_2_name    Marc Gicquel         Albert Montanes
# tourney_fin_commit_USD       424250.0               1110250.0
# tourney_region                oceania                    asia
# tourney_city                 Brisbane                    Doha
# country_code                       AU                      QA
# latitude                    -27.46794                25.28545
# longitude                   153.02809                51.53096
#
#                                       2                 3               4    \
# tourney_type                      ATP 250           ATP 250         ATP 250
# tourney_name                      Chennai            Sydney        Auckland
# tourney_location                  Chennai            Sydney        Auckland
# year                                 2010              2010            2010
# tourney_conditions                Outdoor           Outdoor         Outdoor
# tourney_surface                      Hard              Hard            Hard
# singles_winner_name           Marin Cilic  Marcos Baghdatis      John Isner
# doubles_winner_1_name   Marcel Granollers     Daniel Nestor  Marcus Daniell
# doubles_winner_2_name    Santiago Ventura    Nenad Zimonjic     Horia Tecau
# tourney_fin_commit_USD           450000.0          424250.0        407250.0
# tourney_region                       asia           oceania         oceania
# tourney_city                      Chennai            Sydney        Auckland
# country_code                           IN                AU              NZ
# latitude                         13.08784         -33.86785       -36.84853
# longitude                        80.27847         151.20732       174.76349
#
#                                          5                6    \
# tourney_type                         ATP 250          ATP 250
# tourney_name                    Johannesburg         Santiago
# tourney_location                Johannesburg         Santiago
# year                                    2010             2010
# tourney_conditions                   Outdoor          Outdoor
# tourney_surface                         Hard             Clay
# singles_winner_name          Feliciano Lopez  Thomaz Bellucci
# doubles_winner_1_name          Rohan Bopanna     Lukasz Kubot
# doubles_winner_2_name   Aisam-Ul-Haq Qureshi    Oliver Marach
# tourney_fin_commit_USD              500000.0         450000.0
# tourney_region                        africa    south america
# tourney_city                    Johannesburg         Santiago
# country_code                              ZA               CL
# latitude                           -26.20227        -33.45694
# longitude                           28.04363        -70.64827
#
#                                       7                    8              9    \
# tourney_type                      ATP 250              ATP 250        ATP 500
# tourney_name                     San Jose      Costa do Sauipe        Memphis
# tourney_location                 San Jose      Costa do Sauipe        Memphis
# year                                 2010                 2010           2010
# tourney_conditions                 Indoor              Outdoor         Indoor
# tourney_surface                      Hard                 Clay           Hard
# singles_winner_name     Fernando Verdasco  Juan Carlos Ferrero    Sam Querrey
# doubles_winner_1_name          Mardy Fish         Pablo Cuevas     John Isner
# doubles_winner_2_name         Sam Querrey    Marcel Granollers    Sam Querrey
# tourney_fin_commit_USD           600000.0             500000.0      1226500.0
# tourney_region              north america        south america  north america
# tourney_city                     San José     Mata de São João        Memphis
# country_code                           CR                   BR             US
# latitude                         10.95173            -12.53028       27.53587
# longitude                        -85.1361            -38.29917      -82.56121
#
#                         ...                    650                    651  \
# tourney_type            ...             Grand Slam             Grand Slam
# tourney_name            ...              Wimbledon              Wimbledon
# tourney_location        ...  London, Great Britain  London, Great Britain
# year                    ...                   2010                   2011
# tourney_conditions      ...                Outdoor                Outdoor
# tourney_surface         ...                  Grass                  Grass
# singles_winner_name     ...           Rafael Nadal         Novak Djokovic
# doubles_winner_1_name   ...          Jurgen Melzer              Bob Bryan
# doubles_winner_2_name   ...     Philipp Petzschner             Mike Bryan
# tourney_fin_commit_USD  ...              7456266.4              7979745.4
# tourney_region          ...                 europe                 europe
# tourney_city            ...                 London                 London
# country_code            ...                     GB                     GB
# latitude                ...               51.50853               51.50853
# longitude               ...               -0.12574               -0.12574
#
#                                           652                    653  \
# tourney_type                       Grand Slam             Grand Slam
# tourney_name                        Wimbledon              Wimbledon
# tourney_location        London, Great Britain  London, Great Britain
# year                                     2012                   2013
# tourney_conditions                    Outdoor                Outdoor
# tourney_surface                         Grass                  Grass
# singles_winner_name             Roger Federer            Andy Murray
# doubles_winner_1_name         Jonathan Marray              Bob Bryan
# doubles_winner_2_name        Frederik Nielsen             Mike Bryan
# tourney_fin_commit_USD             8767009.68             12652547.6
# tourney_region                         europe                 europe
# tourney_city                           London                 London
# country_code                               GB                     GB
# latitude                             51.50853               51.50853
# longitude                            -0.12574               -0.12574
#
#                                           654                    655  \
# tourney_type                       Grand Slam             Grand Slam
# tourney_name                        Wimbledon              Wimbledon
# tourney_location        London, Great Britain  London, Great Britain
# year                                     2014                   2015
# tourney_conditions                    Outdoor                Outdoor
# tourney_surface                         Grass                  Grass
# singles_winner_name            Novak Djokovic         Novak Djokovic
# doubles_winner_1_name          Vasek Pospisil      Jean-Julien Rojer
# doubles_winner_2_name               Jack Sock            Horia Tecau
# tourney_fin_commit_USD             14097831.0             15124331.2
# tourney_region                         europe                 europe
# tourney_city                           London                 London
# country_code                               GB                     GB
# latitude                             51.50853               51.50853
# longitude                            -0.12574               -0.12574
#
#                                           656                    657  \
# tourney_type                       Grand Slam             Grand Slam
# tourney_name                        Wimbledon              Wimbledon
# tourney_location        London, Great Britain  London, Great Britain
# year                                     2016                   2017
# tourney_conditions                    Outdoor                Outdoor
# tourney_surface                         Grass                  Grass
# singles_winner_name               Andy Murray          Roger Federer
# doubles_winner_1_name   Pierre-Hugues Herbert           Lukasz Kubot
# doubles_winner_2_name           Nicolas Mahut           Marcelo Melo
# tourney_fin_commit_USD             15840354.2             17858456.0
# tourney_region                         europe                 europe
# tourney_city                           London                 London
# country_code                               GB                     GB
# latitude                             51.50853               51.50853
# longitude                            -0.12574               -0.12574
#
#                                           658                    659
# tourney_type                       Grand Slam             Grand Slam
# tourney_name                        Wimbledon              Wimbledon
# tourney_location        London, Great Britain  London, Great Britain
# year                                     2018                   2019
# tourney_conditions                    Outdoor                Outdoor
# tourney_surface                         Grass                  Grass
# singles_winner_name            Novak Djokovic         Novak Djokovic
# doubles_winner_1_name              Mike Bryan   Juan Sebastian Cabal
# doubles_winner_2_name               Jack Sock           Robert Farah
# tourney_fin_commit_USD             19232738.8             21383214.6
# tourney_region                         europe                 europe
# tourney_city                           London                 London
# country_code                               GB                     GB
# latitude                             51.50853               51.50853
# longitude                            -0.12574               -0.12574
#
# [15 rows x 660 columns]

# %% [markdown]
# <a id = "understanding-preparation-match-scores"></a>
#
# ## 3. Data understanding and preparation - Match Scores dataset
#
# [Back to TOC](#toc)

# %%
match_scores.T
# Out:
#                                                                     0      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS001
# tourney_round_name                                                 Finals
# round_order                                                             1
# match_order                                                             1
# winner_name                                                  Andy Roddick
# winner_player_id                                                     r485
# winner_slug                                                  andy-roddick
# loser_name                                                 Radek Stepanek
# loser_player_id                                                      s694
# loser_slug                                                 radek-stepanek
# winner_seed                                                             1
# loser_seed                                                              2
# match_score_tiebreaks                                         76(2) 76(7)
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     14.0
# loser_games_won                                                      12.0
# winner_tiebreaks_won                                                  2.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS001-8-1-r485-s694
# match_stats_url_suffix  /en/scores/2010/339/MS001/match-stats?isLive=F...
#
#                                                                     1      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS002
# tourney_round_name                                            Semi-Finals
# round_order                                                             2
# match_order                                                             1
# winner_name                                                  Andy Roddick
# winner_player_id                                                     r485
# winner_slug                                                  andy-roddick
# loser_name                                                  Tomas Berdych
# loser_player_id                                                      ba47
# loser_slug                                                  tomas-berdych
# winner_seed                                                             1
# loser_seed                                                              4
# match_score_tiebreaks                                            16 63 64
# winner_sets_won                                                       2.0
# loser_sets_won                                                        1.0
# winner_games_won                                                     13.0
# loser_games_won                                                      13.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS002-7-2-r485-ba47
# match_stats_url_suffix  /en/scores/2010/339/MS002/match-stats?isLive=F...
#
#                                                                     2      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS003
# tourney_round_name                                            Semi-Finals
# round_order                                                             2
# match_order                                                             2
# winner_name                                                Radek Stepanek
# winner_player_id                                                     s694
# winner_slug                                                radek-stepanek
# loser_name                                                   Gael Monfils
# loser_player_id                                                      mc65
# loser_slug                                                   gael-monfils
# winner_seed                                                             2
# loser_seed                                                              3
# match_score_tiebreaks                                               62 61
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     12.0
# loser_games_won                                                       3.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS003-7-1-s694-mc65
# match_stats_url_suffix  /en/scores/2010/339/MS003/match-stats?isLive=F...
#
#                                                                     3      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS004
# tourney_round_name                                         Quarter-Finals
# round_order                                                             3
# match_order                                                             1
# winner_name                                                  Andy Roddick
# winner_player_id                                                     r485
# winner_slug                                                  andy-roddick
# loser_name                                                Richard Gasquet
# loser_player_id                                                      g628
# loser_slug                                                richard-gasquet
# winner_seed                                                             1
# loser_seed                                                            NaN
# match_score_tiebreaks                                            63 76(5)
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     13.0
# loser_games_won                                                       9.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS004-6-4-r485-g628
# match_stats_url_suffix  /en/scores/2010/339/MS004/match-stats?isLive=F...
#
#                                                                     4      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS007
# tourney_round_name                                         Quarter-Finals
# round_order                                                             3
# match_order                                                             2
# winner_name                                                Radek Stepanek
# winner_player_id                                                     s694
# winner_slug                                                radek-stepanek
# loser_name                                                  Wayne Odesnik
# loser_player_id                                                      o234
# loser_slug                                                  wayne-odesnik
# winner_seed                                                             2
# loser_seed                                                            NaN
# match_score_tiebreaks                                            76(2) 61
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     13.0
# loser_games_won                                                       7.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS007-6-3-s694-o234
# match_stats_url_suffix  /en/scores/2010/339/MS007/match-stats?isLive=F...
#
#                                                                     5      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS006
# tourney_round_name                                         Quarter-Finals
# round_order                                                             3
# match_order                                                             3
# winner_name                                                  Gael Monfils
# winner_player_id                                                     mc65
# winner_slug                                                  gael-monfils
# loser_name                                                    James Blake
# loser_player_id                                                      b676
# loser_slug                                                    james-blake
# winner_seed                                                             3
# loser_seed                                                            NaN
# match_score_tiebreaks                                            36 63 64
# winner_sets_won                                                       2.0
# loser_sets_won                                                        1.0
# winner_games_won                                                     15.0
# loser_games_won                                                      13.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS006-6-2-mc65-b676
# match_stats_url_suffix  /en/scores/2010/339/MS006/match-stats?isLive=F...
#
#                                                                     6      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS005
# tourney_round_name                                         Quarter-Finals
# round_order                                                             3
# match_order                                                             4
# winner_name                                                 Tomas Berdych
# winner_player_id                                                     ba47
# winner_slug                                                 tomas-berdych
# loser_name                                                Thomaz Bellucci
# loser_player_id                                                      bd20
# loser_slug                                                thomaz-bellucci
# winner_seed                                                             4
# loser_seed                                                              8
# match_score_tiebreaks                                      76(4) 26 76(3)
# winner_sets_won                                                       2.0
# loser_sets_won                                                        1.0
# winner_games_won                                                     16.0
# loser_games_won                                                      18.0
# winner_tiebreaks_won                                                  2.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS005-6-1-ba47-bd20
# match_stats_url_suffix  /en/scores/2010/339/MS005/match-stats?isLive=F...
#
#                                                                     7      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS008
# tourney_round_name                                            Round of 16
# round_order                                                             4
# match_order                                                             1
# winner_name                                                  Andy Roddick
# winner_player_id                                                     r485
# winner_slug                                                  andy-roddick
# loser_name                                                   Carsten Ball
# loser_player_id                                                      bd59
# loser_slug                                                   carsten-ball
# winner_seed                                                             1
# loser_seed                                                             WC
# match_score_tiebreaks                                               76 63
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     13.0
# loser_games_won                                                       9.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS008-5-8-r485-bd59
# match_stats_url_suffix  /en/scores/2010/339/MS008/match-stats?isLive=F...
#
#                                                                     8      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS015
# tourney_round_name                                            Round of 16
# round_order                                                             4
# match_order                                                             2
# winner_name                                                Radek Stepanek
# winner_player_id                                                     s694
# winner_slug                                                radek-stepanek
# loser_name                                            Alexandr Dolgopolov
# loser_player_id                                                      d801
# loser_slug                                            alexandr-dolgopolov
# winner_seed                                                             2
# loser_seed                                                              Q
# match_score_tiebreaks                                         57 76(4) 62
# winner_sets_won                                                       2.0
# loser_sets_won                                                        1.0
# winner_games_won                                                     18.0
# loser_games_won                                                      15.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2010-339-MS015-5-7-s694-d801
# match_stats_url_suffix  /en/scores/2010/339/MS015/match-stats?isLive=F...
#
#                                                                     9      \
# tourney_year_id                                                  2010-339
# tourney_order                                                           1
# tourney_name                                                     Brisbane
# tourney_slug                                                     brisbane
# tourney_url_suffix           /en/scores/archive/brisbane/339/2010/results
# start_date                                                     2010.01.03
# start_year                                                         2010.0
# start_month                                                           1.0
# start_day                                                             3.0
# end_date                                                       2010.01.10
# end_year                                                           2010.0
# end_month                                                             1.0
# end_day                                                              10.0
# currency                                                              USD
# prize_money                                                      372500.0
# match_index                                                         MS013
# tourney_round_name                                            Round of 16
# round_order                                                             4
# match_order                                                             3
# winner_name                                                  Gael Monfils
# winner_player_id                                                     mc65
# winner_slug                                                  gael-monfils
# loser_name                                                  Florent Serra
# loser_player_id                                                      s963
# loser_slug                                                  florent-serra
# winner_seed                                                             3
# loser_seed                                                            NaN
# match_score_tiebreaks                                      67(5) 76(5) 61
# winner_sets_won                                                       2.0
# loser_sets_won                                                        1.0
# winner_games_won                                                     19.0
# loser_games_won                                                      14.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   1.0
# match_id                                     2010-339-MS013-5-6-mc65-s963
# match_stats_url_suffix  /en/scores/2010/339/MS013/match-stats?isLive=F...
#
#                         ...  \
# tourney_year_id         ...
# tourney_order           ...
# tourney_name            ...
# tourney_slug            ...
# tourney_url_suffix      ...
# start_date              ...
# start_year              ...
# start_month             ...
# start_day               ...
# end_date                ...
# end_year                ...
# end_month               ...
# end_day                 ...
# currency                ...
# prize_money             ...
# match_index             ...
# tourney_round_name      ...
# round_order             ...
# match_order             ...
# winner_name             ...
# winner_player_id        ...
# winner_slug             ...
# loser_name              ...
# loser_player_id         ...
# loser_slug              ...
# winner_seed             ...
# loser_seed              ...
# match_score_tiebreaks   ...
# winner_sets_won         ...
# loser_sets_won          ...
# winner_games_won        ...
# loser_games_won         ...
# winner_tiebreaks_won    ...
# loser_tiebreaks_won     ...
# match_id                ...
# match_stats_url_suffix  ...
#
#                                                                     42817  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS016
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                             3
# winner_name                                                 Roger Federer
# winner_player_id                                                     f324
# winner_slug                                                 roger-federer
# loser_name                                                 Novak Djokovic
# loser_player_id                                                      d643
# loser_slug                                                 novak-djokovic
# winner_seed                                                             3
# loser_seed                                                              2
# match_score_tiebreaks                                               64 63
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     12.0
# loser_games_won                                                       7.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                    2019-605-MS016-1-10-f324-d643
# match_stats_url_suffix  /en/scores/2019/605/MS016/match-stats?isLive=F...
#
#                                                                     42818  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS021
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                             4
# winner_name                                             Matteo Berrettini
# winner_player_id                                                     bk40
# winner_slug                                             matteo-berrettini
# loser_name                                                  Dominic Thiem
# loser_player_id                                                      tb69
# loser_slug                                                  dominic-thiem
# winner_seed                                                             8
# loser_seed                                                              5
# match_score_tiebreaks                                            76(3) 63
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     13.0
# loser_games_won                                                       9.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2019-605-MS021-1-9-bk40-tb69
# match_stats_url_suffix  /en/scores/2019/605/MS021/match-stats?isLive=F...
#
#                                                                     42819  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS008
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                             5
# winner_name                                                  Rafael Nadal
# winner_player_id                                                     n409
# winner_slug                                                  rafael-nadal
# loser_name                                                Daniil Medvedev
# loser_player_id                                                      mm58
# loser_slug                                                daniil-medvedev
# winner_seed                                                             1
# loser_seed                                                              4
# match_score_tiebreaks                                      67(3) 63 76(4)
# winner_sets_won                                                       2.0
# loser_sets_won                                                        1.0
# winner_games_won                                                     19.0
# loser_games_won                                                      16.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   1.0
# match_id                                     2019-605-MS008-1-8-n409-mm58
# match_stats_url_suffix  /en/scores/2019/605/MS008/match-stats?isLive=F...
#
#                                                                     42820  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS013
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                             6
# winner_name                                            Stefanos Tsitsipas
# winner_player_id                                                     te51
# winner_slug                                            stefanos-tsitsipas
# loser_name                                               Alexander Zverev
# loser_player_id                                                      z355
# loser_slug                                               alexander-zverev
# winner_seed                                                             6
# loser_seed                                                              7
# match_score_tiebreaks                                               63 62
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     12.0
# loser_games_won                                                       5.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2019-605-MS013-1-7-te51-z355
# match_stats_url_suffix  /en/scores/2019/605/MS013/match-stats?isLive=F...
#
#                                                                     42821  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS017
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                             7
# winner_name                                                 Dominic Thiem
# winner_player_id                                                     tb69
# winner_slug                                                 dominic-thiem
# loser_name                                                 Novak Djokovic
# loser_player_id                                                      d643
# loser_slug                                                 novak-djokovic
# winner_seed                                                             5
# loser_seed                                                              2
# match_score_tiebreaks                                      67(5) 63 76(5)
# winner_sets_won                                                       2.0
# loser_sets_won                                                        1.0
# winner_games_won                                                     19.0
# loser_games_won                                                      16.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   1.0
# match_id                                     2019-605-MS017-1-6-tb69-d643
# match_stats_url_suffix  /en/scores/2019/605/MS017/match-stats?isLive=F...
#
#                                                                     42822  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS020
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                             8
# winner_name                                                 Roger Federer
# winner_player_id                                                     f324
# winner_slug                                                 roger-federer
# loser_name                                              Matteo Berrettini
# loser_player_id                                                      bk40
# loser_slug                                              matteo-berrettini
# winner_seed                                                             3
# loser_seed                                                              8
# match_score_tiebreaks                                            76(2) 63
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     13.0
# loser_games_won                                                       9.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2019-605-MS020-1-5-f324-bk40
# match_stats_url_suffix  /en/scores/2019/605/MS020/match-stats?isLive=F...
#
#                                                                     42823  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS010
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                             9
# winner_name                                              Alexander Zverev
# winner_player_id                                                     z355
# winner_slug                                              alexander-zverev
# loser_name                                                   Rafael Nadal
# loser_player_id                                                      n409
# loser_slug                                                   rafael-nadal
# winner_seed                                                             7
# loser_seed                                                              1
# match_score_tiebreaks                                               62 64
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     12.0
# loser_games_won                                                       6.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2019-605-MS010-1-4-z355-n409
# match_stats_url_suffix  /en/scores/2019/605/MS010/match-stats?isLive=F...
#
#                                                                     42824  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS011
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                            10
# winner_name                                            Stefanos Tsitsipas
# winner_player_id                                                     te51
# winner_slug                                            stefanos-tsitsipas
# loser_name                                                Daniil Medvedev
# loser_player_id                                                      mm58
# loser_slug                                                daniil-medvedev
# winner_seed                                                             6
# loser_seed                                                              4
# match_score_tiebreaks                                            76(5) 64
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     13.0
# loser_games_won                                                      10.0
# winner_tiebreaks_won                                                  1.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2019-605-MS011-1-3-te51-mm58
# match_stats_url_suffix  /en/scores/2019/605/MS011/match-stats?isLive=F...
#
#                                                                     42825  \
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS018
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                            11
# winner_name                                                Novak Djokovic
# winner_player_id                                                     d643
# winner_slug                                                novak-djokovic
# loser_name                                              Matteo Berrettini
# loser_player_id                                                      bk40
# loser_slug                                              matteo-berrettini
# winner_seed                                                             2
# loser_seed                                                              8
# match_score_tiebreaks                                               62 61
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     12.0
# loser_games_won                                                       3.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2019-605-MS018-1-2-d643-bk40
# match_stats_url_suffix  /en/scores/2019/605/MS018/match-stats?isLive=F...
#
#                                                                     42826
# tourney_year_id                                                  2019-605
# tourney_order                                                          68
# tourney_name                                             Nitto ATP Finals
# tourney_slug                                             nitto-atp-finals
# tourney_url_suffix      /en/scores/archive/nitto-atp-finals/605/2019/r...
# start_date                                                     2019.11.10
# start_year                                                         2019.0
# start_month                                                          11.0
# start_day                                                            10.0
# end_date                                                       2019.11.17
# end_year                                                           2019.0
# end_month                                                            11.0
# end_day                                                              17.0
# currency                                                              USD
# prize_money                                                     9000000.0
# match_index                                                         MS019
# tourney_round_name                                            Round Robin
# round_order                                                             3
# match_order                                                            12
# winner_name                                                 Dominic Thiem
# winner_player_id                                                     tb69
# winner_slug                                                 dominic-thiem
# loser_name                                                  Roger Federer
# loser_player_id                                                      f324
# loser_slug                                                  roger-federer
# winner_seed                                                             5
# loser_seed                                                              3
# match_score_tiebreaks                                               75 75
# winner_sets_won                                                       2.0
# loser_sets_won                                                        0.0
# winner_games_won                                                     14.0
# loser_games_won                                                      10.0
# winner_tiebreaks_won                                                  0.0
# loser_tiebreaks_won                                                   0.0
# match_id                                     2019-605-MS019-1-1-tb69-f324
# match_stats_url_suffix  /en/scores/2019/605/MS019/match-stats?isLive=F...
#
# [36 rows x 42827 columns]

# %% [markdown]
# **Variables**:
#
# - `tourney_year_id`
# - `tourney_order`: in terms of the calendar.
# - `tourney_name`
# - `tourney_slug`
# - `tourney_url_suffix`
# - `start_date`: of the tournament.
# - `start_year`
# - `start_month`
# - `start_day`
# - `end_date`: of the tournament.
# - `end_year`
# - `end_month`
# - `end_day`
# - `currency`
# - `prize_money`
# - `match_index`
# - `tourney_round_name`: different rounds of matches played in the tournament, like: *qualifying rounds*, *first round* (round of 64 or round of 32, for example), *second round*, *third round*, *quarterfinals*, *semifinals*, *finals*, etc.
# - `round_order`: refers to the order of the round, for example Finals would have *round_order* 1, semifinals would have *round_order* 2 and quarterfinals would have *round_order* 3.
# - `match_order`: refers to the order of the game within the round, for example, the first game in the semifinals would have *match_order* 1, and the second game would have *match_order* 2, while, in the same tournament, the first game in the quarterfinals would have *match_order* 1, the second game would have *match_order* 2, the third game would have *match_order* 3, and so on.
# - `winner_name`
# - `winner_player_id`
# - `winner_slug`
# - `loser_name`
# - `loser_player_id`
# - `loser_slug`
# - `winner_seed`: a seed refers to a player who is ranked among the top players in the tournament and is given a predetermined ranking that is used to determine their position in the tournament draw. The seeding process involves assigning a number to each of the top-ranked players in the tournament based on their world ranking. So, this variable stores the seed of the player who won the game.
# - `loser_seed`: while this variable stores the seed of the player who lost the game.
# - `match_score_tiebreaks`: total score (including tiebreaks, if any)
# - `winner_sets_won`
# - `loser_sets_won`
# - `winner_games_won`
# - `loser_games_won`
# - `winner_tiebreaks_won`
# - `loser_tiebreaks_won`
# - `match_id`
# - `match_stats_url_suffix`

# %%
# checking the shape of the dataset

match_scores.shape
# Out:
# (42827, 36)

# %% [markdown]
# #### Data types:

# %%
# checking the types of the variables, as well as the number of non-null observations in each variable

match_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42827 entries, 0 to 42826
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tourney_year_id         42827 non-null  object
#  1   tourney_order           42827 non-null  int64
#  2   tourney_name            42827 non-null  object
#  3   tourney_slug            42827 non-null  object
#  4   tourney_url_suffix      42827 non-null  object
#  5   start_date              42655 non-null  object
#  6   start_year              42655 non-null  float64
#  7   start_month             42655 non-null  float64
#  8   start_day               42655 non-null  float64
#  9   end_date                42655 non-null  object
#  10  end_year                42655 non-null  float64
#  11  end_month               42655 non-null  float64
#  12  end_day                 42655 non-null  float64
#  13  currency                42655 non-null  object
#  14  prize_money             42655 non-null  float64
#  15  match_index             42447 non-null  object
#  16  tourney_round_name      42827 non-null  object
#  17  round_order             42827 non-null  int64
#  18  match_order             42827 non-null  int64
#  19  winner_name             42827 non-null  object
#  20  winner_player_id        42827 non-null  object
#  21  winner_slug             42827 non-null  object
#  22  loser_name              42827 non-null  object
#  23  loser_player_id         42827 non-null  object
#  24  loser_slug              42827 non-null  object
#  25  winner_seed             25831 non-null  object
#  26  loser_seed              20528 non-null  object
#  27  match_score_tiebreaks   42827 non-null  object
#  28  winner_sets_won         42605 non-null  float64
#  29  loser_sets_won          42605 non-null  float64
#  30  winner_games_won        42605 non-null  float64
#  31  loser_games_won         42605 non-null  float64
#  32  winner_tiebreaks_won    42605 non-null  float64
#  33  loser_tiebreaks_won     42605 non-null  float64
#  34  match_id                42827 non-null  object
#  35  match_stats_url_suffix  42447 non-null  object
# dtypes: float64(13), int64(3), object(20)
# memory usage: 11.8+ MB

# %% [markdown]
# Some games have the information regarding the start and end of the tournament missing, and also regarding the `prize_money` of that specific game. It is worth noticing that `start_date` and `end_date` are stored as a string and not as a date. There are also missing variables in variable `match_index` and the seeds, which is normal, since the seed of a player in a tournament refers to their ranking or positioning in the tournament draw, which is determined by their ranking in the ATP, and usually the tournaments seed only 8 or 16 players. There are also other statistics that are missing sometimes, like the number of sets, the number of games, and the number of tiebreaks. Also, the url for the statistics is missing in some cases.

# %%
# storing correctly the variables regarding dates

match_scores['start_date'] = pd.to_datetime(match_scores['start_date'], format = '%Y.%m.%d')
match_scores['end_date'] = pd.to_datetime(match_scores['end_date'], format = '%Y.%m.%d')

# %% [markdown]
# #### Descriptive statistics:

# %%
match_scores.describe().T
# Out:
#                         count          mean           std     min       25%  \
# tourney_order         42827.0  3.295858e+01  1.826405e+01     1.0      19.0
# start_year            42655.0  2.014336e+03  2.850391e+00  2010.0    2012.0
# start_month           42655.0  5.498160e+00  2.952809e+00     1.0       3.0
# start_day             42655.0  1.684567e+01  8.582518e+00     1.0      10.0
# end_year              42655.0  2.014348e+03  2.851810e+00  2010.0    2012.0
# end_month             42655.0  5.663627e+00  2.982104e+00     1.0       3.0
# end_day               42655.0  1.547279e+01  8.703418e+00     1.0       8.0
# prize_money           42655.0  4.728724e+06  6.543085e+06     0.0  501345.0
# round_order           42827.0  5.952016e+00  2.055415e+00     1.0       5.0
# match_order           42827.0  1.013181e+01  1.191788e+01     1.0       3.0
# winner_sets_won       42605.0  2.105410e+00  3.570580e-01     0.0       2.0
# loser_sets_won        42605.0  3.857294e-01  5.325505e-01     0.0       0.0
# winner_games_won      42605.0  1.458587e+01  3.681029e+00     0.0      12.0
# loser_games_won       42605.0  9.630231e+00  4.797228e+00     0.0       6.0
# winner_tiebreaks_won  42605.0  3.274498e-01  5.410730e-01     0.0       0.0
# loser_tiebreaks_won   42605.0  8.846380e-02  2.876670e-01     0.0       0.0
#
#                             50%        75%         max
# tourney_order              33.0       49.0        69.0
# start_year               2014.0     2017.0      2019.0
# start_month                 6.0        8.0        12.0
# start_day                  18.0       24.0        31.0
# end_year                 2014.0     2017.0      2019.0
# end_month                   6.0        8.0        11.0
# end_day                    15.0       23.0        31.0
# prize_money           1404300.0  6196000.0  29687000.0
# round_order                 6.0        7.0        10.0
# match_order                 6.0       12.0        64.0
# winner_sets_won             2.0        2.0         3.0
# loser_sets_won              0.0        1.0         2.0
# winner_games_won           13.0       17.0        92.0
# loser_games_won             9.0       13.0        91.0
# winner_tiebreaks_won        0.0        1.0         3.0
# loser_tiebreaks_won         0.0        0.0         2.0

# %%
match_scores.describe(include = ['O']).T
# Out:
#                         count unique  \
# tourney_year_id         42827    664
# tourney_name            42827     95
# tourney_slug            42827     95
# tourney_url_suffix      42827    664
# currency                42655      4
# match_index             42447    252
# tourney_round_name      42827     13
# winner_name             42827   1195
# winner_player_id        42827   1195
# winner_slug             42827   1195
# loser_name              42827   2122
# loser_player_id         42827   2125
# loser_slug              42827   2122
# winner_seed             25831     62
# loser_seed              20528     61
# match_score_tiebreaks   42827   6544
# match_id                42827  42827
# match_stats_url_suffix  42447  42447
#
#                                                                       top  \
# tourney_year_id                                                  2017-540
# tourney_name                                                Roland Garros
# tourney_slug                                                    wimbledon
# tourney_url_suffix          /en/scores/archive/wimbledon/540/2017/results
# currency                                                              USD
# match_index                                                         MS019
# tourney_round_name                                   1st Round Qualifying
# winner_name                                                Novak Djokovic
# winner_player_id                                                     d643
# winner_slug                                                novak-djokovic
# loser_name                                           Albert Ramos-Vinolas
# loser_player_id                                                      r772
# loser_slug                                           albert-ramos-vinolas
# winner_seed                                                             1
# loser_seed                                                             WC
# match_score_tiebreaks                                               63 64
# match_id                                     2010-339-MS001-8-1-r485-s694
# match_stats_url_suffix  /en/scores/2010/339/MS001/match-stats?isLive=F...
#
#                          freq
# tourney_year_id           239
# tourney_name             2390
# tourney_slug             2390
# tourney_url_suffix        239
# currency                19510
# match_index               661
# tourney_round_name       9596
# winner_name               620
# winner_player_id          620
# winner_slug               620
# loser_name                257
# loser_player_id           257
# loser_slug                257
# winner_seed              2477
# loser_seed               4212
# match_score_tiebreaks    1552
# match_id                    1
# match_stats_url_suffix      1

# %% [markdown]
# Regarding these statistics, it can be seen that the mean of sets won by the winner is 2.1, which makes sense as the majority of the tournaments are played at the best of three sets. Also, the average of games won by the winner is 14.6 and the average of games won by the loser is 9.7. The average prize money is 4.7 million for the tournaments. The player that won more games in this dataframe was Novak Djokovic and the player that lost more was Albert Ramos-Vinolas. Regarding the seeds, the majority of winners of games are 1st seed, while the majority of losers are Wild Cards. Wild Cards is a special entry that allows a player or team to participate in a tournament without having to go through the usual qualification process, and are usually granted by the tournament organizers to players or teams who are not eligible for direct entry into the tournament based on their ranking, but who are deemed to be of sufficient quality or interest to enhance the tournament's appeal.

# %% [markdown]
# #### Do not make sense for our analysis:
#
# As before, we have URL in the dataset (`tourney_url_suffix`, `match_stats_url_suffix`), that do not make sense for our analysis, therefore will also be deleted. The same happens for the `match_order`, as it is irrelevant to know what were the matches that played before or after in the same round (the only thing that matters is the round).

# %%
# dropping the variables as explained before

match_scores.drop(columns = ['tourney_url_suffix', 'match_stats_url_suffix', 'match_order'], inplace = True)

# %% [markdown]
# Again, we have columns that have redundant information, particularly the dates columns, as we have two columns for start date and end date, and other 6 columns for the decomposition of these dates (year, month, and day). They are not necessary, so we will delete them.

# %%
# dropping the variables as explained above

match_scores.drop(columns = ['start_year', 'start_month', 'start_day', 'end_year', 'end_month', 'end_day'], inplace = True)

# %%
match_scores['tourney_name'].unique()
# Out:
# array(['Brisbane', 'Doha', 'Chennai', 'Sydney', 'Auckland',
#        'Australian Open', 'Johannesburg', 'Santiago', 'Zagreb',
#        'Rotterdam', 'San Jose', 'Costa do Sauipe', 'Memphis', 'Marseille',
#        'Buenos Aires', 'Dubai', 'Acapulco', 'Delray Beach',
#        'ATP Masters 1000 Indian Wells', 'ATP Masters 1000 Miami',
#        'Houston', 'Casablanca', 'ATP Masters 1000 Monte Carlo',
#        'Barcelona', 'ATP Masters 1000 Rome', 'Munich', 'Estoril',
#        'Belgrade', 'ATP Masters 1000 Madrid', 'World Team Championship',
#        'Nice', 'Roland Garros', 'Halle', "London / Queen's Club",
#        'Eastbourne', 's-Hertogenbosch', 'Wimbledon', 'Newport', 'Bastad',
#        'Stuttgart', 'Hamburg', 'Atlanta', 'Gstaad', 'Los Angeles', 'Umag',
#        'Washington', 'ATP Masters 1000 Canada',
#        'ATP Masters 1000 Cincinnati', 'New Haven', 'US Open', 'Metz',
#        'Bucharest', 'Kuala Lumpur', 'Bangkok', 'Beijing', 'Tokyo',
#        'ATP Masters 1000 Shanghai', 'Moscow', 'Stockholm',
#        'St. Petersburg', 'Montpellier', 'Vienna', 'Valencia', 'Basel',
#        'ATP Masters 1000 Paris', 'ATP Finals', 'Kitzbühel',
#        'Winston-Salem', 'Vina del Mar', 'Sao Paulo', 'London Olympics',
#        'Oeiras', 'Dusseldorf', 'Bogota', 'Rio de Janeiro', 'Shenzhen',
#        'Quito', 'Istanbul', 'Geneva', 'Nottingham', 'Sofia', 'Marrakech',
#        'Rio de Janeiro Olympic Games', 'Los Cabos', 'Chengdu', 'Antwerp',
#        'Budapest', 'Lyon', 'Antalya', 'Next Gen ATP Finals',
#        'Nitto ATP Finals', 'Pune', 'New York', 'Cordoba', 'Zhuhai'],
#       dtype=object)

# %% [markdown]
# As it can be seen, there are tournaments in this data that are not suitable for our analysis. As explained before, we are not considering Olympics nor World Team Championship. So these observations will be deleted.

# %%
# droping the observations that refer to the tournaments mentioned above

match_scores = match_scores[match_scores['tourney_name'] != 'London Olympics']
match_scores = match_scores[match_scores['tourney_name'] != 'World Team Championship']
match_scores = match_scores[match_scores['tourney_name'] != 'Rio de Janeiro Olympic Games']

# %% [markdown]
# #### Missing values:

# %%
# creating a copy to solve the problems with missing values

match_scores_missing = match_scores.copy()

# %%
# replacing other types of missing values not recognized by pandas with NaN and checking again the number of missing values

match_scores_missing.replace(missing_values, np.nan, inplace = True)
match_scores_missing.isna().sum()
# Out:
# tourney_year_id              0
# tourney_order                0
# tourney_name                 0
# tourney_slug                 0
# start_date                 172
# end_date                   172
# currency                   172
# prize_money                172
# match_index                300
# tourney_round_name           0
# round_order                  0
# winner_name                  0
# winner_player_id             0
# winner_slug                  0
# loser_name                   0
# loser_player_id              0
# loser_slug                   0
# winner_seed              16872
# loser_seed               22131
# match_score_tiebreaks        0
# winner_sets_won            221
# loser_sets_won             221
# winner_games_won           221
# loser_games_won            221
# winner_tiebreaks_won       221
# loser_tiebreaks_won        221
# match_id                     0
# dtype: int64

# %%
# seeing rows with NaNs

match_scores_nans_index = match_scores_missing.isna().any(axis = 1)
match_scores_missing[match_scores_nans_index].T
# Out:
#                                               3      \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS004
# tourney_round_name                   Quarter-Finals
# round_order                                       3
# winner_name                            Andy Roddick
# winner_player_id                               r485
# winner_slug                            andy-roddick
# loser_name                          Richard Gasquet
# loser_player_id                                g628
# loser_slug                          richard-gasquet
# winner_seed                                       1
# loser_seed                                      NaN
# match_score_tiebreaks                      63 76(5)
# winner_sets_won                                 2.0
# loser_sets_won                                  0.0
# winner_games_won                               13.0
# loser_games_won                                 9.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             0.0
# match_id               2010-339-MS004-6-4-r485-g628
#
#                                               4      \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS007
# tourney_round_name                   Quarter-Finals
# round_order                                       3
# winner_name                          Radek Stepanek
# winner_player_id                               s694
# winner_slug                          radek-stepanek
# loser_name                            Wayne Odesnik
# loser_player_id                                o234
# loser_slug                            wayne-odesnik
# winner_seed                                       2
# loser_seed                                      NaN
# match_score_tiebreaks                      76(2) 61
# winner_sets_won                                 2.0
# loser_sets_won                                  0.0
# winner_games_won                               13.0
# loser_games_won                                 7.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             0.0
# match_id               2010-339-MS007-6-3-s694-o234
#
#                                               5      \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS006
# tourney_round_name                   Quarter-Finals
# round_order                                       3
# winner_name                            Gael Monfils
# winner_player_id                               mc65
# winner_slug                            gael-monfils
# loser_name                              James Blake
# loser_player_id                                b676
# loser_slug                              james-blake
# winner_seed                                       3
# loser_seed                                      NaN
# match_score_tiebreaks                      36 63 64
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               15.0
# loser_games_won                                13.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             0.0
# match_id               2010-339-MS006-6-2-mc65-b676
#
#                                               9      \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS013
# tourney_round_name                      Round of 16
# round_order                                       4
# winner_name                            Gael Monfils
# winner_player_id                               mc65
# winner_slug                            gael-monfils
# loser_name                            Florent Serra
# loser_player_id                                s963
# loser_slug                            florent-serra
# winner_seed                                       3
# loser_seed                                      NaN
# match_score_tiebreaks                67(5) 76(5) 61
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               19.0
# loser_games_won                                14.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             1.0
# match_id               2010-339-MS013-5-6-mc65-s963
#
#                                               10     \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS010
# tourney_round_name                      Round of 16
# round_order                                       4
# winner_name                           Tomas Berdych
# winner_player_id                               ba47
# winner_slug                           tomas-berdych
# loser_name                         Marcos Baghdatis
# loser_player_id                                b837
# loser_slug                         marcos-baghdatis
# winner_seed                                       4
# loser_seed                                      NaN
# match_score_tiebreaks                         60 61
# winner_sets_won                                 2.0
# loser_sets_won                                  0.0
# winner_games_won                               12.0
# loser_games_won                                 1.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             0.0
# match_id               2010-339-MS010-5-5-ba47-b837
#
#                                               11     \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS011
# tourney_round_name                      Round of 16
# round_order                                       4
# winner_name                         Thomaz Bellucci
# winner_player_id                               bd20
# winner_slug                         thomaz-bellucci
# loser_name                               Harel Levy
# loser_player_id                                l336
# loser_slug                               harel-levy
# winner_seed                                       8
# loser_seed                                      NaN
# match_score_tiebreaks                      64 46 64
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               16.0
# loser_games_won                                14.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             0.0
# match_id               2010-339-MS011-5-4-bd20-l336
#
#                                               12     \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS012
# tourney_round_name                      Round of 16
# round_order                                       4
# winner_name                             James Blake
# winner_player_id                               b676
# winner_slug                             james-blake
# loser_name                             Marc Gicquel
# loser_player_id                                g436
# loser_slug                             marc-gicquel
# winner_seed                                     NaN
# loser_seed                                      NaN
# match_score_tiebreaks                   63 36 76(8)
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               16.0
# loser_games_won                                15.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             0.0
# match_id               2010-339-MS012-5-3-b676-g436
#
#                                               13     \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS009
# tourney_round_name                      Round of 16
# round_order                                       4
# winner_name                         Richard Gasquet
# winner_player_id                               g628
# winner_slug                         richard-gasquet
# loser_name                            Matthew Ebden
# loser_player_id                                e690
# loser_slug                            matthew-ebden
# winner_seed                                     NaN
# loser_seed                                        Q
# match_score_tiebreaks                         63 64
# winner_sets_won                                 2.0
# loser_sets_won                                  0.0
# winner_games_won                               12.0
# loser_games_won                                 7.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             0.0
# match_id               2010-339-MS009-5-2-g628-e690
#
#                                               14     \
# tourney_year_id                            2010-339
# tourney_order                                     1
# tourney_name                               Brisbane
# tourney_slug                               brisbane
# start_date                      2010-01-03 00:00:00
# end_date                        2010-01-10 00:00:00
# currency                                        USD
# prize_money                                372500.0
# match_index                                   MS014
# tourney_round_name                      Round of 16
# round_order                                       4
# winner_name                           Wayne Odesnik
# winner_player_id                               o234
# winner_slug                           wayne-odesnik
# loser_name                          Alejandro Falla
# loser_player_id                                f444
# loser_slug                          alejandro-falla
# winner_seed                                     NaN
# loser_seed                                      NaN
# match_score_tiebreaks                   67(8) 62 61
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               18.0
# loser_games_won                                10.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             1.0
# match_id               2010-339-MS014-5-1-o234-f444
#
#                                                15     ...  \
# tourney_year_id                             2010-339  ...
# tourney_order                                      1  ...
# tourney_name                                Brisbane  ...
# tourney_slug                                brisbane  ...
# start_date                       2010-01-03 00:00:00  ...
# end_date                         2010-01-10 00:00:00  ...
# currency                                         USD  ...
# prize_money                                 372500.0  ...
# match_index                                    MS016  ...
# tourney_round_name                       Round of 32  ...
# round_order                                        5  ...
# winner_name                             Andy Roddick  ...
# winner_player_id                                r485  ...
# winner_slug                             andy-roddick  ...
# loser_name                              Peter Luczak  ...
# loser_player_id                                 l515  ...
# loser_slug                              peter-luczak  ...
# winner_seed                                        1  ...
# loser_seed                                       NaN  ...
# match_score_tiebreaks                       76(5) 62  ...
# winner_sets_won                                  2.0  ...
# loser_sets_won                                   0.0  ...
# winner_games_won                                13.0  ...
# loser_games_won                                  8.0  ...
# winner_tiebreaks_won                             1.0  ...
# loser_tiebreaks_won                              0.0  ...
# match_id               2010-339-MS016-4-16-r485-l515  ...
#
#                                               42782  \
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS013
# tourney_round_name             2nd Round Qualifying
# round_order                                       7
# winner_name                       Ricardas Berankis
# winner_player_id                               be90
# winner_slug                       ricardas-berankis
# loser_name                            Damir Dzumhur
# loser_player_id                                d923
# loser_slug                            damir-dzumhur
# winner_seed                                     NaN
# loser_seed                                       AL
# match_score_tiebreaks                   63 36 76(4)
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               16.0
# loser_games_won                                15.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             0.0
# match_id               2019-352-QS013-2-3-be90-d923
#
#                                               42783  \
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS008
# tourney_round_name             2nd Round Qualifying
# round_order                                       7
# winner_name                           Jeremy Chardy
# winner_player_id                               ca12
# winner_slug                           jeremy-chardy
# loser_name                          Corentin Moutet
# loser_player_id                                mw02
# loser_slug                          corentin-moutet
# winner_seed                                     NaN
# loser_seed                                       WC
# match_score_tiebreaks                67(2) 76(3) 62
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               19.0
# loser_games_won                                15.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             1.0
# match_id               2019-352-QS008-2-2-ca12-mw02
#
#                                               42784  \
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS011
# tourney_round_name             2nd Round Qualifying
# round_order                                       7
# winner_name                      Yoshihito Nishioka
# winner_player_id                               n732
# winner_slug                      yoshihito-nishioka
# loser_name                            Andreas Seppi
# loser_player_id                                sa93
# loser_slug                            andreas-seppi
# winner_seed                                     NaN
# loser_seed                                      NaN
# match_score_tiebreaks                      63 36 75
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               16.0
# loser_games_won                                14.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             0.0
# match_id               2019-352-QS011-2-1-n732-sa93
#
#                                                42785  \
# tourney_year_id                             2019-352
# tourney_order                                     66
# tourney_name                  ATP Masters 1000 Paris
# tourney_slug                                   paris
# start_date                       2019-10-28 00:00:00
# end_date                         2019-11-03 00:00:00
# currency                                         EUR
# prize_money                                5207405.0
# match_index                                    QS016
# tourney_round_name              1st Round Qualifying
# round_order                                        8
# winner_name                            Jeremy Chardy
# winner_player_id                                ca12
# winner_slug                            jeremy-chardy
# loser_name                      Albert Ramos-Vinolas
# loser_player_id                                 r772
# loser_slug                      albert-ramos-vinolas
# winner_seed                                      NaN
# loser_seed                                         1
# match_score_tiebreaks                          64 64
# winner_sets_won                                  2.0
# loser_sets_won                                   0.0
# winner_games_won                                12.0
# loser_games_won                                  8.0
# winner_tiebreaks_won                             0.0
# loser_tiebreaks_won                              0.0
# match_id               2019-352-QS016-1-12-ca12-r772
#
#                                                42787  \
# tourney_year_id                             2019-352
# tourney_order                                     66
# tourney_name                  ATP Masters 1000 Paris
# tourney_slug                                   paris
# start_date                       2019-10-28 00:00:00
# end_date                         2019-11-03 00:00:00
# currency                                         EUR
# prize_money                                5207405.0
# match_index                                    QS022
# tourney_round_name              1st Round Qualifying
# round_order                                        8
# winner_name                            Andreas Seppi
# winner_player_id                                sa93
# winner_slug                            andreas-seppi
# loser_name                          Alexander Bublik
# loser_player_id                                 bk92
# loser_slug                          alexander-bublik
# winner_seed                                      NaN
# loser_seed                                         4
# match_score_tiebreaks                       76(5) 75
# winner_sets_won                                  2.0
# loser_sets_won                                   0.0
# winner_games_won                                14.0
# loser_games_won                                 11.0
# winner_tiebreaks_won                             1.0
# loser_tiebreaks_won                              0.0
# match_id               2019-352-QS022-1-10-sa93-bk92
#
#                                               42789  \
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS026
# tourney_round_name             1st Round Qualifying
# round_order                                       8
# winner_name                       Ricardas Berankis
# winner_player_id                               be90
# winner_slug                       ricardas-berankis
# loser_name                             John Millman
# loser_player_id                                mh30
# loser_slug                             john-millman
# winner_seed                                     NaN
# loser_seed                                        6
# match_score_tiebreaks                      62 76(1)
# winner_sets_won                                 2.0
# loser_sets_won                                  0.0
# winner_games_won                               13.0
# loser_games_won                                 8.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             0.0
# match_id               2019-352-QS026-1-8-be90-mh30
#
#                                               42792  \
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS019
# tourney_round_name             1st Round Qualifying
# round_order                                       8
# winner_name                          Cameron Norrie
# winner_player_id                               n771
# winner_slug                          cameron-norrie
# loser_name                        Federico Delbonis
# loser_player_id                                d874
# loser_slug                        federico-delbonis
# winner_seed                                       9
# loser_seed                                      NaN
# match_score_tiebreaks                      63 76(4)
# winner_sets_won                                 2.0
# loser_sets_won                                  0.0
# winner_games_won                               13.0
# loser_games_won                                 9.0
# winner_tiebreaks_won                            1.0
# loser_tiebreaks_won                             0.0
# match_id               2019-352-QS019-1-5-n771-d874
#
#                                               42793  \
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS023
# tourney_round_name             1st Round Qualifying
# round_order                                       8
# winner_name                      Yoshihito Nishioka
# winner_player_id                               n732
# winner_slug                      yoshihito-nishioka
# loser_name                          Feliciano Lopez
# loser_player_id                                l397
# loser_slug                          feliciano-lopez
# winner_seed                                     NaN
# loser_seed                                       10
# match_score_tiebreaks                   67(2) 63 62
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               18.0
# loser_games_won                                12.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             1.0
# match_id               2019-352-QS023-1-4-n732-l397
#
#                                               42795  \
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS025
# tourney_round_name             1st Round Qualifying
# round_order                                       8
# winner_name                             Casper Ruud
# winner_player_id                               rh16
# winner_slug                             casper-ruud
# loser_name                              Mikael Ymer
# loser_player_id                                y268
# loser_slug                              mikael-ymer
# winner_seed                                      12
# loser_seed                                      NaN
# match_score_tiebreaks                      64 36 64
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               15.0
# loser_games_won                                14.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             0.0
# match_id               2019-352-QS025-1-2-rh16-y268
#
#                                               42796
# tourney_year_id                            2019-352
# tourney_order                                    66
# tourney_name                 ATP Masters 1000 Paris
# tourney_slug                                  paris
# start_date                      2019-10-28 00:00:00
# end_date                        2019-11-03 00:00:00
# currency                                        EUR
# prize_money                               5207405.0
# match_index                                   QS018
# tourney_round_name             1st Round Qualifying
# round_order                                       8
# winner_name                          Egor Gerasimov
# winner_player_id                               gc89
# winner_slug                          egor-gerasimov
# loser_name                  Roberto Carballes Baena
# loser_player_id                                cf59
# loser_slug                  roberto-carballes-baena
# winner_seed                                      AL
# loser_seed                                      NaN
# match_score_tiebreaks                      57 63 64
# winner_sets_won                                 2.0
# loser_sets_won                                  1.0
# winner_games_won                               17.0
# loser_games_won                                14.0
# winner_tiebreaks_won                            0.0
# loser_tiebreaks_won                             0.0
# match_id               2019-352-QS018-1-1-gc89-cf59
#
# [27 rows x 31151 columns]

# %%
# seeing missing values in the dates variables

match_scores_missing[match_scores_missing['start_date'].isna()]
# Out:
#       tourney_year_id  tourney_order tourney_name tourney_slug start_date  \
# 838          2010-402             13      Memphis      memphis        NaT
# 839          2010-402             13      Memphis      memphis        NaT
# 840          2010-402             13      Memphis      memphis        NaT
# 841          2010-402             13      Memphis      memphis        NaT
# 842          2010-402             13      Memphis      memphis        NaT
# ...               ...            ...          ...          ...        ...
# 14497        2013-402             13      Memphis      memphis        NaT
# 14498        2013-402             13      Memphis      memphis        NaT
# 14499        2013-402             13      Memphis      memphis        NaT
# 14500        2013-402             13      Memphis      memphis        NaT
# 14501        2013-402             13      Memphis      memphis        NaT
#
#       end_date currency  prize_money match_index    tourney_round_name  ...  \
# 838        NaT      NaN          NaN       MS001                Finals  ...
# 839        NaT      NaN          NaN       MS003           Semi-Finals  ...
# 840        NaT      NaN          NaN       MS002           Semi-Finals  ...
# 841        NaT      NaN          NaN       MS004        Quarter-Finals  ...
# 842        NaT      NaN          NaN       MS005        Quarter-Finals  ...
# ...        ...      ...          ...         ...                   ...  ...
# 14497      NaT      NaN          NaN       QS014  1st Round Qualifying  ...
# 14498      NaT      NaN          NaN       QS013  1st Round Qualifying  ...
# 14499      NaT      NaN          NaN       QS011  1st Round Qualifying  ...
# 14500      NaT      NaN          NaN       QS015  1st Round Qualifying  ...
# 14501      NaT      NaN          NaN       QS009  1st Round Qualifying  ...
#
#        winner_seed loser_seed match_score_tiebreaks winner_sets_won  \
# 838              8          6        67(3) 76(5) 63             2.0
# 839              6        NaN              75 46 63             2.0
# 840              8        NaN                 63 64             2.0
# 841              8          1              75 36 61             2.0
# 842            NaN          5           36 63 76(3)             2.0
# ...            ...        ...                   ...             ...
# 14497            4         WC                 63 64             2.0
# 14498            5         WC                 75 61             2.0
# 14499          NaN          6              64 76(3)             2.0
# 14500            7        NaN        76(4) 26 76(4)             2.0
# 14501          NaN          8                 62 61             2.0
#
#       loser_sets_won winner_games_won loser_games_won winner_tiebreaks_won  \
# 838              1.0             19.0            16.0                  1.0
# 839              1.0             17.0            14.0                  0.0
# 840              0.0             12.0             7.0                  0.0
# 841              1.0             16.0            12.0                  0.0
# 842              1.0             16.0            15.0                  1.0
# ...              ...              ...             ...                  ...
# 14497            0.0             12.0             7.0                  0.0
# 14498            0.0             13.0             6.0                  0.0
# 14499            0.0             13.0            10.0                  1.0
# 14500            1.0             16.0            18.0                  2.0
# 14501            0.0             12.0             3.0                  0.0
#
#       loser_tiebreaks_won                      match_id
# 838                   1.0  2010-402-MS001-7-1-q927-i186
# 839                   0.0  2010-402-MS003-6-2-i186-p624
# 840                   0.0  2010-402-MS002-6-1-q927-g858
# 841                   0.0  2010-402-MS004-5-4-q927-r485
# 842                   0.0  2010-402-MS005-5-3-g858-ba47
# ...                   ...                           ...
# 14497                 0.0  2013-402-QS014-1-5-e690-ge61
# 14498                 0.0  2013-402-QS013-1-4-b842-bh02
# 14499                 0.0  2013-402-QS011-1-3-m915-pd07
# 14500                 0.0  2013-402-QS015-1-2-me89-g806
# 14501                 0.0  2013-402-QS009-1-1-y124-kb09
#
# [172 rows x 27 columns]

# %% [markdown]
# We can manually inpute the values that are missing regarding the dates, by seraching on the internet what were the actual dates of the tournaments (they are only 4 tournaments).

# %%
# from https://en.wikipedia.org/wiki/2010_Regions_Morgan_Keegan_Championships_and_the_Cellular_South_Cup
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2010-402', 'start_date'] = pd.to_datetime('2010-02-13')
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2010-402', 'end_date'] = pd.to_datetime('2010-02-21')

# from https://en.wikipedia.org/wiki/2011_Regions_Morgan_Keegan_Championships_and_the_Cellular_South_Cup
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2011-402', 'start_date'] = pd.to_datetime('2011-02-13')
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2011-402', 'end_date'] = pd.to_datetime('2011-02-20')

# from https://en.wikipedia.org/wiki/2012_Regions_Morgan_Keegan_Championships_and_Memphis_International
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2012-402', 'start_date'] = pd.to_datetime('2012-02-17')
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2012-402', 'end_date'] = pd.to_datetime('2012-02-26')

# from https://en.wikipedia.org/wiki/2013_U.S._National_Indoor_Tennis_Championships
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2013-402', 'start_date'] = pd.to_datetime('2013-02-18')
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2013-402', 'end_date'] = pd.to_datetime('2013-02-24')

# %%
# seeing missing values in the doubles winner variable

match_scores_missing[match_scores_missing['prize_money'].isna()]
# Out:
#       tourney_year_id  tourney_order tourney_name tourney_slug start_date  \
# 838          2010-402             13      Memphis      memphis 2010-02-13
# 839          2010-402             13      Memphis      memphis 2010-02-13
# 840          2010-402             13      Memphis      memphis 2010-02-13
# 841          2010-402             13      Memphis      memphis 2010-02-13
# 842          2010-402             13      Memphis      memphis 2010-02-13
# ...               ...            ...          ...          ...        ...
# 14497        2013-402             13      Memphis      memphis 2013-02-18
# 14498        2013-402             13      Memphis      memphis 2013-02-18
# 14499        2013-402             13      Memphis      memphis 2013-02-18
# 14500        2013-402             13      Memphis      memphis 2013-02-18
# 14501        2013-402             13      Memphis      memphis 2013-02-18
#
#         end_date currency  prize_money match_index    tourney_round_name  ...  \
# 838   2010-02-21      NaN          NaN       MS001                Finals  ...
# 839   2010-02-21      NaN          NaN       MS003           Semi-Finals  ...
# 840   2010-02-21      NaN          NaN       MS002           Semi-Finals  ...
# 841   2010-02-21      NaN          NaN       MS004        Quarter-Finals  ...
# 842   2010-02-21      NaN          NaN       MS005        Quarter-Finals  ...
# ...          ...      ...          ...         ...                   ...  ...
# 14497 2013-02-24      NaN          NaN       QS014  1st Round Qualifying  ...
# 14498 2013-02-24      NaN          NaN       QS013  1st Round Qualifying  ...
# 14499 2013-02-24      NaN          NaN       QS011  1st Round Qualifying  ...
# 14500 2013-02-24      NaN          NaN       QS015  1st Round Qualifying  ...
# 14501 2013-02-24      NaN          NaN       QS009  1st Round Qualifying  ...
#
#        winner_seed loser_seed match_score_tiebreaks winner_sets_won  \
# 838              8          6        67(3) 76(5) 63             2.0
# 839              6        NaN              75 46 63             2.0
# 840              8        NaN                 63 64             2.0
# 841              8          1              75 36 61             2.0
# 842            NaN          5           36 63 76(3)             2.0
# ...            ...        ...                   ...             ...
# 14497            4         WC                 63 64             2.0
# 14498            5         WC                 75 61             2.0
# 14499          NaN          6              64 76(3)             2.0
# 14500            7        NaN        76(4) 26 76(4)             2.0
# 14501          NaN          8                 62 61             2.0
#
#       loser_sets_won winner_games_won loser_games_won winner_tiebreaks_won  \
# 838              1.0             19.0            16.0                  1.0
# 839              1.0             17.0            14.0                  0.0
# 840              0.0             12.0             7.0                  0.0
# 841              1.0             16.0            12.0                  0.0
# 842              1.0             16.0            15.0                  1.0
# ...              ...              ...             ...                  ...
# 14497            0.0             12.0             7.0                  0.0
# 14498            0.0             13.0             6.0                  0.0
# 14499            0.0             13.0            10.0                  1.0
# 14500            1.0             16.0            18.0                  2.0
# 14501            0.0             12.0             3.0                  0.0
#
#       loser_tiebreaks_won                      match_id
# 838                   1.0  2010-402-MS001-7-1-q927-i186
# 839                   0.0  2010-402-MS003-6-2-i186-p624
# 840                   0.0  2010-402-MS002-6-1-q927-g858
# 841                   0.0  2010-402-MS004-5-4-q927-r485
# 842                   0.0  2010-402-MS005-5-3-g858-ba47
# ...                   ...                           ...
# 14497                 0.0  2013-402-QS014-1-5-e690-ge61
# 14498                 0.0  2013-402-QS013-1-4-b842-bh02
# 14499                 0.0  2013-402-QS011-1-3-m915-pd07
# 14500                 0.0  2013-402-QS015-1-2-me89-g806
# 14501                 0.0  2013-402-QS009-1-1-y124-kb09
#
# [172 rows x 27 columns]

# %% [markdown]
# After a search it was possible to impute the prize money for these tournaments. And since they are US tournaments, the currency of the prize is 'USD'.

# %%
# https://en.wikipedia.org/wiki/2010_Regions_Morgan_Keegan_Championships_and_the_Cellular_South_Cup
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2010-402', 'prize_money'] = 1226500
# https://www.memphisdailynews.com/news/2011/feb/14/memphis-aces//print
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2011-402', 'prize_money'] = 1226500
# https://oncourtadvantage.com/eye-on-the-tour/memphis-open-tennis-2012/
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2012-402', 'prize_money'] = 1281500
# https://en.wikipedia.org/wiki/2013_U.S._National_Indoor_Tennis_Championships
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2013-402', 'prize_money'] = 1353550

match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2010-402', 'currency'] = 'USD'
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2011-402', 'currency'] = 'USD'
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2012-402', 'currency'] = 'USD'
match_scores_missing.loc[match_scores_missing['tourney_year_id'] == '2013-402', 'currency'] = 'USD'

# %% [markdown]
# Regarding the missing values on `match_index`, since it is a variable that is not important for our analysis, it will be deleted.
#
# As for the seeds variables, as explained before, it is normal to have observations with missing values. Therefore the missing values will be imputed with '*not applicable*'.

# %%
# dropping the march_index variable
match_scores_missing.drop('match_index', axis = 1, inplace = True)

# inputing the missing values on the seeds variables
match_scores_missing['winner_seed'].fillna('Not applicable', inplace = True)
match_scores_missing['loser_seed'].fillna('Not applicable', inplace = True)

# %%
# seeing missing values in the doubles winner variable

match_scores_missing[match_scores_missing['winner_sets_won'].isna()]
# Out:
#       tourney_year_id  tourney_order            tourney_name     tourney_slug  \
# 89           2010-451              2                    Doha             doha
# 298          2010-580              6         Australian Open  australian-open
# 552         2010-5012              7            Johannesburg     johannesburg
# 682          2010-407             10               Rotterdam        rotterdam
# 942          2010-506             15            Buenos Aires     buenos-aires
# ...               ...            ...                     ...              ...
# 42009        2019-560             52                 US Open          us-open
# 42404        2019-747             58                 Beijing          beijing
# 42692        2019-328             65                   Basel            basel
# 42721        2019-328             65                   Basel            basel
# 42734        2019-352             66  ATP Masters 1000 Paris            paris
#
#       start_date   end_date currency  prize_money    tourney_round_name  \
# 89    2010-01-04 2010-01-09      USD    1024000.0  2nd Round Qualifying
# 298   2010-01-18 2010-01-31      AUD   11048640.0           Round of 32
# 552   2010-02-01 2010-02-07      USD     442500.0  2nd Round Qualifying
# 682   2010-02-08 2010-02-14      EUR    1150000.0        Quarter-Finals
# 942   2010-02-15 2010-02-21      USD     475300.0        Quarter-Finals
# ...          ...        ...      ...          ...                   ...
# 42009 2019-08-26 2019-09-08      USD   28619350.0           Round of 64
# 42404 2019-09-30 2019-10-06      USD    3515225.0  1st Round Qualifying
# 42692 2019-10-21 2019-10-27      EUR    2082655.0        Quarter-Finals
# 42721 2019-10-21 2019-10-27      EUR    2082655.0  2nd Round Qualifying
# 42734 2019-10-28 2019-11-03      EUR    5207405.0           Semi-Finals
#
#        round_order  ...     winner_seed      loser_seed match_score_tiebreaks  \
# 89               7  ...               2  Not applicable                 (W/O)
# 298              5  ...  Not applicable              20                 (W/O)
# 552              7  ...               8  Not applicable                 (W/O)
# 682              3  ...               1  Not applicable                 (W/O)
# 942              3  ...               5  Not applicable                 (W/O)
# ...            ...  ...             ...             ...                   ...
# 42009            6  ...  Not applicable              12                 (W/O)
# 42404            7  ...  Not applicable               3                 (W/O)
# 42692            3  ...               1               7                 (W/O)
# 42721            6  ...               3               6                 (W/O)
# 42734            2  ...  Not applicable               2                 (W/O)
#
#       winner_sets_won loser_sets_won winner_games_won loser_games_won  \
# 89                NaN            NaN              NaN             NaN
# 298               NaN            NaN              NaN             NaN
# 552               NaN            NaN              NaN             NaN
# 682               NaN            NaN              NaN             NaN
# 942               NaN            NaN              NaN             NaN
# ...               ...            ...              ...             ...
# 42009             NaN            NaN              NaN             NaN
# 42404             NaN            NaN              NaN             NaN
# 42692             NaN            NaN              NaN             NaN
# 42721             NaN            NaN              NaN             NaN
# 42734             NaN            NaN              NaN             NaN
#
#       winner_tiebreaks_won loser_tiebreaks_won                      match_id
# 89                     NaN                 NaN   2010-451-NULL-2-7-b804-l480
# 298                    NaN                 NaN   2010-580-NULL-6-4-k540-y061
# 552                    NaN                 NaN  2010-5012-NULL-2-1-w421-bc35
# 682                    NaN                 NaN   2010-407-NULL-5-4-d643-mb02
# 942                    NaN                 NaN   2010-506-NULL-6-1-m824-n301
# ...                    ...                 ...                           ...
# 42009                  NaN                 NaN  2019-560-NULL-5-26-d875-cg80
# 42404                  NaN                 NaN   2019-747-NULL-1-6-ta46-f724
# 42692                  NaN                 NaN   2019-328-NULL-5-4-f324-w367
# 42721                  NaN                 NaN   2019-328-NULL-2-3-be90-bk24
# 42734                  NaN                 NaN   2019-352-NULL-7-1-su55-n409
#
# [221 rows x 26 columns]

# %% [markdown]
# As it can be seen, the missing values in the tiebreaks, sets, and games statistics are due to the match score: W/O. A walkover occurs when one player wins a match without having to play any points, games, or sets. This can happen when the opponent of a player withdraws from the match before it begins, or is unable to continue playing during the match due to injury, illness, or other reasons. So, the missing values are normal, therefore will be inputed as 0.

# %%
# inputing the missing values on the match statistics variables

match_scores_missing.loc[match_scores_missing['winner_sets_won'].isna(), ['winner_sets_won', 'loser_sets_won', 'winner_games_won', 'loser_games_won', 'winner_tiebreaks_won', 'loser_tiebreaks_won']] = 0

# %%
# checking that there are no more missing values

match_scores_missing.isna().sum()
# Out:
# tourney_year_id          0
# tourney_order            0
# tourney_name             0
# tourney_slug             0
# start_date               0
# end_date                 0
# currency                 0
# prize_money              0
# tourney_round_name       0
# round_order              0
# winner_name              0
# winner_player_id         0
# winner_slug              0
# loser_name               0
# loser_player_id          0
# loser_slug               0
# winner_seed              0
# loser_seed               0
# match_score_tiebreaks    0
# winner_sets_won          0
# loser_sets_won           0
# winner_games_won         0
# loser_games_won          0
# winner_tiebreaks_won     0
# loser_tiebreaks_won      0
# match_id                 0
# dtype: int64

# %%
# keeping the dataframe without missing values

match_scores = match_scores_missing.copy()

# %% [markdown]
# Having the year can be useful, so a new variable called `tourney_year` will be created.

# %%
# creating variable 'tourney_year'

match_scores['tourney_year'] = match_scores['tourney_year_id'].str[:4].astype('int32')

# %% [markdown]
# Also, since we will need the players that play together the most, a new column will be added, that combines the winner and loser names in alphabetical order.

# %%
# creating variable 'pair'

match_scores['pair'] = match_scores.apply(lambda row: '-'.join(sorted([row['winner_name'], row['loser_name']])), axis = 1)

# %% [markdown]
# #### Solving the currency problem:

# %%
# checking the different currencies present in the dataset

match_scores['currency'].value_counts()
# Out:
# USD    19618
# EUR    18223
# AUD     2390
# GBP     2390
# Name: currency, dtype: int64

# %%
# using the same dataframe with the exchange rates defined before

# merging the tournaments dataframe with the exchange rate dataframe
merged_match_scores = match_scores.merge(exchange_rate, on = 'currency')

# creating a new column in the merged dataframe with the TFC in US dollars, by multiplying the value with the exchange rate
merged_match_scores['prize_money_USD'] = merged_match_scores['prize_money'] * merged_match_scores['exchange_rate']

# drop the currency and exchange rate columns, as they are no longer needed
merged_match_scores.drop(['currency', 'exchange_rate', 'prize_money'], axis = 1, inplace = True)

# sorting by ascending order regarding variable date
merged_match_scores.sort_index(inplace = True)

# %%
# keeping the changes for the currencies in the original dataset

match_scores = merged_match_scores.copy()

# %%
match_scores
# Out:
#       tourney_year_id  tourney_order tourney_name tourney_slug start_date  \
# 0            2010-339              1     Brisbane     brisbane 2010-01-03
# 1            2010-339              1     Brisbane     brisbane 2010-01-03
# 2            2010-339              1     Brisbane     brisbane 2010-01-03
# 3            2010-339              1     Brisbane     brisbane 2010-01-03
# 4            2010-339              1     Brisbane     brisbane 2010-01-03
# ...               ...            ...          ...          ...        ...
# 42616        2019-540             39    Wimbledon    wimbledon 2019-07-01
# 42617        2019-540             39    Wimbledon    wimbledon 2019-07-01
# 42618        2019-540             39    Wimbledon    wimbledon 2019-07-01
# 42619        2019-540             39    Wimbledon    wimbledon 2019-07-01
# 42620        2019-540             39    Wimbledon    wimbledon 2019-07-01
#
#         end_date    tourney_round_name  round_order        winner_name  \
# 0     2010-01-10                Finals            1       Andy Roddick
# 1     2010-01-10           Semi-Finals            2       Andy Roddick
# 2     2010-01-10           Semi-Finals            2     Radek Stepanek
# 3     2010-01-10        Quarter-Finals            3       Andy Roddick
# 4     2010-01-10        Quarter-Finals            3     Radek Stepanek
# ...          ...                   ...          ...                ...
# 42616 2019-07-14  1st Round Qualifying           10           Go Soeda
# 42617 2019-07-14  1st Round Qualifying           10      Yuichi Sugita
# 42618 2019-07-14  1st Round Qualifying           10  Mikael Torpegaard
# 42619 2019-07-14  1st Round Qualifying           10  Yasutaka Uchiyama
# 42620 2019-07-14  1st Round Qualifying           10       Donald Young
#
#       winner_player_id  ... winner_sets_won loser_sets_won winner_games_won  \
# 0                 r485  ...             2.0            0.0             14.0
# 1                 r485  ...             2.0            1.0             13.0
# 2                 s694  ...             2.0            0.0             12.0
# 3                 r485  ...             2.0            0.0             13.0
# 4                 s694  ...             2.0            0.0             13.0
# ...                ...  ...             ...            ...              ...
# 42616             sc47  ...             2.0            1.0             15.0
# 42617             se73  ...             2.0            0.0             12.0
# 42618             tc12  ...             2.0            1.0             17.0
# 42619             u134  ...             2.0            0.0             13.0
# 42620             y124  ...             2.0            0.0             13.0
#
#       loser_games_won winner_tiebreaks_won loser_tiebreaks_won  \
# 0                12.0                  2.0                 0.0
# 1                13.0                  0.0                 0.0
# 2                 3.0                  0.0                 0.0
# 3                 9.0                  1.0                 0.0
# 4                 7.0                  1.0                 0.0
# ...               ...                  ...                 ...
# 42616            11.0                  0.0                 0.0
# 42617             6.0                  0.0                 0.0
# 42618            15.0                  1.0                 0.0
# 42619            10.0                  1.0                 0.0
# 42620            10.0                  1.0                 0.0
#
#                            match_id  tourney_year  \
# 0      2010-339-MS001-8-1-r485-s694          2010
# 1      2010-339-MS002-7-2-r485-ba47          2010
# 2      2010-339-MS003-7-1-s694-mc65          2010
# 3      2010-339-MS004-6-4-r485-g628          2010
# 4      2010-339-MS007-6-3-s694-o234          2010
# ...                             ...           ...
# 42616  2019-540-QS086-1-5-sc47-bm03          2019
# 42617  2019-540-QS121-1-4-se73-b884          2019
# 42618  2019-540-QS090-1-3-tc12-mm66          2019
# 42619  2019-540-QS070-1-2-u134-d0co          2019
# 42620  2019-540-QS126-1-1-y124-gc89          2019
#
#                                      pair  prize_money_USD
# 0             Andy Roddick-Radek Stepanek         372500.0
# 1              Andy Roddick-Tomas Berdych         372500.0
# 2             Gael Monfils-Radek Stepanek         372500.0
# 3            Andy Roddick-Richard Gasquet         372500.0
# 4            Radek Stepanek-Wayne Odesnik         372500.0
# ...                                   ...              ...
# 42616              Filippo Baldi-Go Soeda       21383214.6
# 42617        Carlos Berlocq-Yuichi Sugita       21383214.6
# 42618  Mikael Torpegaard-Nikola Milojevic       21383214.6
# 42619       Jack Draper-Yasutaka Uchiyama       21383214.6
# 42620         Donald Young-Egor Gerasimov       21383214.6
#
# [42621 rows x 27 columns]

# %% [markdown]
# <a id = "understanding-preparation-match-stats"></a>
#
# ## 4. Data understanding and preparation - Match Stats dataset
#
# [Back to TOC](#toc)

# %%
match_stats.T
# Out:
#                                                                               0      \
# match_id                                               2010-339-MS001-8-1-r485-s694
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS001/match-stats?isLive=F...
# match_time                                                                 02:05:00
# match_duration                                                                125.0
# winner_slug                                                                    r485
# winner_serve_rating                                                           304.0
# winner_aces                                                                     7.0
# winner_double_faults                                                            1.0
# winner_first_serves_in                                                         64.0
# winner_first_serves_total                                                      83.0
# winner_first_serve_points_won                                                  45.0
# winner_first_serve_points_total                                                64.0
# winner_second_serve_points_won                                                 13.0
# winner_second_serve_points_total                                               19.0
# winner_break_points_saved                                                       3.0
# winner_break_points_serve_total                                                 5.0
# winner_service_games_played                                                    12.0
# winner_return_rating                                                          119.0
# winner_first_serve_return_won                                                  18.0
# winner_first_serve_return_total                                                56.0
# winner_second_serve_return_won                                                 18.0
# winner_second_serve_return_total                                               39.0
# winner_break_points_converted                                                   2.0
# winner_break_points_return_total                                                8.0
# winner_return_games_played                                                     12.0
# winner_service_points_won                                                      58.0
# winner_service_points_total                                                    83.0
# winner_return_points_won                                                       36.0
# winner_return_points_total                                                     95.0
# winner_total_points_won                                                        94.0
# winner_total_points_total                                                     178.0
# loser_slug                                                                     s694
# loser_serve_rating                                                            261.0
# loser_aces                                                                      5.0
# loser_double_faults                                                             8.0
# loser_first_serves_in                                                          56.0
# loser_first_serves_total                                                       95.0
# loser_first_serve_points_won                                                   38.0
# loser_first_serve_points_total                                                 56.0
# loser_second_serve_points_won                                                  21.0
# loser_second_serve_points_total                                                39.0
# loser_break_points_saved                                                        6.0
# loser_break_points_serve_total                                                  8.0
# loser_service_games_played                                                     12.0
# loser_return_rating                                                           118.0
# loser_first_serve_return_won                                                   19.0
# loser_first_serve_return_total                                                 64.0
# loser_second_serve_return_won                                                   6.0
# loser_second_serve_return_total                                                19.0
# loser_break_points_converted                                                    2.0
# loser_break_points_return_total                                                 5.0
# loser_return_games_played                                                      12.0
# loser_service_points_won                                                       59.0
# loser_service_points_total                                                     95.0
# loser_return_points_won                                                        25.0
# loser_return_points_total                                                      83.0
# loser_total_points_won                                                         84.0
# loser_total_points_total                                                      178.0
#
#                                                                               1      \
# match_id                                               2010-339-MS002-7-2-r485-ba47
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS002/match-stats?isLive=F...
# match_time                                                                 02:08:00
# match_duration                                                                128.0
# winner_slug                                                                    r485
# winner_serve_rating                                                           288.0
# winner_aces                                                                     7.0
# winner_double_faults                                                            1.0
# winner_first_serves_in                                                         60.0
# winner_first_serves_total                                                      81.0
# winner_first_serve_points_won                                                  43.0
# winner_first_serve_points_total                                                60.0
# winner_second_serve_points_won                                                 11.0
# winner_second_serve_points_total                                               21.0
# winner_break_points_saved                                                       4.0
# winner_break_points_serve_total                                                 6.0
# winner_service_games_played                                                    13.0
# winner_return_rating                                                          106.0
# winner_first_serve_return_won                                                   9.0
# winner_first_serve_return_total                                                43.0
# winner_second_serve_return_won                                                 24.0
# winner_second_serve_return_total                                               45.0
# winner_break_points_converted                                                   2.0
# winner_break_points_return_total                                               12.0
# winner_return_games_played                                                     13.0
# winner_service_points_won                                                      54.0
# winner_service_points_total                                                    81.0
# winner_return_points_won                                                       33.0
# winner_return_points_total                                                     88.0
# winner_total_points_won                                                        87.0
# winner_total_points_total                                                     169.0
# loser_slug                                                                     ba47
# loser_serve_rating                                                            269.0
# loser_aces                                                                     12.0
# loser_double_faults                                                             2.0
# loser_first_serves_in                                                          43.0
# loser_first_serves_total                                                       88.0
# loser_first_serve_points_won                                                   34.0
# loser_first_serve_points_total                                                 43.0
# loser_second_serve_points_won                                                  21.0
# loser_second_serve_points_total                                                45.0
# loser_break_points_saved                                                       10.0
# loser_break_points_serve_total                                                 12.0
# loser_service_games_played                                                     13.0
# loser_return_rating                                                           124.0
# loser_first_serve_return_won                                                   17.0
# loser_first_serve_return_total                                                 60.0
# loser_second_serve_return_won                                                  10.0
# loser_second_serve_return_total                                                21.0
# loser_break_points_converted                                                    2.0
# loser_break_points_return_total                                                 6.0
# loser_return_games_played                                                      13.0
# loser_service_points_won                                                       55.0
# loser_service_points_total                                                     88.0
# loser_return_points_won                                                        27.0
# loser_return_points_total                                                      81.0
# loser_total_points_won                                                         82.0
# loser_total_points_total                                                      169.0
#
#                                                                               2      \
# match_id                                               2010-339-MS003-7-1-s694-mc65
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS003/match-stats?isLive=F...
# match_time                                                                 01:01:00
# match_duration                                                                 61.0
# winner_slug                                                                    s694
# winner_serve_rating                                                           309.0
# winner_aces                                                                     3.0
# winner_double_faults                                                            0.0
# winner_first_serves_in                                                         31.0
# winner_first_serves_total                                                      50.0
# winner_first_serve_points_won                                                  20.0
# winner_first_serve_points_total                                                31.0
# winner_second_serve_points_won                                                 15.0
# winner_second_serve_points_total                                               19.0
# winner_break_points_saved                                                       1.0
# winner_break_points_serve_total                                                 1.0
# winner_service_games_played                                                     8.0
# winner_return_rating                                                          223.0
# winner_first_serve_return_won                                                  13.0
# winner_first_serve_return_total                                                27.0
# winner_second_serve_return_won                                                 11.0
# winner_second_serve_return_total                                               18.0
# winner_break_points_converted                                                   4.0
# winner_break_points_return_total                                                7.0
# winner_return_games_played                                                      7.0
# winner_service_points_won                                                      35.0
# winner_service_points_total                                                    50.0
# winner_return_points_won                                                       24.0
# winner_return_points_total                                                     45.0
# winner_total_points_won                                                        59.0
# winner_total_points_total                                                      95.0
# loser_slug                                                                     mc65
# loser_serve_rating                                                            191.0
# loser_aces                                                                      1.0
# loser_double_faults                                                             3.0
# loser_first_serves_in                                                          27.0
# loser_first_serves_total                                                       45.0
# loser_first_serve_points_won                                                   14.0
# loser_first_serve_points_total                                                 27.0
# loser_second_serve_points_won                                                   7.0
# loser_second_serve_points_total                                                18.0
# loser_break_points_saved                                                        3.0
# loser_break_points_serve_total                                                  7.0
# loser_service_games_played                                                      7.0
# loser_return_rating                                                            56.0
# loser_first_serve_return_won                                                   11.0
# loser_first_serve_return_total                                                 31.0
# loser_second_serve_return_won                                                   4.0
# loser_second_serve_return_total                                                19.0
# loser_break_points_converted                                                    0.0
# loser_break_points_return_total                                                 1.0
# loser_return_games_played                                                       8.0
# loser_service_points_won                                                       21.0
# loser_service_points_total                                                     45.0
# loser_return_points_won                                                        15.0
# loser_return_points_total                                                      50.0
# loser_total_points_won                                                         36.0
# loser_total_points_total                                                       95.0
#
#                                                                               3      \
# match_id                                               2010-339-MS004-6-4-r485-g628
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS004/match-stats?isLive=F...
# match_time                                                                 01:25:00
# match_duration                                                                 85.0
# winner_slug                                                                    r485
# winner_serve_rating                                                           344.0
# winner_aces                                                                    16.0
# winner_double_faults                                                            1.0
# winner_first_serves_in                                                         45.0
# winner_first_serves_total                                                      60.0
# winner_first_serve_points_won                                                  39.0
# winner_first_serve_points_total                                                45.0
# winner_second_serve_points_won                                                 10.0
# winner_second_serve_points_total                                               15.0
# winner_break_points_saved                                                       0.0
# winner_break_points_serve_total                                                 0.0
# winner_service_games_played                                                    11.0
# winner_return_rating                                                           93.0
# winner_first_serve_return_won                                                   7.0
# winner_first_serve_return_total                                                38.0
# winner_second_serve_return_won                                                 15.0
# winner_second_serve_return_total                                               29.0
# winner_break_points_converted                                                   1.0
# winner_break_points_return_total                                                8.0
# winner_return_games_played                                                     10.0
# winner_service_points_won                                                      49.0
# winner_service_points_total                                                    60.0
# winner_return_points_won                                                       22.0
# winner_return_points_total                                                     67.0
# winner_total_points_won                                                        71.0
# winner_total_points_total                                                     127.0
# loser_slug                                                                     g628
# loser_serve_rating                                                            281.0
# loser_aces                                                                      6.0
# loser_double_faults                                                             2.0
# loser_first_serves_in                                                          38.0
# loser_first_serves_total                                                       67.0
# loser_first_serve_points_won                                                   31.0
# loser_first_serve_points_total                                                 38.0
# loser_second_serve_points_won                                                  14.0
# loser_second_serve_points_total                                                29.0
# loser_break_points_saved                                                        7.0
# loser_break_points_serve_total                                                  8.0
# loser_service_games_played                                                     10.0
# loser_return_rating                                                            46.0
# loser_first_serve_return_won                                                    6.0
# loser_first_serve_return_total                                                 45.0
# loser_second_serve_return_won                                                   5.0
# loser_second_serve_return_total                                                15.0
# loser_break_points_converted                                                    0.0
# loser_break_points_return_total                                                 0.0
# loser_return_games_played                                                      11.0
# loser_service_points_won                                                       45.0
# loser_service_points_total                                                     67.0
# loser_return_points_won                                                        11.0
# loser_return_points_total                                                      60.0
# loser_total_points_won                                                         56.0
# loser_total_points_total                                                      127.0
#
#                                                                               4      \
# match_id                                               2010-339-MS007-6-3-s694-o234
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS007/match-stats?isLive=F...
# match_time                                                                 01:40:00
# match_duration                                                                100.0
# winner_slug                                                                    s694
# winner_serve_rating                                                           279.0
# winner_aces                                                                     7.0
# winner_double_faults                                                            4.0
# winner_first_serves_in                                                         33.0
# winner_first_serves_total                                                      61.0
# winner_first_serve_points_won                                                  24.0
# winner_first_serve_points_total                                                33.0
# winner_second_serve_points_won                                                 17.0
# winner_second_serve_points_total                                               28.0
# winner_break_points_saved                                                       1.0
# winner_break_points_serve_total                                                 2.0
# winner_service_games_played                                                     9.0
# winner_return_rating                                                          180.0
# winner_first_serve_return_won                                                  15.0
# winner_first_serve_return_total                                                40.0
# winner_second_serve_return_won                                                 18.0
# winner_second_serve_return_total                                               29.0
# winner_break_points_converted                                                   4.0
# winner_break_points_return_total                                               10.0
# winner_return_games_played                                                     10.0
# winner_service_points_won                                                      41.0
# winner_service_points_total                                                    61.0
# winner_return_points_won                                                       33.0
# winner_return_points_total                                                     69.0
# winner_total_points_won                                                        74.0
# winner_total_points_total                                                     130.0
# loser_slug                                                                     o234
# loser_serve_rating                                                            219.0
# loser_aces                                                                      3.0
# loser_double_faults                                                             3.0
# loser_first_serves_in                                                          40.0
# loser_first_serves_total                                                       69.0
# loser_first_serve_points_won                                                   25.0
# loser_first_serve_points_total                                                 40.0
# loser_second_serve_points_won                                                  11.0
# loser_second_serve_points_total                                                29.0
# loser_break_points_saved                                                        6.0
# loser_break_points_serve_total                                                 10.0
# loser_service_games_played                                                     10.0
# loser_return_rating                                                           127.0
# loser_first_serve_return_won                                                    9.0
# loser_first_serve_return_total                                                 33.0
# loser_second_serve_return_won                                                  11.0
# loser_second_serve_return_total                                                28.0
# loser_break_points_converted                                                    1.0
# loser_break_points_return_total                                                 2.0
# loser_return_games_played                                                       9.0
# loser_service_points_won                                                       36.0
# loser_service_points_total                                                     69.0
# loser_return_points_won                                                        20.0
# loser_return_points_total                                                      61.0
# loser_total_points_won                                                         56.0
# loser_total_points_total                                                      130.0
#
#                                                                               5      \
# match_id                                               2010-339-MS006-6-2-mc65-b676
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS006/match-stats?isLive=F...
# match_time                                                                 01:44:00
# match_duration                                                                104.0
# winner_slug                                                                    mc65
# winner_serve_rating                                                           281.0
# winner_aces                                                                    13.0
# winner_double_faults                                                            4.0
# winner_first_serves_in                                                         55.0
# winner_first_serves_total                                                      90.0
# winner_first_serve_points_won                                                  41.0
# winner_first_serve_points_total                                                55.0
# winner_second_serve_points_won                                                 18.0
# winner_second_serve_points_total                                               35.0
# winner_break_points_saved                                                       7.0
# winner_break_points_serve_total                                                 9.0
# winner_service_games_played                                                    14.0
# winner_return_rating                                                          150.0
# winner_first_serve_return_won                                                  12.0
# winner_first_serve_return_total                                                50.0
# winner_second_serve_return_won                                                 21.0
# winner_second_serve_return_total                                               38.0
# winner_break_points_converted                                                   3.0
# winner_break_points_return_total                                                6.0
# winner_return_games_played                                                     14.0
# winner_service_points_won                                                      59.0
# winner_service_points_total                                                    90.0
# winner_return_points_won                                                       33.0
# winner_return_points_total                                                     88.0
# winner_total_points_won                                                        92.0
# winner_total_points_total                                                     178.0
# loser_slug                                                                     b676
# loser_serve_rating                                                            255.0
# loser_aces                                                                      4.0
# loser_double_faults                                                             5.0
# loser_first_serves_in                                                          50.0
# loser_first_serves_total                                                       88.0
# loser_first_serve_points_won                                                   38.0
# loser_first_serve_points_total                                                 50.0
# loser_second_serve_points_won                                                  17.0
# loser_second_serve_points_total                                                38.0
# loser_break_points_saved                                                        3.0
# loser_break_points_serve_total                                                  6.0
# loser_service_games_played                                                     14.0
# loser_return_rating                                                           110.0
# loser_first_serve_return_won                                                   14.0
# loser_first_serve_return_total                                                 55.0
# loser_second_serve_return_won                                                  17.0
# loser_second_serve_return_total                                                35.0
# loser_break_points_converted                                                    2.0
# loser_break_points_return_total                                                 9.0
# loser_return_games_played                                                      14.0
# loser_service_points_won                                                       55.0
# loser_service_points_total                                                     88.0
# loser_return_points_won                                                        31.0
# loser_return_points_total                                                      90.0
# loser_total_points_won                                                         86.0
# loser_total_points_total                                                      178.0
#
#                                                                               6      \
# match_id                                               2010-339-MS005-6-1-ba47-bd20
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS005/match-stats?isLive=F...
# match_time                                                                 02:42:00
# match_duration                                                                162.0
# winner_slug                                                                    ba47
# winner_serve_rating                                                           285.0
# winner_aces                                                                    12.0
# winner_double_faults                                                            2.0
# winner_first_serves_in                                                         59.0
# winner_first_serves_total                                                      99.0
# winner_first_serve_points_won                                                  45.0
# winner_first_serve_points_total                                                59.0
# winner_second_serve_points_won                                                 23.0
# winner_second_serve_points_total                                               40.0
# winner_break_points_saved                                                       3.0
# winner_break_points_serve_total                                                 6.0
# winner_service_games_played                                                    16.0
# winner_return_rating                                                          112.0
# winner_first_serve_return_won                                                  16.0
# winner_first_serve_return_total                                                62.0
# winner_second_serve_return_won                                                 24.0
# winner_second_serve_return_total                                               51.0
# winner_break_points_converted                                                   1.0
# winner_break_points_return_total                                                3.0
# winner_return_games_played                                                     16.0
# winner_service_points_won                                                      68.0
# winner_service_points_total                                                    99.0
# winner_return_points_won                                                       40.0
# winner_return_points_total                                                    113.0
# winner_total_points_won                                                       108.0
# winner_total_points_total                                                     212.0
# loser_slug                                                                     bd20
# loser_serve_rating                                                            278.0
# loser_aces                                                                      8.0
# loser_double_faults                                                             5.0
# loser_first_serves_in                                                          62.0
# loser_first_serves_total                                                      113.0
# loser_first_serve_points_won                                                   46.0
# loser_first_serve_points_total                                                 62.0
# loser_second_serve_points_won                                                  27.0
# loser_second_serve_points_total                                                51.0
# loser_break_points_saved                                                        2.0
# loser_break_points_serve_total                                                  3.0
# loser_service_games_played                                                     16.0
# loser_return_rating                                                           135.0
# loser_first_serve_return_won                                                   14.0
# loser_first_serve_return_total                                                 59.0
# loser_second_serve_return_won                                                  17.0
# loser_second_serve_return_total                                                40.0
# loser_break_points_converted                                                    3.0
# loser_break_points_return_total                                                 6.0
# loser_return_games_played                                                      16.0
# loser_service_points_won                                                       73.0
# loser_service_points_total                                                    113.0
# loser_return_points_won                                                        31.0
# loser_return_points_total                                                      99.0
# loser_total_points_won                                                        104.0
# loser_total_points_total                                                      212.0
#
#                                                                               7      \
# match_id                                               2010-339-MS008-5-8-r485-bd59
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS008/match-stats?isLive=F...
# match_time                                                                 01:21:00
# match_duration                                                                 81.0
# winner_slug                                                                    r485
# winner_serve_rating                                                           356.0
# winner_aces                                                                     9.0
# winner_double_faults                                                            0.0
# winner_first_serves_in                                                         49.0
# winner_first_serves_total                                                      59.0
# winner_first_serve_points_won                                                  41.0
# winner_first_serve_points_total                                                49.0
# winner_second_serve_points_won                                                  8.0
# winner_second_serve_points_total                                               10.0
# winner_break_points_saved                                                       1.0
# winner_break_points_serve_total                                                 1.0
# winner_service_games_played                                                    11.0
# winner_return_rating                                                           95.0
# winner_first_serve_return_won                                                  10.0
# winner_first_serve_return_total                                                36.0
# winner_second_serve_return_won                                                 14.0
# winner_second_serve_return_total                                               32.0
# winner_break_points_converted                                                   1.0
# winner_break_points_return_total                                                8.0
# winner_return_games_played                                                     10.0
# winner_service_points_won                                                      49.0
# winner_service_points_total                                                    59.0
# winner_return_points_won                                                       24.0
# winner_return_points_total                                                     68.0
# winner_total_points_won                                                        73.0
# winner_total_points_total                                                     127.0
# loser_slug                                                                     bd59
# loser_serve_rating                                                            276.0
# loser_aces                                                                      8.0
# loser_double_faults                                                             3.0
# loser_first_serves_in                                                          36.0
# loser_first_serves_total                                                       68.0
# loser_first_serve_points_won                                                   26.0
# loser_first_serve_points_total                                                 36.0
# loser_second_serve_points_won                                                  18.0
# loser_second_serve_points_total                                                32.0
# loser_break_points_saved                                                        7.0
# loser_break_points_serve_total                                                  8.0
# loser_service_games_played                                                     10.0
# loser_return_rating                                                            36.0
# loser_first_serve_return_won                                                    8.0
# loser_first_serve_return_total                                                 49.0
# loser_second_serve_return_won                                                   2.0
# loser_second_serve_return_total                                                10.0
# loser_break_points_converted                                                    0.0
# loser_break_points_return_total                                                 1.0
# loser_return_games_played                                                      11.0
# loser_service_points_won                                                       44.0
# loser_service_points_total                                                     68.0
# loser_return_points_won                                                        10.0
# loser_return_points_total                                                      59.0
# loser_total_points_won                                                         54.0
# loser_total_points_total                                                      127.0
#
#                                                                               8      \
# match_id                                               2010-339-MS015-5-7-s694-d801
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS015/match-stats?isLive=F...
# match_time                                                                 02:20:00
# match_duration                                                                140.0
# winner_slug                                                                    s694
# winner_serve_rating                                                           273.0
# winner_aces                                                                    11.0
# winner_double_faults                                                            7.0
# winner_first_serves_in                                                         70.0
# winner_first_serves_total                                                     108.0
# winner_first_serve_points_won                                                  53.0
# winner_first_serve_points_total                                                70.0
# winner_second_serve_points_won                                                 18.0
# winner_second_serve_points_total                                               38.0
# winner_break_points_saved                                                       4.0
# winner_break_points_serve_total                                                 7.0
# winner_service_games_played                                                    16.0
# winner_return_rating                                                          148.0
# winner_first_serve_return_won                                                   9.0
# winner_first_serve_return_total                                                49.0
# winner_second_serve_return_won                                                 27.0
# winner_second_serve_return_total                                               49.0
# winner_break_points_converted                                                   4.0
# winner_break_points_return_total                                                8.0
# winner_return_games_played                                                     16.0
# winner_service_points_won                                                      71.0
# winner_service_points_total                                                   108.0
# winner_return_points_won                                                       36.0
# winner_return_points_total                                                     98.0
# winner_total_points_won                                                       107.0
# winner_total_points_total                                                     206.0
# loser_slug                                                                     d801
# loser_serve_rating                                                            255.0
# loser_aces                                                                      9.0
# loser_double_faults                                                             6.0
# loser_first_serves_in                                                          49.0
# loser_first_serves_total                                                       98.0
# loser_first_serve_points_won                                                   40.0
# loser_first_serve_points_total                                                 49.0
# loser_second_serve_points_won                                                  22.0
# loser_second_serve_points_total                                                49.0
# loser_break_points_saved                                                        4.0
# loser_break_points_serve_total                                                  8.0
# loser_service_games_played                                                     16.0
# loser_return_rating                                                           138.0
# loser_first_serve_return_won                                                   17.0
# loser_first_serve_return_total                                                 70.0
# loser_second_serve_return_won                                                  20.0
# loser_second_serve_return_total                                                38.0
# loser_break_points_converted                                                    3.0
# loser_break_points_return_total                                                 7.0
# loser_return_games_played                                                      16.0
# loser_service_points_won                                                       62.0
# loser_service_points_total                                                     98.0
# loser_return_points_won                                                        37.0
# loser_return_points_total                                                     108.0
# loser_total_points_won                                                         99.0
# loser_total_points_total                                                      206.0
#
#                                                                               9      \
# match_id                                               2010-339-MS013-5-6-mc65-s963
# tourney_slug                                                               brisbane
# match_stats_url_suffix            /en/scores/2010/339/MS013/match-stats?isLive=F...
# match_time                                                                 02:19:00
# match_duration                                                                139.0
# winner_slug                                                                    mc65
# winner_serve_rating                                                           267.0
# winner_aces                                                                    16.0
# winner_double_faults                                                            6.0
# winner_first_serves_in                                                         53.0
# ...
# loser_return_points_won                                                        12.0
# loser_return_points_total                                                      49.0
# loser_total_points_won                                                         45.0
# loser_total_points_total                                                      109.0
#
#                                                                               42444  \
# match_id                                               2019-605-MS011-1-3-te51-mm58
# tourney_slug                                                       nitto-atp-finals
# match_stats_url_suffix            /en/scores/2019/605/MS011/match-stats?isLive=F...
# match_time                                                                 01:42:00
# match_duration                                                                102.0
# winner_slug                                                                    te51
# winner_serve_rating                                                           295.0
# winner_aces                                                                     5.0
# winner_double_faults                                                            0.0
# winner_first_serves_in                                                         44.0
# winner_first_serves_total                                                      73.0
# winner_first_serve_points_won                                                  39.0
# winner_first_serve_points_total                                                44.0
# winner_second_serve_points_won                                                 12.0
# winner_second_serve_points_total                                               29.0
# winner_break_points_saved                                                       0.0
# winner_break_points_serve_total                                                 0.0
# winner_service_games_played                                                    11.0
# winner_return_rating                                                          108.0
# winner_first_serve_return_won                                                  15.0
# winner_first_serve_return_total                                                53.0
# winner_second_serve_return_won                                                 11.0
# winner_second_serve_return_total                                               24.0
# winner_break_points_converted                                                   1.0
# winner_break_points_return_total                                                4.0
# winner_return_games_played                                                     11.0
# winner_service_points_won                                                      51.0
# winner_service_points_total                                                    73.0
# winner_return_points_won                                                       26.0
# winner_return_points_total                                                     77.0
# winner_total_points_won                                                        77.0
# winner_total_points_total                                                     150.0
# loser_slug                                                                     mm58
# loser_serve_rating                                                            291.0
# loser_aces                                                                      6.0
# loser_double_faults                                                             0.0
# loser_first_serves_in                                                          53.0
# loser_first_serves_total                                                       77.0
# loser_first_serve_points_won                                                   38.0
# loser_first_serve_points_total                                                 53.0
# loser_second_serve_points_won                                                  13.0
# loser_second_serve_points_total                                                24.0
# loser_break_points_saved                                                        3.0
# loser_break_points_serve_total                                                  4.0
# loser_service_games_played                                                     11.0
# loser_return_rating                                                            70.0
# loser_first_serve_return_won                                                    5.0
# loser_first_serve_return_total                                                 44.0
# loser_second_serve_return_won                                                  17.0
# loser_second_serve_return_total                                                29.0
# loser_break_points_converted                                                    0.0
# loser_break_points_return_total                                                 0.0
# loser_return_games_played                                                      11.0
# loser_service_points_won                                                       51.0
# loser_service_points_total                                                     77.0
# loser_return_points_won                                                        22.0
# loser_return_points_total                                                      73.0
# loser_total_points_won                                                         73.0
# loser_total_points_total                                                      150.0
#
#                                                                               42445  \
# match_id                                               2019-605-MS018-1-2-d643-bk40
# tourney_slug                                                       nitto-atp-finals
# match_stats_url_suffix            /en/scores/2019/605/MS018/match-stats?isLive=F...
# match_time                                                                 01:04:00
# match_duration                                                                 64.0
# winner_slug                                                                    d643
# winner_serve_rating                                                           300.0
# winner_aces                                                                     4.0
# winner_double_faults                                                            1.0
# winner_first_serves_in                                                         24.0
# winner_first_serves_total                                                      40.0
# winner_first_serve_points_won                                                  18.0
# winner_first_serve_points_total                                                24.0
# winner_second_serve_points_won                                                 12.0
# winner_second_serve_points_total                                               16.0
# winner_break_points_saved                                                       0.0
# winner_break_points_serve_total                                                 1.0
# winner_service_games_played                                                     8.0
# winner_return_rating                                                          266.0
# winner_first_serve_return_won                                                  18.0
# winner_first_serve_return_total                                                34.0
# winner_second_serve_return_won                                                 10.0
# winner_second_serve_return_total                                               14.0
# winner_break_points_converted                                                   5.0
# winner_break_points_return_total                                                7.0
# winner_return_games_played                                                      7.0
# winner_service_points_won                                                      30.0
# winner_service_points_total                                                    40.0
# winner_return_points_won                                                       28.0
# winner_return_points_total                                                     48.0
# winner_total_points_won                                                        58.0
# winner_total_points_total                                                      88.0
# loser_slug                                                                     bk40
# loser_serve_rating                                                            177.0
# loser_aces                                                                      4.0
# loser_double_faults                                                             2.0
# loser_first_serves_in                                                          34.0
# loser_first_serves_total                                                       48.0
# loser_first_serve_points_won                                                   16.0
# loser_first_serve_points_total                                                 34.0
# loser_second_serve_points_won                                                   4.0
# loser_second_serve_points_total                                                14.0
# loser_break_points_saved                                                        2.0
# loser_break_points_serve_total                                                  7.0
# loser_service_games_played                                                      7.0
# loser_return_rating                                                           162.0
# loser_first_serve_return_won                                                    6.0
# loser_first_serve_return_total                                                 24.0
# loser_second_serve_return_won                                                   4.0
# loser_second_serve_return_total                                                16.0
# loser_break_points_converted                                                    1.0
# loser_break_points_return_total                                                 1.0
# loser_return_games_played                                                       8.0
# loser_service_points_won                                                       20.0
# loser_service_points_total                                                     48.0
# loser_return_points_won                                                        10.0
# loser_return_points_total                                                      40.0
# loser_total_points_won                                                         30.0
# loser_total_points_total                                                       88.0
#
#                                                                               42446
# match_id                                               2019-605-MS019-1-1-tb69-f324
# tourney_slug                                                       nitto-atp-finals
# match_stats_url_suffix            /en/scores/2019/605/MS019/match-stats?isLive=F...
# match_time                                                                 01:40:00
# match_duration                                                                100.0
# winner_slug                                                                    tb69
# winner_serve_rating                                                           282.0
# winner_aces                                                                     1.0
# winner_double_faults                                                            1.0
# winner_first_serves_in                                                         51.0
# winner_first_serves_total                                                      81.0
# winner_first_serve_points_won                                                  33.0
# winner_first_serve_points_total                                                51.0
# winner_second_serve_points_won                                                 19.0
# winner_second_serve_points_total                                               30.0
# winner_break_points_saved                                                       3.0
# winner_break_points_serve_total                                                 4.0
# winner_service_games_played                                                    12.0
# winner_return_rating                                                          167.0
# winner_first_serve_return_won                                                  14.0
# winner_first_serve_return_total                                                47.0
# winner_second_serve_return_won                                                 11.0
# winner_second_serve_return_total                                               21.0
# winner_break_points_converted                                                   3.0
# winner_break_points_return_total                                                5.0
# winner_return_games_played                                                     12.0
# winner_service_points_won                                                      52.0
# winner_service_points_total                                                    81.0
# winner_return_points_won                                                       25.0
# winner_return_points_total                                                     68.0
# winner_total_points_won                                                        77.0
# winner_total_points_total                                                     149.0
# loser_slug                                                                     f324
# loser_serve_rating                                                            267.0
# loser_aces                                                                      5.0
# loser_double_faults                                                             0.0
# loser_first_serves_in                                                          47.0
# loser_first_serves_total                                                       68.0
# loser_first_serve_points_won                                                   33.0
# loser_first_serve_points_total                                                 47.0
# loser_second_serve_points_won                                                  10.0
# loser_second_serve_points_total                                                21.0
# loser_break_points_saved                                                        2.0
# loser_break_points_serve_total                                                  5.0
# loser_service_games_played                                                     12.0
# loser_return_rating                                                           105.0
# loser_first_serve_return_won                                                   18.0
# loser_first_serve_return_total                                                 51.0
# loser_second_serve_return_won                                                  11.0
# loser_second_serve_return_total                                                30.0
# loser_break_points_converted                                                    1.0
# loser_break_points_return_total                                                 4.0
# loser_return_games_played                                                      12.0
# loser_service_points_won                                                       43.0
# loser_service_points_total                                                     68.0
# loser_return_points_won                                                        29.0
# loser_return_points_total                                                      81.0
# loser_total_points_won                                                         72.0
# loser_total_points_total                                                      149.0
#
# [59 rows x 42447 columns]

# %% [markdown]
# **Variables**:
#
# - `match_id`
# - `tourney_slug`
# - `match_stats_url_suffix`
# - `match_time`: total duration of the match, in hours and minutes.
# - `match_duration`: total duration of the match, in minutes.
# - `winner_slug`
# - `winner_serve_rating`: calculated by dividing the total number of points won on a player's serve by the total number of service games played; for example, if a player wins 80 points out of 100 service points played, their serve rating would be 80%. Is used to measure how effective a player's serve is in winning points and games. Players with a high serve rating are generally able to hold their serve more easily and put pressure on their opponent.
# - `winner_aces`: number of aces for the player. An ace is a serve that is not touched by the receiver and lands inside the service box, resulting in a point for the server.
# - `winner_double_faults`: number of double faults for the player. A double fault is a serve that fails to land in the opponent's service box, resulting in a point for the opponent. A double fault occurs when a player misses both their first and second serves, or commits a fault on their second serve.
# - `winner_first_serves_in`: number of first serves-in for the player. A player is allowed two attempts to serve the ball into the opponent's service box. If the first serve is unsuccessful, they get a second attempt, which is known as the second serve. So, this variable stores the number of first serves-in refers to the number of times a player successfully lands their first serve in the opponent's service box during a match.
# - `winner_first_serves_total`: number of first serves in the total for the player.
# - `winner_first_serve_points_won`: number of points gained in the player's first serve.
# - `winner_first_serve_points_total`: number of points played in the player's first serve.
# - `winner_second_serve_points_won`: number of points gained in the player's second serve.
# - `winner_second_serve_points_total`: number of points played in the player's second serve.
# - `winner_break_points_saved`: a break point is a situation in which the receiver has the opportunity to win a game on the server's next service game. A break point occurs when the receiver wins a point during the server's service game, putting them in a position to potentially win the game by breaking their opponent's serve. So this variables stores the number of break points that the player saved.
# - `winner_break_points_serve_total`: the number of break points that the player was faced to.
# - `winner_service_games_played`: number of games that the player is serving played.
# - `winner_return_rating`: the return rate refers to the percentage of return points won by a player during the match. A return point is any point in which the player is receiving serve and has the opportunity to win the point by returning the serve and subsequently winning the rally.
# - `winner_first_serve_return_won`: number of points gained, by returning to the first serve of the other player.
# - `winner_first_serve_return_total`: number of points played, by returning to the first serve of the other player.
# - `winner_second_serve_return_won`: number of points gained, by returning to the second serve of the other player.
# - `winner_second_serve_return_total`: number of points played, by returning to the second serve of the other player.
# - `winner_break_points_converted`: number of break point opportunities that the player successfully converts into service breaks during the match.
# - `winner_break_points_return_total`: number of break point opportunities that the player had during the match.
# - `winner_return_games_played`: number of games that the player had to return the other player's service.
# - `winner_service_points_won`: number of points won during the service of the player.
# - `winner_service_points_total`: number of points played during the service of the player.
# - `winner_return_points_won`: number of points won by returning the other player's service.
# - `winner_return_points_total`: number of points played by returning the other player's service.
# - `winner_total_points_won`: number of points won by the player, independently of the service.
# - `winner_total_points_total`: number of points played.
# - `loser_slug`
# - `loser_serve_rating`: calculated by dividing the total number of points won on a player's serve by the total number of service games played.
# - `loser_aces`: number of aces for the player.
# - `loser_double_faults`: number of double faults for the player.
# - `loser_first_serves_in`: number of first serves-in for the player. This variable stores the number of first serves-in refers to the number of times a player successfully lands their first serve in the opponent's service box during the match.
# - `loser_first_serves_total`: number of first serves in the total for the player.
# - `loser_first_serve_points_won`: number of points gained in the player's first serve.
# - `loser_first_serve_points_total`: number of points played in the player's first serve.
# - `loser_second_serve_points_won`: number of points gained in the player's second serve.
# - `loser_second_serve_points_total`: number of points played in the player's second serve.
# - `loser_break_points_saved`: the number of break points that the player saved.
# - `loser_break_points_serve_total`: the number of break points that the player was faced to.
# - `loser_service_games_played`: number of games that the player is serving played.
# - `loser_return_rating`: percentage of return points won by a player during the match.
# - `loser_first_serve_return_won`: number of points gained, by returning to the first serve of the other player.
# - `loser_first_serve_return_total`: number of points played, by returning to the first serve of the other player.
# - `loser_second_serve_return_won`: number of points gained, by returning to the second serve of the other player.
# - `loser_second_serve_return_total`: number of points played, by returning to the second serve of the other player.
# - `loser_break_points_converted`: number of break point opportunities that the player successfully converts into service breaks during the match.
# - `loser_break_points_return_total`: number of break point opportunities that the player had during the match.
# - `loser_return_games_played`: number of games that the player had to return the other player's service.
# - `loser_service_points_won`: number of points won during the service of the player.
# - `loser_service_points_total`: number of points played during the service of the player.
# - `loser_return_points_won`: number of points won by returning the other player's service.
# - `loser_return_points_total`: number of points played by returning the other player's service.
# - `loser_total_points_won`: number of points won by the player, independently of the service.
# - `loser_total_points_total`: number of points played.

# %%
# checking the shape of the dataset

match_stats.shape
# Out:
# (42447, 59)

# %% [markdown]
# This dataset has an observation for each match, therefore, should be merged with the previous one by `match_id` that is a uniquely identifier for each observation.

# %% [markdown]
# #### Data types:

# %%
# checking the types of the variables, as well as the number of non-null observations in each variable

match_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42447 entries, 0 to 42446
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   match_id                          42447 non-null  object
#  1   tourney_slug                      42447 non-null  object
#  2   match_stats_url_suffix            42447 non-null  object
#  3   match_time                        42443 non-null  object
#  4   match_duration                    42443 non-null  float64
#  5   winner_slug                       42443 non-null  object
#  6   winner_serve_rating               42443 non-null  float64
#  7   winner_aces                       42443 non-null  float64
#  8   winner_double_faults              42443 non-null  float64
#  9   winner_first_serves_in            42443 non-null  float64
#  10  winner_first_serves_total         42443 non-null  float64
#  11  winner_first_serve_points_won     42443 non-null  float64
#  12  winner_first_serve_points_total   42443 non-null  float64
#  13  winner_second_serve_points_won    42443 non-null  float64
#  14  winner_second_serve_points_total  42443 non-null  float64
#  15  winner_break_points_saved         42443 non-null  float64
#  16  winner_break_points_serve_total   42443 non-null  float64
#  17  winner_service_games_played       42443 non-null  float64
#  18  winner_return_rating              42443 non-null  float64
#  19  winner_first_serve_return_won     42443 non-null  float64
#  20  winner_first_serve_return_total   42443 non-null  float64
#  21  winner_second_serve_return_won    42443 non-null  float64
#  22  winner_second_serve_return_total  42443 non-null  float64
#  23  winner_break_points_converted     42443 non-null  float64
#  24  winner_break_points_return_total  42443 non-null  float64
#  25  winner_return_games_played        42443 non-null  float64
#  26  winner_service_points_won         42443 non-null  float64
#  27  winner_service_points_total       42443 non-null  float64
#  28  winner_return_points_won          42443 non-null  float64
#  29  winner_return_points_total        42443 non-null  float64
#  30  winner_total_points_won           42443 non-null  float64
#  31  winner_total_points_total         42443 non-null  float64
#  32  loser_slug                        42443 non-null  object
#  33  loser_serve_rating                42443 non-null  float64
#  34  loser_aces                        42443 non-null  float64
#  35  loser_double_faults               42443 non-null  float64
#  36  loser_first_serves_in             42443 non-null  float64
#  37  loser_first_serves_total          42443 non-null  float64
#  38  loser_first_serve_points_won      42443 non-null  float64
#  39  loser_first_serve_points_total    42443 non-null  float64
#  40  loser_second_serve_points_won     42443 non-null  float64
#  41  loser_second_serve_points_total   42443 non-null  float64
#  42  loser_break_points_saved          42443 non-null  float64
#  43  loser_break_points_serve_total    42443 non-null  float64
#  44  loser_service_games_played        42443 non-null  float64
#  45  loser_return_rating               42443 non-null  float64
#  46  loser_first_serve_return_won      42443 non-null  float64
#  47  loser_first_serve_return_total    42443 non-null  float64
#  48  loser_second_serve_return_won     42443 non-null  float64
#  49  loser_second_serve_return_total   42443 non-null  float64
#  50  loser_break_points_converted      42443 non-null  float64
#  51  loser_break_points_return_total   42443 non-null  float64
#  52  loser_return_games_played         42443 non-null  float64
#  53  loser_service_points_won          42443 non-null  float64
#  54  loser_service_points_total        42443 non-null  float64
#  55  loser_return_points_won           42443 non-null  float64
#  56  loser_return_points_total         42443 non-null  float64
#  57  loser_total_points_won            42443 non-null  float64
#  58  loser_total_points_total          42443 non-null  float64
# dtypes: float64(53), object(6)
# memory usage: 19.1+ MB

# %% [markdown]
# There are 4 matches that have multiple missing values in almost all variables. That should be investigated in detail.

# %%
# storing correctly the variable regarding time

match_stats['match_time'] = pd.to_datetime(match_stats['match_time'], format = '%H:%M:%S')

# %% [markdown]
# #### Descriptive statistics:

# %%
match_stats.describe().T
# Out:
#                                     count        mean        std   min    25%  \
# match_duration                    42443.0  101.715831  39.158675   2.0   74.0
# winner_serve_rating               42443.0  282.597649  44.751406   0.0  268.0
# winner_aces                       42443.0    6.361779   5.329839   0.0    3.0
# winner_double_faults              42443.0    2.523078   2.202477   0.0    1.0
# winner_first_serves_in            42443.0   45.430436  18.543442   0.0   33.0
# winner_first_serves_total         42443.0   73.549136  28.674691   0.0   54.0
# winner_first_serve_points_won     42443.0   34.329807  13.386354   0.0   26.0
# winner_first_serve_points_total   42443.0   45.430436  18.543442   0.0   33.0
# winner_second_serve_points_won    42443.0   15.619395   6.786309   0.0   11.0
# winner_second_serve_points_total  42443.0   28.118700  12.574635   0.0   20.0
# winner_break_points_saved         42443.0    3.272247   2.980732  -7.0    1.0
# winner_break_points_serve_total   42443.0    4.743821   3.868447   0.0    2.0
# winner_service_games_played       42443.0   11.785029   4.168166   0.0    9.0
# winner_return_rating              42443.0  170.509083  48.174174   0.0  143.0
# winner_first_serve_return_won     42443.0   15.460641   6.749674   0.0   11.0
# winner_first_serve_return_total   42443.0   45.900125  18.879860   0.0   33.0
# winner_second_serve_return_won    42443.0   16.475438   6.808634   0.0   12.0
# winner_second_serve_return_total  42443.0   30.457249  12.527065   0.0   22.0
# winner_break_points_converted     42443.0    3.701105   1.635369   0.0    3.0
# winner_break_points_return_total  42443.0    8.234644   3.987552   0.0    6.0
# winner_return_games_played        42443.0   11.596918   4.170696   0.0    9.0
# winner_service_points_won         42443.0   49.949202  18.215048   0.0   38.0
# winner_service_points_total       42443.0   73.549136  28.674691   0.0   54.0
# winner_return_points_won          42443.0   31.936079  11.139744   0.0   25.0
# winner_return_points_total        42443.0   76.357373  28.737296   0.0   57.0
# winner_total_points_won           42443.0   81.885281  27.019816   0.0   64.0
# winner_total_points_total         42443.0  149.906510  55.846267   0.0  112.0
# loser_serve_rating                42443.0  232.694484  46.573048  -2.0  213.0
# loser_aces                        42443.0    4.684165   4.622071   0.0    2.0
# loser_double_faults               42443.0    3.265061   2.440933   0.0    1.0
# loser_first_serves_in             42443.0   45.968475  18.806744   0.0   33.0
# loser_first_serves_total          42443.0   76.464175  28.599390   0.0   57.0
# loser_first_serve_points_won      42443.0   30.483543  14.082759   0.0   21.0
# loser_first_serve_points_total    42443.0   45.968475  18.806744   0.0   33.0
# loser_second_serve_points_won     42443.0   14.002898   6.980890   0.0    9.0
# loser_second_serve_points_total   42443.0   30.495700  12.478434   0.0   22.0
# loser_break_points_saved          42443.0    4.537521   3.175627 -10.0    2.0
# loser_break_points_serve_total    42443.0    8.233278   3.989027   0.0    6.0
# loser_service_games_played        42443.0   11.596918   4.170696   0.0    9.0
# loser_return_rating               42443.0  106.456636  45.968165   0.0   64.0
# loser_first_serve_return_won      42443.0   11.083524   6.674144   0.0    6.0
# loser_first_serve_return_total    42443.0   45.366680  18.617534   0.0   33.0
# loser_second_serve_return_won     42443.0   12.486299   6.896829   0.0    8.0
# loser_second_serve_return_total   42443.0   28.080367  12.614653   0.0   19.0
# loser_break_points_converted      42443.0    1.474684   1.468754   0.0    0.0
# loser_break_points_return_total   42443.0    4.744457   3.868078   0.0    2.0
# loser_return_games_played         42443.0   11.785029   4.168166   0.0    9.0
# loser_service_points_won          42443.0   44.486441  19.447181   0.0   31.0
# loser_service_points_total        42443.0   76.464175  28.599390   0.0   57.0
# loser_return_points_won           42443.0   23.569823  11.949361   0.0   15.0
# loser_return_points_total         42443.0   73.447047  28.802091   0.0   54.0
# loser_total_points_won            42443.0   68.056264  29.391501   0.0   48.0
# loser_total_points_total          42443.0  149.911222  55.840156   0.0  112.0
#
#                                     50%    75%     max
# match_duration                     94.0  124.0  1412.0
# winner_serve_rating               287.0  306.0   419.0
# winner_aces                         5.0    9.0   113.0
# winner_double_faults                2.0    4.0    26.0
# winner_first_serves_in             43.0   56.0   361.0
# winner_first_serves_total          69.0   90.0   491.0
# winner_first_serve_points_won      32.0   41.0   292.0
# winner_first_serve_points_total    43.0   56.0   361.0
# winner_second_serve_points_won     15.0   19.0    82.0
# winner_second_serve_points_total   26.0   35.0   130.0
# winner_break_points_saved           3.0    5.0    55.0
# winner_break_points_serve_total     4.0    7.0    55.0
# winner_service_games_played        11.0   14.0    90.0
# winner_return_rating              170.0  199.0   400.0
# winner_first_serve_return_won      15.0   19.0    58.0
# winner_first_serve_return_total    43.0   56.0   328.0
# winner_second_serve_return_won     16.0   20.0    61.0
# winner_second_serve_return_total   29.0   37.0   161.0
# winner_break_points_converted       4.0    5.0    15.0
# winner_break_points_return_total    8.0   11.0    46.0
# winner_return_games_played         11.0   14.0    91.0
# winner_service_points_won          47.0   60.0   374.0
# winner_service_points_total        69.0   90.0   491.0
# winner_return_points_won           30.0   38.0   104.0
# winner_return_points_total         72.0   93.0   489.0
# winner_total_points_won            77.0   97.0   478.0
# winner_total_points_total         141.0  183.0   980.0
# loser_serve_rating                239.0  261.0   396.0
# loser_aces                          3.0    6.0   103.0
# loser_double_faults                 3.0    5.0    21.0
# loser_first_serves_in              43.0   56.0   328.0
# loser_first_serves_total           72.0   93.0   489.0
# loser_first_serve_points_won       29.0   38.0   284.0
# loser_first_serve_points_total     43.0   56.0   328.0
# loser_second_serve_points_won      13.0   18.0   101.0
# loser_second_serve_points_total    29.0   37.0   161.0
# loser_break_points_saved            4.0    6.0    46.0
# loser_break_points_serve_total      8.0   11.0    46.0
# loser_service_games_played         11.0   14.0    91.0
# loser_return_rating               109.0  140.0   350.0
# loser_first_serve_return_won       10.0   15.0    69.0
# loser_first_serve_return_total     43.0   56.0   361.0
# loser_second_serve_return_won      11.0   16.0    57.0
# loser_second_serve_return_total    26.0   35.0   130.0
# loser_break_points_converted        1.0    2.0    26.0
# loser_break_points_return_total     4.0    7.0    55.0
# loser_return_games_played          11.0   14.0    90.0
# loser_service_points_won           42.0   56.0   385.0
# loser_service_points_total         72.0   93.0   489.0
# loser_return_points_won            22.0   31.0   117.0
# loser_return_points_total          69.0   90.0   491.0
# loser_total_points_won             64.0   86.0   502.0
# loser_total_points_total          141.0  183.0   980.0

# %%
match_stats.describe(include = ['O']).T
# Out:
#                         count unique  \
# match_id                42447  42447
# tourney_slug            42447     95
# match_stats_url_suffix  42447  42447
# winner_slug             42443   1188
# loser_slug              42443   2120
#
#                                                                       top  \
# match_id                                     2010-339-MS001-8-1-r485-s694
# tourney_slug                                              australian-open
# match_stats_url_suffix  /en/scores/2010/339/MS001/match-stats?isLive=F...
# winner_slug                                                          d643
# loser_slug                                                           r772
#
#                         freq
# match_id                   1
# tourney_slug            2386
# match_stats_url_suffix     1
# winner_slug              608
# loser_slug               256

# %% [markdown]
# From this descriptive statistics, we can see that the average game lasts for 102 minutes, and on average the match has 150 points played. It would be interesting to know which players are the ones that win more and that lose more. To do that, we need to merge the two datasets (this one and the one with match scores), but this slug information do not add that much, therefore these two variables (`winner_slug` and `loser_slug`) should be deleted.

# %% [markdown]
# #### Do not make sense for our analysis:
#
# Again, we have URL in the dataset (`match_stats_url_suffix`), that does not make sense for our analysis, therefore will also be deleted. The same happens for the `match_order`, as it is irrelevant to know what were the matches that played before or after in the same round (the only thing that matters is the round).

# %%
# dropping the variables as explained before

match_stats.drop(columns = ['match_stats_url_suffix'], inplace = True)

# %%
# dropping the variables as explained before

match_stats.drop(columns = ['winner_slug', 'loser_slug'], inplace = True)

# %% [markdown]
# #### Missing values:

# %%
# creating a copy to solve the problems with missing values

match_stats_missing = match_stats.copy()

# %%
# replacing other types of missing values not recognized by pandas with NaN and checking again the number of missing values

match_stats_missing.replace(missing_values, np.nan, inplace = True)
match_stats_missing.isna().sum()
# Out:
# match_id                            0
# tourney_slug                        0
# match_time                          4
# match_duration                      4
# winner_serve_rating                 4
# winner_aces                         4
# winner_double_faults                4
# winner_first_serves_in              4
# winner_first_serves_total           4
# winner_first_serve_points_won       4
# winner_first_serve_points_total     4
# winner_second_serve_points_won      4
# winner_second_serve_points_total    4
# winner_break_points_saved           4
# winner_break_points_serve_total     4
# winner_service_games_played         4
# winner_return_rating                4
# winner_first_serve_return_won       4
# winner_first_serve_return_total     4
# winner_second_serve_return_won      4
# winner_second_serve_return_total    4
# winner_break_points_converted       4
# winner_break_points_return_total    4
# winner_return_games_played          4
# winner_service_points_won           4
# winner_service_points_total         4
# winner_return_points_won            4
# winner_return_points_total          4
# winner_total_points_won             4
# winner_total_points_total           4
# loser_serve_rating                  4
# loser_aces                          4
# loser_double_faults                 4
# loser_first_serves_in               4
# loser_first_serves_total            4
# loser_first_serve_points_won        4
# loser_first_serve_points_total      4
# loser_second_serve_points_won       4
# loser_second_serve_points_total     4
# loser_break_points_saved            4
# loser_break_points_serve_total      4
# loser_service_games_played          4
# loser_return_rating                 4
# loser_first_serve_return_won        4
# loser_first_serve_return_total      4
# loser_second_serve_return_won       4
# loser_second_serve_return_total     4
# loser_break_points_converted        4
# loser_break_points_return_total     4
# loser_return_games_played           4
# loser_service_points_won            4
# loser_service_points_total          4
# loser_return_points_won             4
# loser_return_points_total           4
# loser_total_points_won              4
# loser_total_points_total            4
# dtype: int64

# %%
# seeing rows with NaNs

match_stats_nans_index = match_stats_missing.isna().any(axis = 1)
match_stats_missing[match_stats_nans_index]
# Out:
#                             match_id    tourney_slug match_time  \
# 1806    2010-468-QS008-2-7-p701-n605         estoril        NaT
# 1810    2010-468-QS015-2-2-m984-bd42         estoril        NaT
# 39269  2019-6932-QS015-1-2-mo44-d0ar  rio-de-janeiro        NaT
# 39677  2019-403-MS086-3-21-h756-l797           miami        NaT
#
#        match_duration  winner_serve_rating  winner_aces  winner_double_faults  \
# 1806              NaN                  NaN          NaN                   NaN
# 1810              NaN                  NaN          NaN                   NaN
# 39269             NaN                  NaN          NaN                   NaN
# 39677             NaN                  NaN          NaN                   NaN
#
#        winner_first_serves_in  winner_first_serves_total  \
# 1806                      NaN                        NaN
# 1810                      NaN                        NaN
# 39269                     NaN                        NaN
# 39677                     NaN                        NaN
#
#        winner_first_serve_points_won  ...  loser_second_serve_return_total  \
# 1806                             NaN  ...                              NaN
# 1810                             NaN  ...                              NaN
# 39269                            NaN  ...                              NaN
# 39677                            NaN  ...                              NaN
#
#        loser_break_points_converted  loser_break_points_return_total  \
# 1806                            NaN                              NaN
# 1810                            NaN                              NaN
# 39269                           NaN                              NaN
# 39677                           NaN                              NaN
#
#        loser_return_games_played  loser_service_points_won  \
# 1806                         NaN                       NaN
# 1810                         NaN                       NaN
# 39269                        NaN                       NaN
# 39677                        NaN                       NaN
#
#        loser_service_points_total  loser_return_points_won  \
# 1806                          NaN                      NaN
# 1810                          NaN                      NaN
# 39269                         NaN                      NaN
# 39677                         NaN                      NaN
#
#        loser_return_points_total  loser_total_points_won  \
# 1806                         NaN                     NaN
# 1810                         NaN                     NaN
# 39269                        NaN                     NaN
# 39677                        NaN                     NaN
#
#        loser_total_points_total
# 1806                        NaN
# 1810                        NaN
# 39269                       NaN
# 39677                       NaN
#
# [4 rows x 56 columns]

# %%
# list with the match_id of the observations with missing values
match_id_missing = ['2010-468-QS008-2-7-p701-n605', '2010-468-QS015-2-2-m984-bd42', '2019-6932-QS015-1-2-mo44-d0ar', '2019-403-MS086-3-21-h756-l797']

# using the match_id to search in the match_scores dataset the specific matches
match_scores[match_scores['match_id'].isin(match_id_missing)].T
# Out:
#                                                                  18171  \
# tourney_year_id                                              2019-6932
# tourney_order                                                       13
# tourney_name                                            Rio de Janeiro
# tourney_slug                                            rio-de-janeiro
# start_date                                         2019-02-18 00:00:00
# end_date                                           2019-02-24 00:00:00
# tourney_round_name                                1st Round Qualifying
# round_order                                                          7
# winner_name                                             Pedro Martinez
# winner_player_id                                                  mo44
# winner_slug                                             pedro-martinez
# loser_name                            Mateus De Carvalho Cardoso Alves
# loser_player_id                                                   d0ar
# loser_slug                            mateus-de-carvalho-cardoso-alves
# winner_seed                                                          8
# loser_seed                                                          WC
# match_score_tiebreaks                                         64 36 75
# winner_sets_won                                                    2.0
# loser_sets_won                                                     1.0
# winner_games_won                                                  16.0
# loser_games_won                                                   15.0
# winner_tiebreaks_won                                               0.0
# loser_tiebreaks_won                                                0.0
# match_id                                 2019-6932-QS015-1-2-mo44-d0ar
# tourney_year                                                      2019
# pair                   Mateus De Carvalho Cardoso Alves-Pedro Martinez
# prize_money_USD                                              1786690.0
#
#                                                18546  \
# tourney_year_id                             2019-403
# tourney_order                                     20
# tourney_name                  ATP Masters 1000 Miami
# tourney_slug                                   miami
# start_date                       2019-03-20 00:00:00
# end_date                         2019-03-31 00:00:00
# tourney_round_name                      Round of 128
# round_order                                        7
# winner_name                              Robin Haase
# winner_player_id                                h756
# winner_slug                              robin-haase
# loser_name                               Lukas Lacko
# loser_player_id                                 l797
# loser_slug                               lukas-lacko
# winner_seed                           Not applicable
# loser_seed                                         Q
# match_score_tiebreaks                          62 64
# winner_sets_won                                  2.0
# loser_sets_won                                   0.0
# winner_games_won                                12.0
# loser_games_won                                  6.0
# winner_tiebreaks_won                             0.0
# loser_tiebreaks_won                              0.0
# match_id               2019-403-MS086-3-21-h756-l797
# tourney_year                                    2019
# pair                         Lukas Lacko-Robin Haase
# prize_money_USD                            8359455.0
#
#                                                       22534  \
# tourney_year_id                                    2010-468
# tourney_order                                            27
# tourney_name                                        Estoril
# tourney_slug                                        estoril
# start_date                              2010-05-03 00:00:00
# end_date                                2010-05-09 00:00:00
# tourney_round_name                     2nd Round Qualifying
# round_order                                               7
# winner_name                               Michal Przysiezny
# winner_player_id                                       p701
# winner_slug                               michal-przysiezny
# loser_name                               Jose-Ricardo Nunes
# loser_player_id                                        n605
# loser_slug                               jose-ricardo-nunes
# winner_seed                                               1
# loser_seed                                               WC
# match_score_tiebreaks                                 60 61
# winner_sets_won                                         2.0
# loser_sets_won                                          0.0
# winner_games_won                                       12.0
# loser_games_won                                         1.0
# winner_tiebreaks_won                                    0.0
# loser_tiebreaks_won                                     0.0
# match_id                       2010-468-QS008-2-7-p701-n605
# tourney_year                                           2010
# pair                   Jose-Ricardo Nunes-Michal Przysiezny
# prize_money_USD                                   423976.95
#
#                                                     22539
# tourney_year_id                                  2010-468
# tourney_order                                          27
# tourney_name                                      Estoril
# tourney_slug                                      estoril
# start_date                            2010-05-03 00:00:00
# end_date                              2010-05-09 00:00:00
# tourney_round_name                   2nd Round Qualifying
# round_order                                             7
# winner_name                                 David Marrero
# winner_player_id                                     m984
# winner_slug                                 david-marrero
# loser_name                           Agustin Boje-Ordonez
# loser_player_id                                      bd42
# loser_slug                           agustin-boje-ordonez
# winner_seed                                             6
# loser_seed                                 Not applicable
# match_score_tiebreaks                            26 63 64
# winner_sets_won                                       2.0
# loser_sets_won                                        1.0
# winner_games_won                                     14.0
# loser_games_won                                      13.0
# winner_tiebreaks_won                                  0.0
# loser_tiebreaks_won                                   0.0
# match_id                     2010-468-QS015-2-2-m984-bd42
# tourney_year                                         2010
# pair                   Agustin Boje-Ordonez-David Marrero
# prize_money_USD                                 423976.95

# %% [markdown]
# After a search on the internet (and specially websites that have tennis statistics like ATP tour or flashscore) we did not found the statistics regarding these games. Adding the fact that these games are not that important to the analysis that is going to be made (3 matches are from the qualifying draw and the other one is from round of 128, so they are not really decisive), these games will be deleted from the dataset.

# %%
# droping those observations

match_stats_missing.dropna(inplace = True)

# %%
# keeping the dataframe without missing values

match_stats = match_stats_missing.copy()

# %% [markdown]
# For the dashboard created we want to plot some relevant statistics from the matches to have a better understanding of the performance of players. Therefore we need to have the data normalized in the same scale to plot it. The variables that are going to be used are: 'winner_aces', 'winner_break_points_converted', 'winner_break_points_saved', 'winner_double_faults', 'winner_return_points_won', 'winner_total_points_won', 'loser_aces', 'loser_break_points_converted', 'loser_break_points_saved', 'loser_double_faults', 'loser_return_points_won', and 'loser_total_points_won'. So, those will be normalized using MinMaxScaler, forcing the range to be between 0 and 10.

# %%
# defining the statistics that are going to be displayed in the radar chart
skills = ['winner_aces', 'winner_break_points_converted', 'winner_break_points_saved', 'winner_double_faults', 'winner_return_points_won', 'winner_total_points_won', 'loser_aces', 'loser_break_points_converted', 'loser_break_points_saved', 'loser_double_faults', 'loser_return_points_won', 'loser_total_points_won']

# defining an instance of MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 10))

# scaling the data, making sure that all data will be in the range 0-10 and assigning the scaled data to the dataframe
match_stats[[col + '_norm' for col in skills]] = scaler.fit_transform(match_stats[skills])

# %% [markdown]
# Also, for constructing the dashboard we will need to see the maximum number of aces and the maximum number of break points saved, independetly if the player was loser or winner. So, two columns will be created storing the maximum number of those statistics for each match.

# %%
# creating the columns with the maximum values of the statistics

match_stats['max_aces'] = match_stats[['winner_aces', 'loser_aces']].max(axis = 1)
match_stats['max_break_points_saved'] = match_stats[['winner_break_points_saved', 'loser_break_points_saved']].max(axis = 1)

# %%
match_stats
# Out:
#                            match_id      tourney_slug          match_time  \
# 0      2010-339-MS001-8-1-r485-s694          brisbane 1900-01-01 02:05:00
# 1      2010-339-MS002-7-2-r485-ba47          brisbane 1900-01-01 02:08:00
# 2      2010-339-MS003-7-1-s694-mc65          brisbane 1900-01-01 01:01:00
# 3      2010-339-MS004-6-4-r485-g628          brisbane 1900-01-01 01:25:00
# 4      2010-339-MS007-6-3-s694-o234          brisbane 1900-01-01 01:40:00
# ...                             ...               ...                 ...
# 42442  2019-605-MS020-1-5-f324-bk40  nitto-atp-finals 1900-01-01 01:18:00
# 42443  2019-605-MS010-1-4-z355-n409  nitto-atp-finals 1900-01-01 01:24:00
# 42444  2019-605-MS011-1-3-te51-mm58  nitto-atp-finals 1900-01-01 01:42:00
# 42445  2019-605-MS018-1-2-d643-bk40  nitto-atp-finals 1900-01-01 01:04:00
# 42446  2019-605-MS019-1-1-tb69-f324  nitto-atp-finals 1900-01-01 01:40:00
#
#        match_duration  winner_serve_rating  winner_aces  winner_double_faults  \
# 0               125.0                304.0          7.0                   1.0
# 1               128.0                288.0          7.0                   1.0
# 2                61.0                309.0          3.0                   0.0
# 3                85.0                344.0         16.0                   1.0
# 4               100.0                279.0          7.0                   4.0
# ...               ...                  ...          ...                   ...
# 42442            78.0                321.0          8.0                   0.0
# 42443            84.0                313.0         11.0                   2.0
# 42444           102.0                295.0          5.0                   0.0
# 42445            64.0                300.0          4.0                   1.0
# 42446           100.0                282.0          1.0                   1.0
#
#        winner_first_serves_in  winner_first_serves_total  \
# 0                        64.0                       83.0
# 1                        60.0                       81.0
# 2                        31.0                       50.0
# 3                        45.0                       60.0
# 4                        33.0                       61.0
# ...                       ...                        ...
# 42442                    45.0                       67.0
# 42443                    34.0                       49.0
# 42444                    44.0                       73.0
# 42445                    24.0                       40.0
# 42446                    51.0                       81.0
#
#        winner_first_serve_points_won  ...  winner_return_points_won_norm  \
# 0                               45.0  ...                       3.461538
# 1                               43.0  ...                       3.173077
# 2                               20.0  ...                       2.307692
# 3                               39.0  ...                       2.115385
# 4                               24.0  ...                       3.173077
# ...                              ...  ...                            ...
# 42442                           35.0  ...                       2.115385
# 42443                           30.0  ...                       2.596154
# 42444                           39.0  ...                       2.500000
# 42445                           18.0  ...                       2.692308
# 42446                           33.0  ...                       2.403846
#
#        winner_total_points_won_norm  loser_aces_norm  \
# 0                          1.966527         0.485437
# 1                          1.820084         1.165049
# 2                          1.234310         0.097087
# 3                          1.485356         0.582524
# 4                          1.548117         0.291262
# ...                             ...              ...
# 42442                      1.506276         0.582524
# 42443                      1.338912         0.485437
# 42444                      1.610879         0.582524
# 42445                      1.213389         0.388350
# 42446                      1.610879         0.485437
#
#        loser_break_points_converted_norm  loser_break_points_saved_norm  \
# 0                               0.769231                       2.857143
# 1                               0.769231                       3.571429
# 2                               0.000000                       2.321429
# 3                               0.000000                       3.035714
# 4                               0.384615                       2.857143
# ...                                  ...                            ...
# 42442                           0.000000                       2.142857
# 42443                           0.000000                       1.964286
# 42444                           0.000000                       2.321429
# 42445                           0.384615                       2.142857
# 42446                           0.384615                       2.142857
#
#        loser_double_faults_norm  loser_return_points_won_norm  \
# 0                      3.809524                      2.136752
# 1                      0.952381                      2.307692
# 2                      1.428571                      1.282051
# 3                      0.952381                      0.940171
# 4                      1.428571                      1.709402
# ...                         ...                           ...
# 42442                  0.476190                      1.452991
# 42443                  0.000000                      1.025641
# 42444                  0.000000                      1.880342
# 42445                  0.952381                      0.854701
# 42446                  0.000000                      2.478632
#
#        loser_total_points_won_norm  max_aces  max_break_points_saved
# 0                         1.673307       7.0                     6.0
# 1                         1.633466      12.0                    10.0
# 2                         0.717131       3.0                     3.0
# 3                         1.115538      16.0                     7.0
# 4                         1.115538       7.0                     6.0
# ...                            ...       ...                     ...
# 42442                     1.155378       8.0                     3.0
# 42443                     0.896414      11.0                     1.0
# 42444                     1.454183       6.0                     3.0
# 42445                     0.597610       4.0                     2.0
# 42446                     1.434263       5.0                     3.0
#
# [42443 rows x 70 columns]

# %% [markdown]
# <a id = "merging-match-scores-stats"></a>
#
# ## 5. Merging the stats dataset with the score dataset
#
# [Back to TOC](#toc)

# %%
# merging the two datasets

all_match = pd.merge(match_scores, match_stats, how = 'left', on = 'match_id', suffixes = ('_match_scores', '_match_stats'))
all_match
# Out:
#       tourney_year_id  tourney_order tourney_name tourney_slug_match_scores  \
# 0            2010-339              1     Brisbane                  brisbane
# 1            2010-339              1     Brisbane                  brisbane
# 2            2010-339              1     Brisbane                  brisbane
# 3            2010-339              1     Brisbane                  brisbane
# 4            2010-339              1     Brisbane                  brisbane
# ...               ...            ...          ...                       ...
# 42616        2019-540             39    Wimbledon                 wimbledon
# 42617        2019-540             39    Wimbledon                 wimbledon
# 42618        2019-540             39    Wimbledon                 wimbledon
# 42619        2019-540             39    Wimbledon                 wimbledon
# 42620        2019-540             39    Wimbledon                 wimbledon
#
#       start_date   end_date    tourney_round_name  round_order  \
# 0     2010-01-03 2010-01-10                Finals            1
# 1     2010-01-03 2010-01-10           Semi-Finals            2
# 2     2010-01-03 2010-01-10           Semi-Finals            2
# 3     2010-01-03 2010-01-10        Quarter-Finals            3
# 4     2010-01-03 2010-01-10        Quarter-Finals            3
# ...          ...        ...                   ...          ...
# 42616 2019-07-01 2019-07-14  1st Round Qualifying           10
# 42617 2019-07-01 2019-07-14  1st Round Qualifying           10
# 42618 2019-07-01 2019-07-14  1st Round Qualifying           10
# 42619 2019-07-01 2019-07-14  1st Round Qualifying           10
# 42620 2019-07-01 2019-07-14  1st Round Qualifying           10
#
#              winner_name winner_player_id  ... winner_return_points_won_norm  \
# 0           Andy Roddick             r485  ...                      3.461538
# 1           Andy Roddick             r485  ...                      3.173077
# 2         Radek Stepanek             s694  ...                      2.307692
# 3           Andy Roddick             r485  ...                      2.115385
# 4         Radek Stepanek             s694  ...                      3.173077
# ...                  ...              ...  ...                           ...
# 42616           Go Soeda             sc47  ...                      2.692308
# 42617      Yuichi Sugita             se73  ...                      2.019231
# 42618  Mikael Torpegaard             tc12  ...                      2.692308
# 42619  Yasutaka Uchiyama             u134  ...                      2.403846
# 42620       Donald Young             y124  ...                      1.730769
#
#       winner_total_points_won_norm loser_aces_norm  \
# 0                         1.966527        0.485437
# 1                         1.820084        1.165049
# 2                         1.234310        0.097087
# 3                         1.485356        0.582524
# 4                         1.548117        0.291262
# ...                            ...             ...
# 42616                     1.924686        0.291262
# 42617                     1.192469        0.388350
# 42618                     2.029289        0.582524
# 42619                     1.694561        0.485437
# 42620                     1.527197        1.067961
#
#       loser_break_points_converted_norm loser_break_points_saved_norm  \
# 0                              0.769231                      2.857143
# 1                              0.769231                      3.571429
# 2                              0.000000                      2.321429
# 3                              0.000000                      3.035714
# 4                              0.384615                      2.857143
# ...                                 ...                           ...
# 42616                          0.384615                      1.785714
# 42617                          0.000000                      1.785714
# 42618                          1.153846                      2.142857
# 42619                          0.384615                      2.142857
# 42620                          0.384615                      1.785714
#
#       loser_double_faults_norm loser_return_points_won_norm  \
# 0                     3.809524                     2.136752
# 1                     0.952381                     2.307692
# 2                     1.428571                     1.282051
# 3                     0.952381                     0.940171
# 4                     1.428571                     1.709402
# ...                        ...                          ...
# 42616                 1.428571                     2.735043
# 42617                 1.428571                     0.769231
# 42618                 0.952381                     3.931624
# 42619                 1.904762                     2.051282
# 42620                 0.000000                     2.393162
#
#        loser_total_points_won_norm  max_aces  max_break_points_saved
# 0                         1.673307       7.0                     6.0
# 1                         1.633466      12.0                    10.0
# 2                         0.717131       3.0                     3.0
# 3                         1.115538      16.0                     7.0
# 4                         1.115538       7.0                     6.0
# ...                            ...       ...                     ...
# 42616                     1.533865       4.0                    12.0
# 42617                     0.756972       4.0                     0.0
# 42618                     2.051793       6.0                     8.0
# 42619                     1.294821      14.0                     2.0
# 42620                     1.414343      11.0                     4.0
#
# [42621 rows x 96 columns]

# %%
# checking the missing values of the merged dataset

all_match.isna().sum()
# Out:
# tourney_year_id                   0
# tourney_order                     0
# tourney_name                      0
# tourney_slug_match_scores         0
# start_date                        0
#                                ...
# loser_double_faults_norm        304
# loser_return_points_won_norm    304
# loser_total_points_won_norm     304
# max_aces                        304
# max_break_points_saved          304
# Length: 96, dtype: int64

# %%
pd.set_option('display.max_rows', 350)

# seeing rows with NaNs
all_match_nans_index = all_match.isna().any(axis = 1)
missing = all_match[all_match_nans_index]
missing
# Out:
#       tourney_year_id  tourney_order                   tourney_name  \
# 84           2010-451              2                           Doha
# 85           2010-451              2                           Doha
# 86           2010-451              2                           Doha
# 87           2010-451              2                           Doha
# 89           2010-451              2                           Doha
# 313         2010-5012              7                   Johannesburg
# 546          2010-506             15                   Buenos Aires
# 641          2010-495             16                          Dubai
# 693          2010-499             18                   Delray Beach
# 763          2010-404             19  ATP Masters 1000 Indian Wells
# 772          2010-404             19  ATP Masters 1000 Indian Wells
# 800          2010-404             19  ATP Masters 1000 Indian Wells
# 1054         2010-717             21                        Houston
# 1095         2010-315             38                        Newport
# 1370         2010-422             48    ATP Masters 1000 Cincinnati
# 1853         2010-747             55                        Beijing
# 1894         2010-329             56                          Tokyo
# 2294         2011-891              3                        Chennai
# 2340         2011-338              4                         Sydney
# 2402         2011-301              5                       Auckland
# 2406         2011-301              5                       Auckland
# 2528         2011-424             11                       San Jose
# 2883         2011-404             19  ATP Masters 1000 Indian Wells
# 3964        2011-1720             55                        Bangkok
# 3965        2011-1720             55                        Bangkok
# 3968        2011-1720             55                        Bangkok
# 4072        2011-5014             58      ATP Masters 1000 Shanghai
# 4275         2012-339              1                       Brisbane
# 4322         2012-451              2                           Doha
# 4332         2012-451              2                           Doha
# 4387         2012-891              3                        Chennai
# 4983         2012-404             19  ATP Masters 1000 Indian Wells
# 5012         2012-404             19  ATP Masters 1000 Indian Wells
# 5087         2012-403             20         ATP Masters 1000 Miami
# 5103         2012-403             20         ATP Masters 1000 Miami
# 5243         2012-717             21                        Houston
# 5484         2012-421             50        ATP Masters 1000 Canada
# 5699         2012-560             53                        US Open
# 6009        2012-6003             56                   Kuala Lumpur
# 6081         2012-747             58                        Beijing
# 6176        2012-5014             60      ATP Masters 1000 Shanghai
# 6565         2013-301              5                       Auckland
# 6570         2013-301              5                       Auckland
# 6590         2013-505              8                   Vina del Mar
# 6759         2013-402             13                        Memphis
# 7014         2013-404             19  ATP Masters 1000 Indian Wells
# 7043         2013-404             19  ATP Masters 1000 Indian Wells
# 7096         2013-404             19  ATP Masters 1000 Indian Wells
# 7153         2013-403             20         ATP Masters 1000 Miami
# 7160         2013-403             20         ATP Masters 1000 Miami
# 8157         2013-747             56                        Beijing
# 8245        2013-5014             58      ATP Masters 1000 Shanghai
# 8478         2014-451              2                           Doha
# 8504         2014-891              3                        Chennai
# 8585         2014-301              4                       Auckland
# 8687         2014-505              8                   Vina del Mar
# 8827        2014-6932             14                 Rio de Janeiro
# 8909         2014-495             17                          Dubai
# 8916         2014-495             17                          Dubai
# 9174         2014-403             21         ATP Masters 1000 Miami
# 9175         2014-403             21         ATP Masters 1000 Miami
# 9189         2014-403             21         ATP Masters 1000 Miami
# 9305         2014-717             22                        Houston
# 9579         2014-421             49        ATP Masters 1000 Canada
# 9601         2014-421             49        ATP Masters 1000 Canada
# 9720        2014-6242             51                  Winston-Salem
# 9804         2014-560             52                        US Open
# 9821         2014-560             52                        US Open
# 10102       2014-6967             55                       Shenzhen
# 10330        2014-605             65                     ATP Finals
# 11027        2015-404             19  ATP Masters 1000 Indian Wells
# 11721       2015-6242             51                  Winston-Salem
# 12146       2015-6967             56                       Shenzhen
# 12735       2016-6932             13                 Rio de Janeiro
# 12987        2016-404             19  ATP Masters 1000 Indian Wells
# 13110        2016-403             20         ATP Masters 1000 Miami
# 13512        2016-422             51    ATP Masters 1000 Cincinnati
# 13600       2016-6242             52                  Winston-Salem
# 13664        2016-560             53                        US Open
# 13991        2016-747             58                        Beijing
# 14043        2016-329             59                          Tokyo
# 14331        2017-338              4                         Sydney
# 14375        2017-301              5                       Auckland
# 14471        2017-424             11                        Memphis
# 14564        2017-499             15                   Delray Beach
# 14570        2017-499             15                   Delray Beach
# 14655        2017-807             17                       Acapulco
# 14737        2017-404             19  ATP Masters 1000 Indian Wells
# 14759        2017-404             19  ATP Masters 1000 Indian Wells
# 14880        2017-403             20         ATP Masters 1000 Miami
# 14968        2017-403             20         ATP Masters 1000 Miami
# 15099       2017-6116             45                        Atlanta
# 15674        2017-568             54                 St. Petersburg
# 15996       2017-7696             68            Next Gen ATP Finals
# 16052        2018-451              2                           Doha
# 16171        2018-338              4                         Sydney
# 16550        2018-404             19  ATP Masters 1000 Indian Wells
# 16922        2018-418             47                     Washington
# 17072        2018-421             50        ATP Masters 1000 Canada
# 17073        2018-421             50        ATP Masters 1000 Canada
# 17191       2018-6242             52                  Winston-Salem
# 17583        2018-747             59                        Beijing
# 17616        2018-747             59                        Beijing
# 17662        2018-329             60                          Tokyo
# 17755        2018-438             62                         Moscow
# 17822        2019-451              1                           Doha
# 18132       2019-6932             13                 Rio de Janeiro
# 18171       2019-6932             13                 Rio de Janeiro
# 18270        2019-807             17                       Acapulco
# 18290        2019-807             17                       Acapulco
# 18342        2019-404             19  ATP Masters 1000 Indian Wells
# 18346        2019-404             19  ATP Masters 1000 Indian Wells
# 18514        2019-403             20         ATP Masters 1000 Miami
# 18516        2019-403             20         ATP Masters 1000 Miami
# 18546        2019-403             20         ATP Masters 1000 Miami
# 18576        2019-403             20         ATP Masters 1000 Miami
# 18821        2019-421             49        ATP Masters 1000 Canada
# 18876        2019-421             49        ATP Masters 1000 Canada
# 18902        2019-422             50    ATP Masters 1000 Cincinnati
# 19063        2019-560             52                        US Open
# 19068        2019-560             52                        US Open
# 19424        2019-747             58                        Beijing
# 19645        2010-580              6                Australian Open
# 20129        2012-580              6                Australian Open
# 20258        2012-580              6                Australian Open
# 20595        2014-580              6                Australian Open
# 22070        2010-407             10                      Rotterdam
# 22385        2010-416             25          ATP Masters 1000 Rome
# 22534        2010-468             27                        Estoril
# 22538        2010-468             27                        Estoril
# 22539        2010-468             27                        Estoril
# 22865        2010-520             32                  Roland Garros
# 23026        2010-311             34          London / Queen's Club
# 23127        2010-741             35                     Eastbourne
# 23187        2010-440             36                s-Hertogenbosch
# 23468        2010-439             45                           Umag
# 23469        2010-439             45                           Umag
# 23472        2010-439             45                           Umag
# 23473        2010-439             45                           Umag
# 23477        2010-341             51                           Metz
# 23554        2010-773             52                      Bucharest
# 23570        2010-773             52                      Bucharest
# 23692        2010-337             62                         Vienna
# 23727        2010-337             62                         Vienna
# 23801        2010-328             64                          Basel
# 23905       2011-2276              9                         Zagreb
# 23954        2011-407             10                      Rotterdam
# 24020        2011-496             14                      Marseille
# 24021        2011-496             14                      Marseille
# 24022        2011-496             14                      Marseille
# 24023        2011-496             14                      Marseille
# 24024        2011-496             14                      Marseille
# 24025        2011-496             14                      Marseille
# 24026        2011-496             14                      Marseille
# 24027        2011-496             14                      Marseille
# 24028        2011-496             14                      Marseille
# 24029        2011-496             14                      Marseille
# 24030        2011-496             14                      Marseille
# 24031        2011-496             14                      Marseille
# 24032        2011-496             14                      Marseille
# 24033        2011-496             14                      Marseille
# 24034        2011-496             14                      Marseille
# 24035        2011-496             14                      Marseille
# 24036        2011-496             14                      Marseille
# 24037        2011-496             14                      Marseille
# 24038        2011-496             14                      Marseille
# 24039        2011-496             14                      Marseille
# 24040        2011-496             14                      Marseille
# 24041        2011-496             14                      Marseille
# 24042        2011-496             14                      Marseille
# 24043        2011-496             14                      Marseille
# 24044        2011-496             14                      Marseille
# 24045        2011-496             14                      Marseille
# 24046        2011-496             14                      Marseille
# 24047        2011-496             14                      Marseille
# 24086        2011-360             22                     Casablanca
# 24370       2011-5053             27                       Belgrade
# 24431       2011-1536             28        ATP Masters 1000 Madrid
# 24555        2011-416             29          ATP Masters 1000 Rome
# 24556        2011-416             29          ATP Masters 1000 Rome
# 24557        2011-416             29          ATP Masters 1000 Rome
# 24558        2011-416             29          ATP Masters 1000 Rome
# 24559        2011-416             29          ATP Masters 1000 Rome
# 24560        2011-416             29          ATP Masters 1000 Rome
# 24561        2011-416             29          ATP Masters 1000 Rome
# 24562        2011-416             29          ATP Masters 1000 Rome
# 24563        2011-416             29          ATP Masters 1000 Rome
# 24564        2011-416             29          ATP Masters 1000 Rome
# 24565        2011-416             29          ATP Masters 1000 Rome
# 24566        2011-416             29          ATP Masters 1000 Rome
# 24567        2011-416             29          ATP Masters 1000 Rome
# 24568        2011-416             29          ATP Masters 1000 Rome
# 24569        2011-416             29          ATP Masters 1000 Rome
# 24570        2011-416             29          ATP Masters 1000 Rome
# 24571        2011-416             29          ATP Masters 1000 Rome
# 24572        2011-416             29          ATP Masters 1000 Rome
# 24573        2011-416             29          ATP Masters 1000 Rome
# 24574        2011-416             29          ATP Masters 1000 Rome
# 24575        2011-416             29          ATP Masters 1000 Rome
# 24634        2011-520             32                  Roland Garros
# 24791        2011-520             32                  Roland Garros
# 24932        2011-311             34          London / Queen's Club
# 25062        2011-741             35                     Eastbourne
# 25132        2011-316             39                         Bastad
# 25358        2011-439             45                           Umag
# 25377        2011-439             45                           Umag
# 25390        2011-439             45                           Umag
# 25396        2011-439             45                           Umag
# 25429        2011-319             47                      Kitzbühel
# 25430        2011-319             47                      Kitzbühel
# 25431        2011-319             47                      Kitzbühel
# 25432        2011-319             47                      Kitzbühel
# 25433        2011-319             47                      Kitzbühel
# 25434        2011-319             47                      Kitzbühel
# 25435        2011-319             47                      Kitzbühel
# 25436        2011-319             47                      Kitzbühel
# 25437        2011-319             47                      Kitzbühel
# 25438        2011-319             47                      Kitzbühel
# 25439        2011-319             47                      Kitzbühel
# 25440        2011-319             47                      Kitzbühel
# 25555        2011-429             60                      Stockholm
# 25671        2011-573             63                       Valencia
# 25749        2011-352             65         ATP Masters 1000 Paris
# 25927        2012-407             10                      Rotterdam
# 26062        2012-360             22                     Casablanca
# 26319        2012-468             26                        Estoril
# 26579        2012-416             30          ATP Masters 1000 Rome
# 27027        2012-440             36                s-Hertogenbosch
# 27236        2012-321             41                      Stuttgart
# 27699        2012-352             66         ATP Masters 1000 Paris
# 28005        2013-360             22                     Casablanca
# 28095        2013-425             24                      Barcelona
# 28404        2013-416             29          ATP Masters 1000 Rome
# 28420        2013-416             29          ATP Masters 1000 Rome
# 28474       2013-6710             30                     Dusseldorf
# 28622        2013-520             32                  Roland Garros
# 28898        2013-311             34          London / Queen's Club
# 29430        2013-341             53                           Metz
# 29435        2013-429             60                      Stockholm
# 29736        2014-375              7                    Montpellier
# 29962        2014-410             24   ATP Masters 1000 Monte Carlo
# 30273       2014-1536             29        ATP Masters 1000 Madrid
# 30657        2014-520             33                  Roland Garros
# 30763        2014-500             34                          Halle
# 30772        2014-500             34                          Halle
# 30814        2014-311             35          London / Queen's Club
# 30901        2014-440             36                s-Hertogenbosch
# 31132        2014-414             42                        Hamburg
# 31240        2014-439             46                           Umag
# 31292        2014-319             47                      Kitzbühel
# 31510        2014-573             62                       Valencia
# 31511        2014-573             62                       Valencia
# 31852        2015-496             14                      Marseille
# 32096        2015-773             25                      Bucharest
# 32354        2015-416             30          ATP Masters 1000 Rome
# 32516       2015-6120             32                           Nice
# 32541        2015-520             33                  Roland Garros
# 32577        2015-520             33                  Roland Garros
# 33142        2015-414             44                        Hamburg
# 33293        2015-341             54                           Metz
# 33640       2016-7434              9                          Sofia
# 33703        2016-407             10                      Rotterdam
# 33763        2016-360             22                      Marrakech
# 34172        2016-416             30          ATP Masters 1000 Rome
# 34338        2016-520             33                  Roland Garros
# 34649        2016-311             36          London / Queen's Club
# 34684        2016-500             37                          Halle
# 34688        2016-500             37                          Halle
# 35004        2016-341             55                           Metz
# 35095        2016-337             64                         Vienna
# 35181        2016-352             66         ATP Masters 1000 Paris
# 35534        2017-425             24                      Barcelona
# 35634       2017-7290             26                        Estoril
# 35742       2017-1536             29        ATP Masters 1000 Madrid
# 35763       2017-1536             29        ATP Masters 1000 Madrid
# 36438        2017-741             39                     Eastbourne
# 36855        2017-352             67         ATP Masters 1000 Paris
# 37000        2018-407             10                      Rotterdam
# 37128        2018-410             23   ATP Masters 1000 Monte Carlo
# 37551        2018-416             30          ATP Masters 1000 Rome
# 38019        2018-311             37          London / Queen's Club
# 38216        2018-414             44                        Hamburg
# 38279        2018-314             46                         Gstaad
# 38369       2018-7485             63                        Antwerp
# 38452        2018-337             65                         Vienna
# 38546        2018-352             67         ATP Masters 1000 Paris
# 38555        2018-352             67         ATP Masters 1000 Paris
# 38639       2019-7434              9                          Sofia
# 38758        2019-360             22                      Marrakech
# 38823        2019-410             23   ATP Masters 1000 Monte Carlo
# 38858        2019-410             23   ATP Masters 1000 Monte Carlo
# 39058       2019-1536             28        ATP Masters 1000 Madrid
# 39136        2019-416             29          ATP Masters 1000 Rome
# 39257       2019-7694             31                           Lyon
# 39525        2019-321             33                      Stuttgart
# 39654        2019-311             36          London / Queen's Club
# 40126        2019-328             65                          Basel
# 40155        2019-328             65                          Basel
# 40168        2019-352             66         ATP Masters 1000 Paris
# 40280        2010-540             37                      Wimbledon
# 40987        2013-540             37                      Wimbledon
# 41006        2013-540             37                      Wimbledon
# 41461        2015-540             39                      Wimbledon
# 41709        2016-540             39                      Wimbledon
#
#       tourney_slug_match_scores start_date   end_date    tourney_round_name  \
# 84                         doha 2010-01-04 2010-01-09  3rd Round Qualifying
# 85                         doha 2010-01-04 2010-01-09  3rd Round Qualifying
# 86                         doha 2010-01-04 2010-01-09  3rd Round Qualifying
# 87                         doha 2010-01-04 2010-01-09  3rd Round Qualifying
# 89                         doha 2010-01-04 2010-01-09  2nd Round Qualifying
# 313                johannesburg 2010-02-01 2010-02-07  2nd Round Qualifying
# 546                buenos-aires 2010-02-15 2010-02-21        Quarter-Finals
# 641                       dubai 2010-02-22 2010-02-27  1st Round Qualifying
# 693                delray-beach 2010-02-22 2010-02-28           Round of 16
# 763                indian-wells 2010-03-11 2010-03-21           Round of 32
# 772                indian-wells 2010-03-11 2010-03-21           Round of 32
# 800                indian-wells 2010-03-11 2010-03-21           Round of 64
# 1054                    houston 2010-04-05 2010-04-11  1st Round Qualifying
# 1095                    newport 2010-07-05 2010-07-11  2nd Round Qualifying
# 1370                 cincinnati 2010-08-15 2010-08-22           Round of 16
# 1853                    beijing 2010-10-04 2010-10-10           Round of 16
# 1894                      tokyo 2010-10-04 2010-10-10        Quarter-Finals
# 2294                    chennai 2011-01-03 2011-01-09  2nd Round Qualifying
# 2340                     sydney 2011-01-10 2011-01-15  3rd Round Qualifying
# 2402                   auckland 2011-01-10 2011-01-15  2nd Round Qualifying
# 2406                   auckland 2011-01-10 2011-01-15  1st Round Qualifying
# 2528                   san-jose 2011-02-07 2011-02-13           Semi-Finals
# 2883               indian-wells 2011-03-10 2011-03-20        Quarter-Finals
# 3964                    bangkok 2011-09-26 2011-10-02  1st Round Qualifying
# 3965                    bangkok 2011-09-26 2011-10-02  1st Round Qualifying
# 3968                    bangkok 2011-09-26 2011-10-02  1st Round Qualifying
# 4072                   shanghai 2011-10-09 2011-10-16           Round of 32
# 4275                   brisbane 2012-01-01 2012-01-08           Round of 16
# 4322                       doha 2012-01-02 2012-01-07           Semi-Finals
# 4332                       doha 2012-01-02 2012-01-07           Round of 16
# 4387                    chennai 2012-01-02 2012-01-08           Round of 16
# 4983               indian-wells 2012-03-08 2012-03-18           Round of 32
# 5012               indian-wells 2012-03-08 2012-03-18           Round of 64
# 5087                      miami 2012-03-21 2012-04-01           Semi-Finals
# 5103                      miami 2012-03-21 2012-04-01           Round of 32
# 5243                    houston 2012-04-09 2012-04-15  3rd Round Qualifying
# 5484                    toronto 2012-08-06 2012-08-12           Round of 16
# 5699                    us-open 2012-08-27 2012-09-09           Round of 16
# 6009               kuala-lumpur 2012-09-24 2012-09-30  2nd Round Qualifying
# 6081                    beijing 2012-10-01 2012-10-07           Round of 16
# 6176                   shanghai 2012-10-07 2012-10-14           Round of 32
# 6565                   auckland 2013-01-07 2013-01-12  2nd Round Qualifying
# 6570                   auckland 2013-01-07 2013-01-12  1st Round Qualifying
# 6590               vina-del-mar 2013-02-04 2013-02-10        Quarter-Finals
# 6759                    memphis 2013-02-18 2013-02-24           Round of 16
# 7014               indian-wells 2013-03-07 2013-03-17           Round of 32
# 7043               indian-wells 2013-03-07 2013-03-17           Round of 64
# 7096               indian-wells 2013-03-07 2013-03-17  2nd Round Qualifying
# 7153                      miami 2013-03-20 2013-03-31           Round of 32
# 7160                      miami 2013-03-20 2013-03-31           Round of 64
# 8157                    beijing 2013-09-30 2013-10-06           Round of 16
# 8245                   shanghai 2013-10-07 2013-10-13           Round of 16
# 8478                       doha 2013-12-30 2014-01-04  1st Round Qualifying
# 8504                    chennai 2013-12-30 2014-01-05           Round of 16
# 8585                   auckland 2014-01-06 2014-01-11  2nd Round Qualifying
# 8687               vina-del-mar 2014-02-03 2014-02-09  2nd Round Qualifying
# 8827             rio-de-janeiro 2014-02-17 2014-02-23           Round of 16
# 8909                      dubai 2014-02-24 2014-03-01        Quarter-Finals
# 8916                      dubai 2014-02-24 2014-03-01           Round of 16
# 9174                      miami 2014-03-19 2014-03-30           Semi-Finals
# 9175                      miami 2014-03-19 2014-03-30           Semi-Finals
# 9189                      miami 2014-03-19 2014-03-30           Round of 32
# 9305                    houston 2014-04-07 2014-04-13           Semi-Finals
# 9579                    toronto 2014-08-04 2014-08-10           Round of 16
# 9601                    toronto 2014-08-04 2014-08-10           Round of 64
# 9720              winston-salem 2014-08-17 2014-08-23        Quarter-Finals
# 9804                    us-open 2014-08-25 2014-09-08           Round of 32
# 9821                    us-open 2014-08-25 2014-09-08           Round of 64
# 10102                  shenzhen 2014-09-22 2014-09-28  2nd Round Qualifying
# 10330                atp-finals 2014-11-09 2014-11-16                Finals
# 11027              indian-wells 2015-03-12 2015-03-22        Quarter-Finals
# 11721             winston-salem 2015-08-23 2015-08-30        Quarter-Finals
# 12146                  shenzhen 2015-09-28 2015-10-04        Quarter-Finals
# 12735            rio-de-janeiro 2016-02-15 2016-02-21        Quarter-Finals
# 12987              indian-wells 2016-03-10 2016-03-20           Round of 64
# 13110                     miami 2016-03-23 2016-04-03           Round of 64
# 13512                cincinnati 2016-08-14 2016-08-21           Round of 16
# 13600             winston-salem 2016-08-21 2016-08-27           Round of 32
# 13664                   us-open 2016-08-29 2016-09-11           Round of 64
# 13991                   beijing 2016-10-03 2016-10-09           Semi-Finals
# 14043                     tokyo 2016-10-03 2016-10-09           Round of 16
# 14331                    sydney 2017-01-08 2017-01-14        Quarter-Finals
# 14375                  auckland 2017-01-09 2017-01-14           Round of 16
# 14471                   memphis 2017-02-13 2017-02-19  2nd Round Qualifying
# 14564              delray-beach 2017-02-20 2017-02-26                Finals
# 14570              delray-beach 2017-02-20 2017-02-26        Quarter-Finals
# 14655                  acapulco 2017-02-27 2017-03-04        Quarter-Finals
# 14737              indian-wells 2017-03-09 2017-03-19        Quarter-Finals
# 14759              indian-wells 2017-03-09 2017-03-19           Round of 32
# 14880                     miami 2017-03-22 2017-04-02           Round of 32
# 14968                     miami 2017-03-22 2017-04-02  2nd Round Qualifying
# 15099                   atlanta 2017-07-24 2017-07-30  2nd Round Qualifying
# 15674             st-petersburg 2017-09-18 2017-09-24           Round of 16
# 15996       next-gen-atp-finals 2017-11-07 2017-11-11   3rd/4th Place Match
# 16052                      doha 2018-01-01 2018-01-06           Semi-Finals
# 16171                    sydney 2018-01-07 2018-01-13  1st Round Qualifying
# 16550              indian-wells 2018-03-08 2018-03-18           Round of 16
# 16922                washington 2018-07-30 2018-08-05        Quarter-Finals
# 17072                   toronto 2018-08-06 2018-08-12  2nd Round Qualifying
# 17073                   toronto 2018-08-06 2018-08-12  2nd Round Qualifying
# 17191             winston-salem 2018-08-19 2018-08-25           Round of 32
# 17583                   beijing 2018-10-01 2018-10-07           Semi-Finals
# 17616                   beijing 2018-10-01 2018-10-07  2nd Round Qualifying
# 17662                     tokyo 2018-10-01 2018-10-07  1st Round Qualifying
# 17755                    moscow 2018-10-15 2018-10-21           Round of 16
# 17822                      doha 2018-12-31 2019-01-05           Round of 16
# 18132            rio-de-janeiro 2019-02-18 2019-02-24           Semi-Finals
# 18171            rio-de-janeiro 2019-02-18 2019-02-24  1st Round Qualifying
# 18270                  acapulco 2019-02-25 2019-03-02           Round of 16
# 18290                  acapulco 2019-02-25 2019-03-02  2nd Round Qualifying
# 18342              indian-wells 2019-03-07 2019-03-17           Semi-Finals
# 18346              indian-wells 2019-03-07 2019-03-17        Quarter-Finals
# 18514                     miami 2019-03-20 2019-03-31           Round of 64
# 18516                     miami 2019-03-20 2019-03-31           Round of 64
# 18546                     miami 2019-03-20 2019-03-31          Round of 128
# 18576                     miami 2019-03-20 2019-03-31  2nd Round Qualifying
# 18821                  montreal 2019-08-05 2019-08-11           Semi-Finals
# 18876                  montreal 2019-08-05 2019-08-11  2nd Round Qualifying
# 18902                cincinnati 2019-08-11 2019-08-18        Quarter-Finals
# 19063                   us-open 2019-08-26 2019-09-08           Round of 64
# 19068                   us-open 2019-08-26 2019-09-08           Round of 64
# 19424                   beijing 2019-09-30 2019-10-06  1st Round Qualifying
# 19645           australian-open 2010-01-18 2010-01-31           Round of 32
# 20129           australian-open 2012-01-16 2012-01-29           Round of 64
# 20258           australian-open 2012-01-16 2012-01-29  2nd Round Qualifying
# 20595           australian-open 2014-01-13 2014-01-26           Round of 32
# 22070                 rotterdam 2010-02-08 2010-02-14        Quarter-Finals
# 22385                      rome 2010-04-25 2010-05-02           Round of 16
# 22534                   estoril 2010-05-03 2010-05-09  2nd Round Qualifying
# 22538                   estoril 2010-05-03 2010-05-09  2nd Round Qualifying
# 22539                   estoril 2010-05-03 2010-05-09  2nd Round Qualifying
# 22865             roland-garros 2010-05-24 2010-06-06  2nd Round Qualifying
# 23026                    london 2010-06-07 2010-06-13           Round of 16
# 23127                eastbourne 2010-06-13 2010-06-19  2nd Round Qualifying
# 23187           s-hertogenbosch 2010-06-13 2010-06-19  2nd Round Qualifying
# 23468                      umag 2010-07-26 2010-08-01  1st Round Qualifying
# 23469                      umag 2010-07-26 2010-08-01  1st Round Qualifying
# 23472                      umag 2010-07-26 2010-08-01  1st Round Qualifying
# 23473                      umag 2010-07-26 2010-08-01  1st Round Qualifying
# 23477                      metz 2010-09-20 2010-09-26           Semi-Finals
# 23554                 bucharest 2010-09-20 2010-09-26  3rd Round Qualifying
# 23570                 bucharest 2010-09-20 2010-09-26  1st Round Qualifying
# 23692                    vienna 2010-10-25 2010-10-31        Quarter-Finals
# 23727                    vienna 2010-10-25 2010-10-31  2nd Round Qualifying
# 23801                     basel 2010-11-01 2010-11-07           Round of 16
# 23905                    zagreb 2011-01-31 2011-02-06           Round of 16
# 23954                 rotterdam 2011-02-07 2011-02-13        Quarter-Finals
# 24020                 marseille 2011-02-14 2011-02-20  3rd Round Qualifying
# 24021                 marseille 2011-02-14 2011-02-20  3rd Round Qualifying
# 24022                 marseille 2011-02-14 2011-02-20  3rd Round Qualifying
# 24023                 marseille 2011-02-14 2011-02-20  3rd Round Qualifying
# 24024                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24025                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24026                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24027                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24028                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24029                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24030                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24031                 marseille 2011-02-14 2011-02-20  2nd Round Qualifying
# 24032                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24033                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24034                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24035                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24036                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24037                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24038                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24039                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24040                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24041                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24042                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24043                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24044                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24045                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24046                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24047                 marseille 2011-02-14 2011-02-20  1st Round Qualifying
# 24086                casablanca 2011-04-04 2011-04-10  2nd Round Qualifying
# 24370                  belgrade 2011-04-25 2011-05-01           Semi-Finals
# 24431                    madrid 2011-05-01 2011-05-08           Round of 16
# 24555                      rome 2011-05-08 2011-05-15  2nd Round Qualifying
# 24556                      rome 2011-05-08 2011-05-15  2nd Round Qualifying
# 24557                      rome 2011-05-08 2011-05-15  2nd Round Qualifying
# 24558                      rome 2011-05-08 2011-05-15  2nd Round Qualifying
# 24559                      rome 2011-05-08 2011-05-15  2nd Round Qualifying
# 24560                      rome 2011-05-08 2011-05-15  2nd Round Qualifying
# 24561                      rome 2011-05-08 2011-05-15  2nd Round Qualifying
# 24562                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24563                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24564                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24565                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24566                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24567                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24568                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24569                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24570                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24571                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24572                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24573                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24574                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24575                      rome 2011-05-08 2011-05-15  1st Round Qualifying
# 24634             roland-garros 2011-05-22 2011-06-05        Quarter-Finals
# 24791             roland-garros 2011-05-22 2011-06-05  2nd Round Qualifying
# 24932                    london 2011-06-06 2011-06-12        Quarter-Finals
# 25062                eastbourne 2011-06-12 2011-06-18  1st Round Qualifying
# 25132                    bastad 2011-07-11 2011-07-17           Round of 16
# 25358                      umag 2011-07-25 2011-07-31           Round of 16
# 25377                      umag 2011-07-25 2011-07-31  3rd Round Qualifying
# 25390                      umag 2011-07-25 2011-07-31  1st Round Qualifying
# 25396                      umag 2011-07-25 2011-07-31  1st Round Qualifying
# 25429                  kitzbhel 2011-07-31 2011-08-06  3rd Round Qualifying
# 25430                  kitzbhel 2011-07-31 2011-08-06  3rd Round Qualifying
# 25431                  kitzbhel 2011-07-31 2011-08-06  3rd Round Qualifying
# 25432                  kitzbhel 2011-07-31 2011-08-06  3rd Round Qualifying
# 25433                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25434                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25435                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25436                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25437                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25438                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25439                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25440                  kitzbhel 2011-07-31 2011-08-06  2nd Round Qualifying
# 25555                 stockholm 2011-10-17 2011-10-23        Quarter-Finals
# 25671                  valencia 2011-10-31 2011-11-06           Round of 16
# 25749                     paris 2011-11-07 2011-11-13        Quarter-Finals
# 25927                 rotterdam 2012-02-13 2012-02-19           Round of 16
# 26062                casablanca 2012-04-09 2012-04-15  1st Round Qualifying
# 26319                   estoril 2012-04-30 2012-05-06  1st Round Qualifying
# 26579                      rome 2012-05-13 2012-05-20  2nd Round Qualifying
# 27027           s-hertogenbosch 2012-06-17 2012-06-23           Round of 16
# 27236                 stuttgart 2012-07-09 2012-07-15  1st Round Qualifying
# 27699                     paris 2012-10-29 2012-11-04           Round of 16
# 28005                casablanca 2013-04-08 2013-04-14  1st Round Qualifying
# 28095                 barcelona 2013-04-22 2013-04-28        Quarter-Finals
# 28404                      rome 2013-05-12 2013-05-19           Round of 16
# 28420                      rome 2013-05-12 2013-05-19           Round of 32
# 28474                dusseldorf 2013-05-19 2013-05-25        Quarter-Finals
# 28622             roland-garros 2013-05-27 2013-06-09           Round of 64
# 28898                    london 2013-06-10 2013-06-16           Round of 32
# 29430                      metz 2013-09-16 2013-09-22  1st Round Qualifying
# 29435                 stockholm 2013-10-14 2013-10-20        Quarter-Finals
# 29736               montpellier 2014-02-03 2014-02-09  1st Round Qualifying
# 29962               monte-carlo 2014-04-13 2014-04-20           Round of 16
# 30273                    madrid 2014-05-04 2014-05-11           Round of 16
# 30657             roland-garros 2014-05-26 2014-06-08  3rd Round Qualifying
# 30763                     halle 2014-06-09 2014-06-15        Quarter-Finals
# 30772                     halle 2014-06-09 2014-06-15           Round of 16
# 30814                    london 2014-06-09 2014-06-15        Quarter-Finals
# 30901           s-hertogenbosch 2014-06-15 2014-06-21           Round of 16
# 31132                   hamburg 2014-07-14 2014-07-20           Round of 32
# 31240                      umag 2014-07-21 2014-07-27           Round of 16
# 31292                 kitzbuhel 2014-07-27 2014-08-02           Round of 16
# 31510                  valencia 2014-10-20 2014-10-26           Round of 16
# 31511                  valencia 2014-10-20 2014-10-26           Round of 16
# 31852                 marseille 2015-02-16 2015-02-22  1st Round Qualifying
# 32096                 bucharest 2015-04-20 2015-04-26  1st Round Qualifying
# 32354                      rome 2015-05-10 2015-05-17           Round of 16
# 32516                      nice 2015-05-17 2015-05-24  1st Round Qualifying
# 32541             roland-garros 2015-05-24 2015-06-07           Round of 32
# 32577             roland-garros 2015-05-24 2015-06-07           Round of 64
# 33142                   hamburg 2015-07-27 2015-08-02        Quarter-Finals
# 33293                      metz 2015-09-21 2015-09-27        Quarter-Finals
# 33640                     sofia 2016-02-01 2016-02-07           Round of 16
# 33703                 rotterdam 2016-02-08 2016-02-14  2nd Round Qualifying
# 33763                 marrakech 2016-04-04 2016-04-10           Round of 16
# 34172                      rome 2016-05-08 2016-05-15        Quarter-Finals
# 34338             roland-garros 2016-05-22 2016-06-05           Round of 32
# 34649                    london 2016-06-13 2016-06-19           Round of 16
# 34684                     halle 2016-06-13 2016-06-19        Quarter-Finals
# 34688                     halle 2016-06-13 2016-06-19           Round of 16
# 35004                      metz 2016-09-19 2016-09-25  2nd Round Qualifying
# 35095                    vienna 2016-10-24 2016-10-30           Semi-Finals
# 35181                     paris 2016-10-31 2016-11-06           Semi-Finals
# 35534                 barcelona 2017-04-24 2017-04-30           Round of 32
# 35634                   estoril 2017-05-01 2017-05-07           Round of 16
# 35742                    madrid 2017-05-07 2017-05-14        Quarter-Finals
# 35763                    madrid 2017-05-07 2017-05-14           Round of 32
# 36438                eastbourne 2017-06-26 2017-07-01  2nd Round Qualifying
# 36855                     paris 2017-10-30 2017-11-05        Quarter-Finals
# 37000                 rotterdam 2018-02-12 2018-02-18        Quarter-Finals
# 37128               monte-carlo 2018-04-15 2018-04-22           Round of 16
# 37551                      rome 2018-05-13 2018-05-20  2nd Round Qualifying
# 38019                    london 2018-06-18 2018-06-24           Round of 16
# 38216                   hamburg 2018-07-23 2018-07-29           Round of 16
# 38279                    gstaad 2018-07-23 2018-07-29  2nd Round Qualifying
# 38369                   antwerp 2018-10-15 2018-10-21        Quarter-Finals
# 38452                    vienna 2018-10-22 2018-10-28           Round of 16
# 38546                     paris 2018-10-29 2018-11-04           Round of 32
# 38555                     paris 2018-10-29 2018-11-04           Round of 32
# 38639                     sofia 2019-02-04 2019-02-10        Quarter-Finals
# 38758                 marrakech 2019-04-08 2019-04-14        Quarter-Finals
# 38823               monte-carlo 2019-04-14 2019-04-21           Round of 32
# 38858               monte-carlo 2019-04-14 2019-04-21  2nd Round Qualifying
# 39058                    madrid 2019-05-05 2019-05-12        Quarter-Finals
# 39136                      rome 2019-05-12 2019-05-19        Quarter-Finals
# 39257                      lyon 2019-05-19 2019-05-25           Round of 16
# 39525                 stuttgart 2019-06-10 2019-06-16           Semi-Finals
# 39654                    london 2019-06-17 2019-06-23           Round of 16
# 40126                     basel 2019-10-21 2019-10-27        Quarter-Finals
# 40155                     basel 2019-10-21 2019-10-27  2nd Round Qualifying
# 40168                     paris 2019-10-28 2019-11-03           Semi-Finals
# 40280                 wimbledon 2010-06-21 2010-07-04           Round of 64
# 40987                 wimbledon 2013-06-24 2013-07-07           Round of 64
# 41006                 wimbledon 2013-06-24 2013-07-07           Round of 64
# 41461                 wimbledon 2015-06-29 2015-07-12           Round of 64
# 41709                 wimbledon 2016-06-27 2016-07-10           Round of 64
#
#        round_order              winner_name winner_player_id  ...  \
# 84               6          Benjamin Becker             b896  ...
# 85               6            Ryler DeHeart             d617  ...
# 86               6             Steve Darcis             d632  ...
# 87               6        Mikhail Kukushkin             k926  ...
# 89               7               Karol Beck             b804  ...
# 313              7          Fritz Wolmarans             w421  ...
# 546              3          Albert Montanes             m824  ...
# 641              7            Ivan Sergeyev             se69  ...
# 693              4          Benjamin Becker             b896  ...
# 763              5           Viktor Troicki             t840  ...
# 772              5            Jurgen Melzer             m762  ...
# 800              6          Thomaz Bellucci             bd20  ...
# 1054             8             John Valenti             v410  ...
# 1095             7           Alexander Peya             p467  ...
# 1370             4            Roger Federer             f324  ...
# 1853             4           Novak Djokovic             d643  ...
# 1894             3           Radek Stepanek             s694  ...
# 2294             7            Yuichi Sugita             se73  ...
# 2340             6             Igor Andreev             a511  ...
# 2402             7          Michael Russell             r368  ...
# 2406             8           Bobby Reynolds             r483  ...
# 2528             2             Milos Raonic             r975  ...
# 2883             3    Juan Martin del Potro             d683  ...
# 3964             8          Dane Chuntraruk             cb11  ...
# 3965             8          Evgeny Kirillov             k777  ...
# 3968             8          Aviruth Phaphui             pg74  ...
# 4072             5              Andy Murray             mc10  ...
# 4275             4            Denis Istomin             i165  ...
# 4322             2       Jo-Wilfried Tsonga             t786  ...
# 4332             4     Albert Ramos-Vinolas             r772  ...
# 4387             4          Nicolas Almagro             a479  ...
# ...
# 26062                          NaN                          NaN       NaN
# 26319                          NaN                          NaN       NaN
# 26579                          NaN                          NaN       NaN
# 27027                          NaN                          NaN       NaN
# 27236                          NaN                          NaN       NaN
# 27699                          NaN                          NaN       NaN
# 28005                          NaN                          NaN       NaN
# 28095                          NaN                          NaN       NaN
# 28404                          NaN                          NaN       NaN
# 28420                          NaN                          NaN       NaN
# 28474                          NaN                          NaN       NaN
# 28622                          NaN                          NaN       NaN
# 28898                          NaN                          NaN       NaN
# 29430                          NaN                          NaN       NaN
# 29435                          NaN                          NaN       NaN
# 29736                          NaN                          NaN       NaN
# 29962                          NaN                          NaN       NaN
# 30273                          NaN                          NaN       NaN
# 30657                          NaN                          NaN       NaN
# 30763                          NaN                          NaN       NaN
# 30772                          NaN                          NaN       NaN
# 30814                          NaN                          NaN       NaN
# 30901                          NaN                          NaN       NaN
# 31132                          NaN                          NaN       NaN
# 31240                          NaN                          NaN       NaN
# 31292                          NaN                          NaN       NaN
# 31510                          NaN                          NaN       NaN
# 31511                          NaN                          NaN       NaN
# 31852                          NaN                          NaN       NaN
# 32096                          NaN                          NaN       NaN
# 32354                          NaN                          NaN       NaN
# 32516                          NaN                          NaN       NaN
# 32541                          NaN                          NaN       NaN
# 32577                          NaN                          NaN       NaN
# 33142                          NaN                          NaN       NaN
# 33293                          NaN                          NaN       NaN
# 33640                          NaN                          NaN       NaN
# 33703                          NaN                          NaN       NaN
# 33763                          NaN                          NaN       NaN
# 34172                          NaN                          NaN       NaN
# 34338                          NaN                          NaN       NaN
# 34649                          NaN                          NaN       NaN
# 34684                          NaN                          NaN       NaN
# 34688                          NaN                          NaN       NaN
# 35004                          NaN                          NaN       NaN
# 35095                          NaN                          NaN       NaN
# 35181                          NaN                          NaN       NaN
# 35534                          NaN                          NaN       NaN
# 35634                          NaN                          NaN       NaN
# 35742                          NaN                          NaN       NaN
# 35763                          NaN                          NaN       NaN
# 36438                          NaN                          NaN       NaN
# 36855                          NaN                          NaN       NaN
# 37000                          NaN                          NaN       NaN
# 37128                          NaN                          NaN       NaN
# 37551                          NaN                          NaN       NaN
# 38019                          NaN                          NaN       NaN
# 38216                          NaN                          NaN       NaN
# 38279                          NaN                          NaN       NaN
# 38369                          NaN                          NaN       NaN
# 38452                          NaN                          NaN       NaN
# 38546                          NaN                          NaN       NaN
# 38555                          NaN                          NaN       NaN
# 38639                          NaN                          NaN       NaN
# 38758                          NaN                          NaN       NaN
# 38823                          NaN                          NaN       NaN
# 38858                          NaN                          NaN       NaN
# 39058                          NaN                          NaN       NaN
# 39136                          NaN                          NaN       NaN
# 39257                          NaN                          NaN       NaN
# 39525                          NaN                          NaN       NaN
# 39654                          NaN                          NaN       NaN
# 40126                          NaN                          NaN       NaN
# 40155                          NaN                          NaN       NaN
# 40168                          NaN                          NaN       NaN
# 40280                          NaN                          NaN       NaN
# 40987                          NaN                          NaN       NaN
# 41006                          NaN                          NaN       NaN
# 41461                          NaN                          NaN       NaN
# 41709                          NaN                          NaN       NaN
#
#        max_break_points_saved
# 84                        NaN
# 85                        NaN
# 86                        NaN
# 87                        NaN
# 89                        NaN
# 313                       NaN
# 546                       NaN
# 641                       NaN
# 693                       NaN
# 763                       NaN
# 772                       NaN
# 800                       NaN
# 1054                      NaN
# 1095                      NaN
# 1370                      NaN
# 1853                      NaN
# 1894                      NaN
# 2294                      NaN
# 2340                      NaN
# 2402                      NaN
# 2406                      NaN
# 2528                      NaN
# 2883                      NaN
# 3964                      NaN
# 3965                      NaN
# 3968                      NaN
# 4072                      NaN
# 4275                      NaN
# 4322                      NaN
# 4332                      NaN
# 4387                      NaN
# 4983                      NaN
# 5012                      NaN
# 5087                      NaN
# 5103                      NaN
# 5243                      NaN
# 5484                      NaN
# 5699                      NaN
# 6009                      NaN
# 6081                      NaN
# 6176                      NaN
# 6565                      NaN
# 6570                      NaN
# 6590                      NaN
# 6759                      NaN
# 7014                      NaN
# 7043                      NaN
# 7096                      NaN
# 7153                      NaN
# 7160                      NaN
# 8157                      NaN
# 8245                      NaN
# 8478                      NaN
# 8504                      NaN
# 8585                      NaN
# 8687                      NaN
# 8827                      NaN
# 8909                      NaN
# 8916                      NaN
# 9174                      NaN
# 9175                      NaN
# 9189                      NaN
# 9305                      NaN
# 9579                      NaN
# 9601                      NaN
# 9720                      NaN
# 9804                      NaN
# 9821                      NaN
# 10102                     NaN
# 10330                     NaN
# 11027                     NaN
# 11721                     NaN
# 12146                     NaN
# 12735                     NaN
# 12987                     NaN
# 13110                     NaN
# 13512                     NaN
# 13600                     NaN
# 13664                     NaN
# 13991                     NaN
# 14043                     NaN
# 14331                     NaN
# 14375                     NaN
# 14471                     NaN
# 14564                     NaN
# 14570                     NaN
# 14655                     NaN
# 14737                     NaN
# 14759                     NaN
# 14880                     NaN
# 14968                     NaN
# 15099                     NaN
# 15674                     NaN
# 15996                     NaN
# 16052                     NaN
# 16171                     NaN
# 16550                     NaN
# 16922                     NaN
# 17072                     NaN
# 17073                     NaN
# 17191                     NaN
# 17583                     NaN
# 17616                     NaN
# 17662                     NaN
# 17755                     NaN
# 17822                     NaN
# 18132                     NaN
# 18171                     NaN
# 18270                     NaN
# 18290                     NaN
# 18342                     NaN
# 18346                     NaN
# 18514                     NaN
# 18516                     NaN
# 18546                     NaN
# 18576                     NaN
# 18821                     NaN
# 18876                     NaN
# 18902                     NaN
# 19063                     NaN
# 19068                     NaN
# 19424                     NaN
# 19645                     NaN
# 20129                     NaN
# 20258                     NaN
# 20595                     NaN
# 22070                     NaN
# 22385                     NaN
# 22534                     NaN
# 22538                     NaN
# 22539                     NaN
# 22865                     NaN
# 23026                     NaN
# 23127                     NaN
# 23187                     NaN
# 23468                     NaN
# 23469                     NaN
# 23472                     NaN
# 23473                     NaN
# 23477                     NaN
# 23554                     NaN
# 23570                     NaN
# 23692                     NaN
# 23727                     NaN
# 23801                     NaN
# 23905                     NaN
# 23954                     NaN
# 24020                     NaN
# 24021                     NaN
# 24022                     NaN
# 24023                     NaN
# 24024                     NaN
# 24025                     NaN
# 24026                     NaN
# 24027                     NaN
# 24028                     NaN
# 24029                     NaN
# 24030                     NaN
# 24031                     NaN
# 24032                     NaN
# 24033                     NaN
# 24034                     NaN
# 24035                     NaN
# 24036                     NaN
# 24037                     NaN
# 24038                     NaN
# 24039                     NaN
# 24040                     NaN
# 24041                     NaN
# 24042                     NaN
# 24043                     NaN
# 24044                     NaN
# 24045                     NaN
# 24046                     NaN
# 24047                     NaN
# 24086                     NaN
# 24370                     NaN
# 24431                     NaN
# 24555                     NaN
# 24556                     NaN
# 24557                     NaN
# 24558                     NaN
# 24559                     NaN
# 24560                     NaN
# 24561                     NaN
# 24562                     NaN
# 24563                     NaN
# 24564                     NaN
# 24565                     NaN
# 24566                     NaN
# 24567                     NaN
# 24568                     NaN
# 24569                     NaN
# 24570                     NaN
# 24571                     NaN
# 24572                     NaN
# 24573                     NaN
# 24574                     NaN
# 24575                     NaN
# 24634                     NaN
# 24791                     NaN
# 24932                     NaN
# 25062                     NaN
# 25132                     NaN
# 25358                     NaN
# 25377                     NaN
# 25390                     NaN
# 25396                     NaN
# 25429                     NaN
# 25430                     NaN
# 25431                     NaN
# 25432                     NaN
# 25433                     NaN
# 25434                     NaN
# 25435                     NaN
# 25436                     NaN
# 25437                     NaN
# 25438                     NaN
# 25439                     NaN
# 25440                     NaN
# 25555                     NaN
# 25671                     NaN
# 25749                     NaN
# 25927                     NaN
# 26062                     NaN
# 26319                     NaN
# 26579                     NaN
# 27027                     NaN
# 27236                     NaN
# 27699                     NaN
# 28005                     NaN
# 28095                     NaN
# 28404                     NaN
# 28420                     NaN
# 28474                     NaN
# 28622                     NaN
# 28898                     NaN
# 29430                     NaN
# 29435                     NaN
# 29736                     NaN
# 29962                     NaN
# 30273                     NaN
# 30657                     NaN
# 30763                     NaN
# 30772                     NaN
# 30814                     NaN
# 30901                     NaN
# 31132                     NaN
# 31240                     NaN
# 31292                     NaN
# 31510                     NaN
# 31511                     NaN
# 31852                     NaN
# 32096                     NaN
# 32354                     NaN
# 32516                     NaN
# 32541                     NaN
# 32577                     NaN
# 33142                     NaN
# 33293                     NaN
# 33640                     NaN
# 33703                     NaN
# 33763                     NaN
# 34172                     NaN
# 34338                     NaN
# 34649                     NaN
# 34684                     NaN
# 34688                     NaN
# 35004                     NaN
# 35095                     NaN
# 35181                     NaN
# 35534                     NaN
# 35634                     NaN
# 35742                     NaN
# 35763                     NaN
# 36438                     NaN
# 36855                     NaN
# 37000                     NaN
# 37128                     NaN
# 37551                     NaN
# 38019                     NaN
# 38216                     NaN
# 38279                     NaN
# 38369                     NaN
# 38452                     NaN
# 38546                     NaN
# 38555                     NaN
# 38639                     NaN
# 38758                     NaN
# 38823                     NaN
# 38858                     NaN
# 39058                     NaN
# 39136                     NaN
# 39257                     NaN
# 39525                     NaN
# 39654                     NaN
# 40126                     NaN
# 40155                     NaN
# 40168                     NaN
# 40280                     NaN
# 40987                     NaN
# 41006                     NaN
# 41461                     NaN
# 41709                     NaN
#
# [304 rows x 96 columns]

# %%
# confirming if there are some missing information regarding match stats for finals matches

missing[missing['tourney_round_name'] == 'finals']
# Out:
# Empty DataFrame
# Columns: [tourney_year_id, tourney_order, tourney_name, tourney_slug_match_scores, start_date, end_date, tourney_round_name, round_order, winner_name, winner_player_id, winner_slug, loser_name, loser_player_id, loser_slug, winner_seed, loser_seed, match_score_tiebreaks, winner_sets_won, loser_sets_won, winner_games_won, loser_games_won, winner_tiebreaks_won, loser_tiebreaks_won, match_id, tourney_year, pair, prize_money_USD, tourney_slug_match_stats, match_time, match_duration, winner_serve_rating, winner_aces, winner_double_faults, winner_first_serves_in, winner_first_serves_total, winner_first_serve_points_won, winner_first_serve_points_total, winner_second_serve_points_won, winner_second_serve_points_total, winner_break_points_saved, winner_break_points_serve_total, winner_service_games_played, winner_return_rating, winner_first_serve_return_won, winner_first_serve_return_total, winner_second_serve_return_won, winner_second_serve_return_total, winner_break_points_converted, winner_break_points_return_total, winner_return_games_played, winner_service_points_won, winner_service_points_total, winner_return_points_won, winner_return_points_total, winner_total_points_won, winner_total_points_total, loser_serve_rating, loser_aces, loser_double_faults, loser_first_serves_in, loser_first_serves_total, loser_first_serve_points_won, loser_first_serve_points_total, loser_second_serve_points_won, loser_second_serve_points_total, loser_break_points_saved, loser_break_points_serve_total, loser_service_games_played, loser_return_rating, loser_first_serve_return_won, loser_first_serve_return_total, loser_second_serve_return_won, loser_second_serve_return_total, loser_break_points_converted, loser_break_points_return_total, loser_return_games_played, loser_service_points_won, loser_service_points_total, loser_return_points_won, loser_return_points_total, loser_total_points_won, loser_total_points_total, winner_aces_norm, winner_break_points_converted_norm, winner_break_points_saved_norm, winner_double_faults_norm, winner_return_points_won_norm, winner_total_points_won_norm, loser_aces_norm, loser_break_points_converted_norm, loser_break_points_saved_norm, loser_double_faults_norm, loser_return_points_won_norm, loser_total_points_won_norm, max_aces, max_break_points_saved]
# Index: []
#
# [0 rows x 96 columns]

# %% [markdown]
# After seeing all of the information (the dataset with the missing values), we conclude that these missing values appear to be caused because there are no information regarding statistics for that game in the `match_stats` dataset. Therefore, since our analysis will only include statistics for the final match, and there are no missing information regarding those games, we decided that these rows with missing values can be deleted.

# %%
# dropping the observations

all_match.dropna(inplace = True)

# %% [markdown]
# After starting constructing of the dashboard, we noticed that it was being too slow, maybe due to the high number of features and observations in the datasets. Therefore, we decided to drop the variables and observations that were not needed for the analysis.

# %%
all_match = all_match[['tourney_name', 'tourney_round_name', 'round_order', 'match_duration', 'winner_name', 'loser_name', 'winner_aces', 'tourney_year', 'winner_break_points_converted',
                      'winner_double_faults', 'winner_return_points_won', 'winner_total_points_won', 'winner_aces_norm', 'winner_break_points_converted_norm', 'winner_break_points_saved_norm',
                      'winner_double_faults_norm', 'winner_return_points_won_norm', 'winner_total_points_won_norm', 'loser_aces', 'loser_break_points_converted', 'loser_break_points_saved',
                      'loser_double_faults', 'loser_return_points_won', 'loser_total_points_won', 'loser_aces_norm', 'loser_break_points_converted_norm', 'loser_break_points_saved_norm',
                      'loser_double_faults_norm', 'loser_return_points_won_norm', 'loser_total_points_won_norm', 'winner_break_points_saved', 'pair', 'max_break_points_saved', 'max_aces']]

all_match
# Out:
#       tourney_name    tourney_round_name  round_order  match_duration  \
# 0         Brisbane                Finals            1           125.0
# 1         Brisbane           Semi-Finals            2           128.0
# 2         Brisbane           Semi-Finals            2            61.0
# 3         Brisbane        Quarter-Finals            3            85.0
# 4         Brisbane        Quarter-Finals            3           100.0
# ...            ...                   ...          ...             ...
# 42616    Wimbledon  1st Round Qualifying           10           109.0
# 42617    Wimbledon  1st Round Qualifying           10            64.0
# 42618    Wimbledon  1st Round Qualifying           10           124.0
# 42619    Wimbledon  1st Round Qualifying           10            92.0
# 42620    Wimbledon  1st Round Qualifying           10            83.0
#
#              winner_name        loser_name  winner_aces  tourney_year  \
# 0           Andy Roddick    Radek Stepanek          7.0          2010
# 1           Andy Roddick     Tomas Berdych          7.0          2010
# 2         Radek Stepanek      Gael Monfils          3.0          2010
# 3           Andy Roddick   Richard Gasquet         16.0          2010
# 4         Radek Stepanek     Wayne Odesnik          7.0          2010
# ...                  ...               ...          ...           ...
# 42616           Go Soeda     Filippo Baldi          4.0          2019
# 42617      Yuichi Sugita    Carlos Berlocq          2.0          2019
# 42618  Mikael Torpegaard  Nikola Milojevic          6.0          2019
# 42619  Yasutaka Uchiyama       Jack Draper         14.0          2019
# 42620       Donald Young    Egor Gerasimov          2.0          2019
#
#        winner_break_points_converted  winner_double_faults  ...  \
# 0                                2.0                   1.0  ...
# 1                                2.0                   1.0  ...
# 2                                4.0                   0.0  ...
# 3                                1.0                   1.0  ...
# 4                                4.0                   4.0  ...
# ...                              ...                   ...  ...
# 42616                            3.0                   1.0  ...
# 42617                            3.0                   0.0  ...
# 42618                            3.0                   3.0  ...
# 42619                            2.0                   1.0  ...
# 42620                            2.0                   3.0  ...
#
#        loser_aces_norm  loser_break_points_converted_norm  \
# 0             0.485437                           0.769231
# 1             1.165049                           0.769231
# 2             0.097087                           0.000000
# 3             0.582524                           0.000000
# 4             0.291262                           0.384615
# ...                ...                                ...
# 42616         0.291262                           0.384615
# 42617         0.388350                           0.000000
# 42618         0.582524                           1.153846
# 42619         0.485437                           0.384615
# 42620         1.067961                           0.384615
#
#        loser_break_points_saved_norm  loser_double_faults_norm  \
# 0                           2.857143                  3.809524
# 1                           3.571429                  0.952381
# 2                           2.321429                  1.428571
# 3                           3.035714                  0.952381
# 4                           2.857143                  1.428571
# ...                              ...                       ...
# 42616                       1.785714                  1.428571
# 42617                       1.785714                  1.428571
# 42618                       2.142857                  0.952381
# 42619                       2.142857                  1.904762
# 42620                       1.785714                  0.000000
#
#        loser_return_points_won_norm  loser_total_points_won_norm  \
# 0                          2.136752                     1.673307
# 1                          2.307692                     1.633466
# 2                          1.282051                     0.717131
# 3                          0.940171                     1.115538
# 4                          1.709402                     1.115538
# ...                             ...                          ...
# 42616                      2.735043                     1.533865
# 42617                      0.769231                     0.756972
# 42618                      3.931624                     2.051793
# 42619                      2.051282                     1.294821
# 42620                      2.393162                     1.414343
#
#        winner_break_points_saved                                pair  \
# 0                            3.0         Andy Roddick-Radek Stepanek
# 1                            4.0          Andy Roddick-Tomas Berdych
# 2                            1.0         Gael Monfils-Radek Stepanek
# 3                            0.0        Andy Roddick-Richard Gasquet
# 4                            1.0        Radek Stepanek-Wayne Odesnik
# ...                          ...                                 ...
# 42616                       12.0              Filippo Baldi-Go Soeda
# 42617                        0.0        Carlos Berlocq-Yuichi Sugita
# 42618                        8.0  Mikael Torpegaard-Nikola Milojevic
# 42619                        2.0       Jack Draper-Yasutaka Uchiyama
# 42620                        4.0         Donald Young-Egor Gerasimov
#
#        max_break_points_saved  max_aces
# 0                         6.0       7.0
# 1                        10.0      12.0
# 2                         3.0       3.0
# 3                         7.0      16.0
# 4                         6.0       7.0
# ...                       ...       ...
# 42616                    12.0       4.0
# 42617                     0.0       4.0
# 42618                     8.0       6.0
# 42619                     2.0      14.0
# 42620                     4.0      11.0
#
# [42317 rows x 34 columns]

# %%
# saving the datasets already prepared to csv files

all_match.to_csv('all_match_preparation.csv')
tournaments.to_csv('tournaments_preparation.csv')
